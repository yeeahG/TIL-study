# %%
# 필요한 라이브러리 import
from bs4 import BeautifulSoup
from datetime import date,datetime, timedelta
import re, os, requests
import pandas as pd

# %%
# 브라우저 사용해서 접속하는 것처럼 하기 위해서 headers 입력 
head = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36 Edg/86.0.622.38'}

# %%
url = "https://n.news.naver.com/mnews/article/119/0002608171?sid=101"

# %%
r = requests.get(url, headers=head)

# %%
bs = BeautifulSoup(r.text, 'lxml')

# %%
bs
# Out:
# <!DOCTYPE html>
# <html data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36 Edg/86.0.622.38" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="신한금융, 국내 금융그룹 최초 ‘ESG 평가모형’ 개발" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://n.news.naver.com/mnews/article/119/0002608171?sid=101" property="og:url"/>
# <meta content="https://imgnews.pstatic.net/image/119/2022/05/30/0002608171_001_20220530091601422.jpeg" property="og:image"/>
# <meta content="[데일리안 = 이호연 기자] 신한금융그룹은 30일 국내 금융그룹 최초로 기업의 ESG 수준 평가를 통해 여신과 투자 등 다양한 의사결정에 활용하기 위한 ‘ESG 평가모형’을 개발했다고 밝혔다. 신한금융지주와 신한은행" property="og:description"/>
# <meta content="데일리안 | 네이버" property="og:article:author"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="신한금융, 국내 금융그룹 최초 ‘ESG 평가모형’ 개발" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="데일리안" name="twitter:creator"/>
# <meta content="https://imgnews.pstatic.net/image/119/2022/05/30/0002608171_001_20220530091601422.jpeg" name="twitter:image"/>
# <meta content="[데일리안 = 이호연 기자] 신한금융그룹은 30일 국내 금융그룹 최초로 기업의 ESG 수준 평가를 통해 여신과 투자 등 다양한 의사결정에 활용하기 위한 ‘ESG 평가모형’을 개발했다고 밝혔다. 신한금융지주와 신한은행" name="twitter:description"/>
# <meta content="gdid=8812A0A8_000000000000000002608171,service=news,collection=news,section=101" name="napp-site-analysis"/>
# <title>신한금융, 국내 금융그룹 최초 ‘ESG 평가모형’ 개발</title>
# <link href="https://static-nnews.pstatic.net/css/min/20220526a/news.css" rel="stylesheet"/>
# <link href="https://mimgnews.pstatic.net/image/news/m/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" rel="apple-touch-icon-precomposed" size="72x72"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" rel="apple-touch-icon-precomposed" size="96x96"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" rel="apple-touch-icon-precomposed" size="144x144"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed" size="192x192"/>
# <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>
# <script>
# 			var g_ssc = nsc = "Mnews.v2";
# 			var g_default_area = "art";
#
# 			var svr = "one-service-r-20220526-220526-173647-84c94db654-xbhcd";
# 			var nelo = {
# 				sampleNumber : 100,
# 				maxCount : 100,
# 				maxSendMessage : "로그 전송 최대치 도달"
# 			};
# 			var isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;
# 			var isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;
# 			var domain = "https://n.news.naver.com";
# 			var ajaxDomain = "";
# 			var newsDomain = "https://news.naver.com";
# 			var isAvailableDarkMode = false;
#
# 			var article = {
# 				isSubscribe: false,
# 				officeId: "119",
# 				articleId: "0002608171",
# 				sectionId : "101",
# 				gdid: "8812A0A8_000000000000000002608171",
# 				type: "1",
# 				sectionInfo: {
# 					firstSection: "101",
# 					secondSection: "263",
# 					thirdSection: "000"
# 				},
# 				title: document.title
# 			};
#
#
#
# 			var office = {
# 				isChannel: true,
# 				isPressHome: true,
# 				name : "데일리안",
# 				category : "인터넷/IT지"
# 			};
#
# 			var refererType = "UNKNOWN";
#
# 			var searchQuery = (function() {
# 				var referrerLink = document.createElement("a");
# 				var emptySearch = "";
#
# 				referrerLink.href = document.referrer || "";
#
# 				if (referrerLink.host.indexOf("search.naver.com") === -1) {
# 					return emptySearch;
# 				}
#
# 				return decodeURIComponent(
# 					(
# 						referrerLink.search.match(/(?:\?|&)query\=([^&]+)/) || [ null, emptySearch ]
# 					)[1].replace(/\+/g, " ")
# 				);
# 			})();
#
# 			var divIds = [];
# 			var syncDivIds = [];
# 			var syncDivIdsForNonArticle = [];
#
# 			var unitIds = [];
# 			var syncUnitIds = [];
# 			var syncUnitIdsForNonArticle = [];
#
# 			window.gladsdk = window.gladsdk || { cmd: [] };
# 			gladsdk.cmd.push(function() {
# 				gladsdk.setAdDeduplication("article_body_dedup");
# 				gladsdk.setGlobalConfig({ enablePersistAd: true });
#
# 				var adInfoList = [];
#
# 				adInfoList.push({
# 					seq: 1,
# 					unitId: "p_news_newsend",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "0",
# 					calp: false
# 				});
# 				adInfoList.push({
# 					seq: 2,
# 					unitId: "p_news_sidebox",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "0",
# 					calp: false
# 				});
#
# 				var userAgent = navigator.userAgent.toLowerCase();
#
# 				for (var i = 0; i < adInfoList.length; i++) {
# 					var adInfo = adInfoList[i];
#
# 					var divId = "nmap_c_" + article.officeId + "_" + article.articleId + "_" + article.sectionId + "_" + adInfo.seq;
#
# 					var unitId = adInfo.unitId;
# 					var mobileOnly = adInfo.mobileOnly;
# 					var sync = adInfo.sync;
# 					var isArticle = adInfo.article;
# 					var directSalesPct = adInfo.directSalesPct;
# 					var calp = adInfo.calp;
#
# 					if (mobileOnly == true) {
# 						if (/iphone|android|ipod/.test(userAgent) == false) {
# 							continue;
# 						}
# 					}
#
# 					var customParam = {
# 						sid1: article.sectionId,
# 						oid: article.officeId,
# 						gdid: article.gdid,
# 						pk: searchQuery,
# 						directSalesPct: directSalesPct
# 					};
#
# 					if (calp == true) {
# 						customParam.calp = "";
# 					}
#
# 					var adUnit = {
# 						adUnitId: unitId,
# 						adSlotElementId: divId,
# 						customParam: customParam
# 					};
#
# 					if (sync == true) {
# 						syncUnitIds.push(unitId);
# 						syncDivIds.push(divId);
#
# 						if (isArticle == false) {
# 							syncUnitIdsForNonArticle.push(unitId);
# 							syncDivIdsForNonArticle.push(divId);
# 						}
# 					} else {
# 						unitIds.push(unitId);
# 						divIds.push(divId);
# 					}
#
# 					gladsdk.defineAdSlot(adUnit);
# 				}
#
# 			});
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 		</script>
# <script src="https://static-nnews.pstatic.net/js/min/20220526/common.min.js"></script>
# </head>
# <body class="n_news_mnews fs2 as_mp_layout">
# <div class="end_container">
# <div class="u_skip"><a href="#ct">본문 바로가기</a></div>
# <header class="as_gnb_mnews" role="banner">
# <div class="header_inner">
# <div class="Ngnb">
# <div class="Ngnb_inner">
# <div class="Ngnb_both">
# <div class="Ngnb_left">
# <span class="Ngnb_logo"><a class="Nlogo_link _LINK" data-clk="gnb.naver" data-pc-url="https://www.naver.com/" data-url="https://m.naver.com/" href="https://m.naver.com/"><span class="Nicon_logo">NAVER</span></a></span>
# <div class="Ngnb_service">
# <h1 class="Nservice_item"><a class="_LINK" data-clk="gnb.news" data-pc-url="https://news.naver.com/" data-url="https://m.news.naver.com" href="https://m.news.naver.com"><span class="Nicon_service">뉴스</span></a></h1>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.entertain" data-pc-url="https://entertain.naver.com/home" data-url="https://m.entertain.naver.com" href="https://m.entertain.naver.com">
# <span class="Nicon_family Nicon_entertain">연예</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.sports" data-pc-url="https://sports.news.naver.com/index" data-url="https://m.sports.naver.com" href="https://m.sports.naver.com">
# <span class="Nicon_family Nicon_sports">스포츠</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.weather" href="https://weather.naver.com">
# <span class="Nicon_family Nicon_weather">날씨</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.elc2" href="https://news.naver.com/election/region2022">
# <span class="Nicon_family Nicon_election">선거</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.premium" href="https://contents.premium.naver.com">
# <span class="Nicon_family Nicon_premium">프리미엄</span>
# </a>
# </span>
# </div>
# </div>
# <div class="Ngnb_right">
# <div class="Ngnb_group">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="Ngnb_search _SEARCH_WRAP is_hidden"></div>
# <div class="Ngnb_tool">
# <a class="Ntool_button _SEARCH_CONTENT_TOGGLE_BUTTON" data-clk="gnb.scho" href="javascript:;"><span class="Nicon_search">검색</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Nlnb" data-scroll-fixed="true" id="_LNB_PARENT_WRAP" style="z-index:3000;">
# <div class="Nlnb_menu Ntype_scroll" id="_LNB_WRAP" style="position: relative;">
# <div class="Nlnb_menu_inner" id="_LNB">
# <ul class="Nlnb_menu_list" role="tablist">
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.press" href="https://news.naver.com/"><span class="Nitem_link_menu">언론사별</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.pol" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="Nitem_link_menu">정치</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM is_active" role="tab">
# <a class="Nitem_link" data-clk="lnb.eco" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="Nitem_link_menu">경제</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.soc" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="Nitem_link_menu">사회</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.lif" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="Nitem_link_menu">생활/문화</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.it" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="Nitem_link_menu">IT/과학</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.wor" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="Nitem_link_menu">세계</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.rank" href="https://news.naver.com/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="Nitem_link_menu">랭킹</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.paper" href="https://news.naver.com/newspaper/home"><span class="Nitem_link_menu">신문보기</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.opi" href="https://news.naver.com/main/opinion/home.naver"><span class="Nitem_link_menu">오피니언</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.tv" href="https://news.naver.com/main/tv/index.naver?mid=tvh"><span class="Nitem_link_menu">TV</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.fact" href="https://news.naver.com/main/factcheck/main.naver"><span class="Nitem_link_menu">팩트체크</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </header>
# <hr/>
# <script>
# 	var svt = "20220530091837";
# 	var timestamp = svt.substr(0, 8);
# 	var isLogin = false;
# 	var uhv = "";
#
# 	var service = {
# 		news: false,
# 		entertain: false,
# 		sports: false,
# 		mnews: true,
# 		newsType: true
# 	};
# 	var serviceName = "mnews";
#
# 	var isProduction = true;
#
# 	var gnb_service = "news";
# 	var gnb_logout = encodeURIComponent(location.href);
# 	var gnb_template = "gnb_utf8";
# 	var gnb_brightness = 3;
# </script>
# <div class="ct_wrap" id="ct_wrap">
# <div class="ct_scroll_wrapper">
# <div class="newsct_wrapper _GRID_TEMPLATE_COLUMN"><div class="newsct" id="ct" role="main">
# <div class="media_end_head go_trans">
# <div class="media_end_head_top">
# <a class="media_end_head_top_logo" href="http://www.dailian.co.kr/">
# <img alt="데일리안" class="media_end_head_top_logo_img light_type" height="32" src="https://mimgnews.pstatic.net/image/upload/office_logo/119/2020/09/15/logo_119_6_20200915174844.png" title="데일리안" width=""/>
# <img alt="데일리안" class="media_end_head_top_logo_img dark_type" height="32" src="https://mimgnews.pstatic.net/image/upload/office_logo/119/2020/09/15/dark_logo_119_6_20200915174833.png" title="데일리안" width=""/>
# </a>
# <div class="media_end_head_top_channel _CHANNEL_BUTTON_WRAP" style="display:none;">
# <button class="media_end_head_top_channel_add _CHANNEL_BUTTON" data-clk-add="chmain119" data-clk-remove="chdelete119" data-delay="1000" data-notification="true" data-notification-clk="notru" data-text="구독">구독</button>
# <a class="media_end_head_top_channel_layer _LINK" data-clk="chlook" data-url-type="NAVERAPP_NEWS_CHANNEL" href="#" id="_CHANNEL_LAYER_119_0002608171" style="display: none;">
# <span class="media_end_head_top_channel_layer_text"><strong>데일리안</strong> 언론사 구독되었습니다. <br/>메인 뉴스판에서  주요뉴스를 <br/> 볼 수 있습니다.</span>
# <span class="media_end_head_top_channel_layer_link">보러가기</span>
# </a>
# <p class="media_end_head_top_channel_layer" id="_CHANNEL_REMOVE_LAYER_119_0002608171" style="display: none;">
# <span class="media_end_head_top_channel_layer_text"><strong>데일리안</strong> 언론사 구독 해지되었습니다.</span>
# </p>
# </div>
# </div>
# <div class="media_end_head_title">
# <h2 class="media_end_head_headline">신한금융, 국내 금융그룹 최초 ‘ESG 평가모형’ 개발</h2>
# </div>
# <div class="media_end_head_info nv_notrans">
# <div class="media_end_head_info_datestamp">
# <div class="media_end_head_info_datestamp_bunch">
# <em class="media_end_head_info_datestamp_term">입력</em><span class="media_end_head_info_datestamp_time _ARTICLE_DATE_TIME" data-date-time="2022-05-30 09:16:01">2022.05.30. 오전 9:16</span>
# </div>
# <a class="media_end_head_origin_link" data-clk="are.ori" data-extra='{"lk":{"oid":"119","aid":"0b6b783976156c67"}}' data-gdid="119" href="https://www.dailian.co.kr/news/view/1118404/?sc=Naver" target="_blank">기사원문</a>
# </div> <div class="media_end_head_info_variety">
# <div class="media_end_head_info_variety_left" id="commentFontGroup">
# <div class="media_end_head_info_variety_likeit _LIKE_HIDE as_likeit_improve">
# <!-- 좋아요 -->
# <div class="_reactionModule u_likeit nv_notrans" data-cid="ne_119_0002608171" data-sid="NEWS">
# <a aria-haspopup="true" aria-pressed="false" class="u_likeit_button _face _LIKE_BUTTON" data-clk="RTL.face" data-label="recommend">
# <span class="u_likeit_icons _icons">
# <span class="u_likeit_icon __reaction__zeroface"></span>
# </span>
# <span class="u_likeit_text _count">추천</span>
# </a>
# <ul class="u_likeit_layer _faceLayer" role="menu">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.useful|RTL.unuseful" data-type="useful" href="#" role="button">
# <span class="u_likeit_list_name _label">쏠쏠정보</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list wow" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.wow|RTL.unwow" data-type="wow" href="#" role="button">
# <span class="u_likeit_list_name _label">흥미진진</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list touched" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.touched|RTL.untouched" data-type="touched" href="#" role="button">
# <span class="u_likeit_list_name _label">공감백배</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list analytical" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.analytical|RTL.unanalytical" data-type="analytical" href="#" role="button">
# <span class="u_likeit_list_name _label">분석탁월</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list recommend" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.recommend|RTL.unrecommend" data-type="recommend" href="#" role="button">
# <span class="u_likeit_list_name _label">후속강추</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul> </div>
# <!-- 좋아요 -->
# </div>
# <div class="media_end_head_info_variety_cmtcount _COMMENT_HIDE">
# <a class="media_end_head_cmtcount_button _COMMENT_COUNT_VIEW" data-clk="rplt" data-max-limit="true" data-zero-allow="false" href="/mnews/article/comment/119/0002608171?sid=101" id="comment_count">댓글</a>
# </div>
# </div>
# <div class="media_end_head_info_variety_right">
# <!-- 요약봇 -->
# <div class="media_end_head_autosummary _auto_summary_wrapper _SUMMARY _LIKE_HIDE" data-articleid="0002608171" data-officeid="119" id="_SUMMARY_BUTTON">
# <a class="media_end_head_autosummary_button _toggle_btn _SUMMARY_BTN" data-clk="sum" href="javascript:;"><span class="blind">본문 요약봇</span></a>
# <div class="media_end_head_autosummary_layer_dimmed _SUMMARY_DIMMED" style="display: none;"></div>
# <div class="media_end_head_autosummary_layer _auto_summary_contents _SUMMARY_LAYER" style="display: none;">
# <div class="media_end_head_autosummary_layer_head">
# <strong class="media_end_head_autosummary_layer_head_tit">본문 요약봇<a class="media_end_head_autosummary_help _LINK" data-clk="help" data-pc-url="https://help.naver.com/support/contents/contents.help?serviceNo=997&amp;categoryNo=19330" data-url="https://m.help.naver.com/support/alias/news/news_m15.naver" href="https://m.help.naver.com/support/alias/news/news_m15.naver">도움말</a></strong>
# <span class="media_end_head_autosummary_layer_head_txt">자동 추출 기술로 요약된 내용입니다. 요약 기술의 특성상 본문의 주요 내용이 제외될 수 있어, 전체 맥락을 이해하기 위해서는 기사 본문 전체보기를 권장합니다.</span>
# <a class="media_end_head_autosummary_layer_close _close_button _SUMMARY_CLOSE_BTN" data-clk="close" href="javascript:;"><span class="blind">닫기</span></a>
# </div>
# <div class="media_end_head_autosummary_layer_body">
# <div class="_contents_body _SUMMARY_CONTENT_BODY"></div>
# </div>
# </div>
# </div>
# <!-- TTS -->
# <div class="media_end_head_tts nv_notrans" id="tts_player_div_wrap">
# <button class="media_end_head_tts_run _TTS_SETTING_BTN" data-clk="wtts" title="텍스트 음성 변환 서비스" type="button"><span class="blind">텍스트 음성 변환 서비스 사용하기</span></button>
# <div class="media_end_head_tts_setlayer nv_notrans _TTS_SETTING_LAYER">
# <div class="media_end_head_tts_setlayer_select">
# <div class="media_end_head_tts_setlayer_select_bunch" id="ttsSelectGender">
# <em class="media_end_head_tts_option_tit">성별</em>
# <button class="media_end_head_tts_option" data-clk="ttsma" type="button" value="m">남성</button>
# <button class="media_end_head_tts_option" data-clk="ttsfe" type="button" value="f">여성</button>
# </div>
# <div class="media_end_head_tts_setlayer_select_bunch" id="ttsSelectSpeed">
# <em class="media_end_head_tts_option_tit">말하기 속도</em>
# <button class="media_end_head_tts_option" data-clk="ttssp" type="button" value="3">느림</button>
# <button class="media_end_head_tts_option" data-clk="ttssp" type="button" value="2">보통</button>
# <button class="media_end_head_tts_option" data-clk="ttssp" type="button" value="0">빠름</button>
# </div>
# <p class="media_end_head_tts_desc">이동 통신망을 이용하여 음성을 재생하면 별도의 데이터 통화료가 부과될 수 있습니다.</p>
# <button class="media_end_head_tts_apply _TTS_LISTEN_BTN" data-clk="ttsstart" type="button">본문듣기 시작</button>
# </div>
# <button class="media_end_head_tts_setlayer_close _TTS_SETTING_LAYER_CLOSE_BTN" data-clk="ttsclose" type="button"><span class="blind">닫기</span></button>
# </div>
# </div>
# <div id="tts_player_div"></div> <!-- 폰트 사이즈 -->
# <div class="media_end_head_fontsize _font_size_config_wrapper _FONT_WRAP">
# <a class="media_end_head_fontsize_set _font_size_config_toggle_btn _FONT_BUTTON" data-clk="fsz" href="#"><span class="blind">글자 크기 변경하기</span></a>
# <div class="media_end_head_fontsize_setlayer _FONT_LAYER">
# <ul class="media_end_head_fontsize_setlayer_select">
# <li class="media_end_head_fontsize_option1 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz1" data-value="1" href="#">가<em class="blind">1단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz1" data-value="1" href="#">작게</a>
# </li>
# <li class="media_end_head_fontsize_option2 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz2" data-value="2" href="#">가<em class="blind">2단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz2" data-value="2" href="#">보통</a>
# </li>
# <li class="media_end_head_fontsize_option3 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz3" data-value="3" href="#">가<em class="blind">3단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz3" data-value="3" href="#">크게</a>
# </li>
# <li class="media_end_head_fontsize_option4 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz4" data-value="4" href="#">가<em class="blind">4단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz4" data-value="4" href="#">아주크게</a>
# </li>
# <li class="media_end_head_fontsize_option5 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz5" data-value="5" href="#">가<em class="blind">5단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz5" data-value="5" href="#">최대크게</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="media_end_head_share nv_notrans">
# <a class="u_btn_sns_share naver-splugin spi_sns_share nv_notrans _SHARE_BUTTON" data-band-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=band" data-blog-blog-id="naver" data-blog-source-type="3" data-blog-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=blog" data-cafe-source-type="3" data-cafe-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=cafe" data-calendar-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=calendar" data-canonical-url="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=sec&amp;oid=119&amp;aid=0002608171&amp;sid1=001" data-clk="ushr" data-facebook-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=facebook" data-friend-display="on" data-friend-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=friend" data-kakaostory-display="off" data-kakaotalk-image-url="https://imgnews.pstatic.net/image/119/2022/05/30/0002608171_001_20220530091601422.jpeg?type=nf300_200" data-kakaotalk-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=kakao" data-likecontentsid="ne_119_0002608171" data-likeserviceid="NEWS" data-line-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=line" data-mail-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=mail" data-memo-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=memo" data-mypeople-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=mypeople" data-style="type_a" data-title="신한금융, 국내 금융그룹 최초 ‘ESG 평가모형’ 개발" data-twitter-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=twitter" data-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101" href="#" id="spiButton" onclick="return false">
# <span class="naver-splugin-c send_caption"><span class="u_hc">SNS 보내기</span></span>
# </a>
# </div>
# <div class="media_end_head_print">
# <a class="media_end_print_link _PRINT_BUTTON" data-clk="print" data-print-url="/mnews/article/print/119/0002608171" href="#"><span class="blind">인쇄하기</span></a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="newsct_body" id="contents">
# <div class="newsct_article _article_body" id="newsct_article">
# <div class="go_trans _article_content" id="dic_area">
# <strong class="media_end_summary">그룹사 여신 및 투자 의사결정에 활용</strong><span class="end_photo_org"><div class="nbd_im_w _LAZY_LOADING_WRAP">
# <div class="nbd_a _LAZY_LOADING_ERROR_HIDE" id="img_a1">
# <img class="_LAZY_LOADING" data-src="https://imgnews.pstatic.net/image/119/2022/05/30/0002608171_001_20220530091601422.jpeg?type=w647" id="img1"/>
# </div>
# </div><em class="img_desc">신한금융그룹 사옥 ⓒ 신한금융그룹</em></span>[데일리안 = 이호연 기자] 신한금융그룹은 30일 국내 금융그룹 최초로 기업의 ESG 수준 평가를 통해 여신과 투자 등 다양한 의사결정에 활용하기 위한 ‘ESG 평가모형’을 개발했다고 밝혔다.<br/><br/>신한금융지주와 신한은행이 공동 개발한 평가모형은 기업의 ESG 투자 수준을 평가하는 ‘신한 ESG 모형’과 해당 투자에 따른 영향과 지속가능 수준을 평가하는 ‘신한 지속가능 모형’ 두 가지로 구분된다.<br/><br/>ESG 평가모형은 기업의 전반적인 ESG 수준을 A+~A-(우수), B+~B-(보통), C(미흡) 등 7개 등급으로 평가한다. 데이터 공개 규모가 비교적 큰 IFRS와 외감 기업에 대한 평가를 시작으로, 향후 관련 데이터 누적을 통해 비외감 중소기업까지 평가를 확대하도록 모형을 더욱 정교화 할 계획이다.<br/><br/>신한은행은 ESG 평가모형을 통해 산출된 등급을 ‘신한 ESG 우수 상생지원대출’의 대상 선정기준으로 활용할 예정이다. 또한 신한금융그룹은 그룹사들이 ESG 평가 결과를 다양하게 활용할 수 있는 방안을 지속적으로 강구해 나갈 계획이다.<br/><br/>신한금융 조용병 회장은 “이번 ESG 평가모형은 기업의 ESG 수준을 데이터에 기반해 정량적으로 평가 가능하다는 데 큰 의의가 있다”며, “ESG 리딩 금융그룹으로서 탄소배출량 넷제로 달성을 목표로 ESG 실천을 더욱 가속화해 나가겠다”고 말했다.<br/><br/>한편 신한금융은 지난 3월 국내 금융그룹 최초로 금융자산의 탄소배출량을 효율적으로 관리하기 위한 ‘금융배출량 측정 시스템’을 개발해 체계적인 ESG 리스크 관리를 위한 기반을 마련했다.
# 		</div>
# </div>
# <div class="byline">
# <p class="byline_p">
# <span class="byline_s">이호연 기자 (mico911@dailian.co.kr)</span>
# </p>
# </div>
# <div class="copyright">
# <div class="c_inner">
# <p class="c_text">Copyright ⓒ 데일리안. All rights reserved. 무단 전재 및 재배포 금지.</p>
# </div>
# </div> <div class="media_end_categorize">
# <a class="media_end_categorize_link _categorize_title _TOGGLE" data-target="_ARTICLE_SECTION_GUIDE_LAYER" href="#">이 기사는 언론사에서 <em class="media_end_categorize_item">경제</em> 섹션으로 분류했습니다.</a>
# <div class="media_end_categorize_ct" id="_ARTICLE_SECTION_GUIDE_LAYER">
# <em class="media_end_categorize_ct_title">기사 섹션 분류 안내</em>
# <p class="media_end_categorize_ct_p">기사의 섹션 정보는 해당 언론사의 분류를 따르고 있습니다. 언론사는 개별 기사를 2개 이상 섹션으로 중복 분류할 수 있습니다.</p>
# <a class="media_end_categorize_ct_close _CLOSE" data-target="_ARTICLE_SECTION_GUIDE_LAYER" href="#">닫기</a>
# </div>
# </div>
# <div id="channelBanner" style="display:none;">
# <div class="media_end_channel_banner _LAZY_LOADING_WRAP">
# <a class="media_end_channel_banner_link _CHANNEL_BANNER _CHANNEL_ADD" data-clk-add="chbanner119" data-clk-remove="chsee119" data-notification="true" data-notification-clk="notbb" href="#">
# <div class="media_end_channel_banner_head _LAZY_LOADING_ERROR_HIDE">
# <div class="media_end_channel_banner_img">
# <img alt="데일리안" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/119/2018/08/08/logo_119_57_20180808174508.png" height="40" style="display:none;" width="40"/>
# </div>
# </div>
# <div class="media_end_channel_banner_body _before _CHANNEL_BANNER_ADD">
# <p class="media_end_channel_banner_add">구독</p>
# <p class="media_end_channel_banner_txt"><span class="media_end_channel_banner_span"><strong>메인에서</strong> 바로 보는 언론사 편집 뉴스 지금 바로 구독해보세요!</span></p>
# </div>
# <div class="media_end_channel_banner_body _after _CHANNEL_BANNER_REMOVE is_hidden">
# <p class="media_end_channel_banner_add is_disabled">구독중</p>
# <p class="media_end_channel_banner_txt"><span class="media_end_channel_banner_span"><strong>메인에서</strong> 바로 보는 언론사 편집 뉴스 지금 바로 확인해보세요!</span> <em>보러가기</em></p>
# </div>
# </a>
# </div>
# </div>
# <div id="channelBannerRecommendList"></div>
# <script class="_CHANNEL_BANNER_RECOMMEND_LIST" type="x-tmpl-mustache">
# 	<div class="office_preference _CHANNEL_BANNER_RECOMMEND_LIST_WRAP">
# 	<div class="ofpr_recommend">
# 		<div class="ofpr_recommend_inner">
# 			<div class="ofpr_more_link">
# 				<h4 class="ofpr_tit">추가 구독해보세요</h4>
# 			</div>
# 			<ul class="ofpr_channel">
# 				{{#recommendList}}
# 				<li class="ofpr_item">
# 					<a href="#" class="ofpr_a _ALL_OFFICES_ITEM" data-officeId="{{officeId}}" data-officename="{{name}}" data-logo="{{logo}}" role="checkbox" aria-checked="false" data-clk-add="chwith" data-clk-remove="chwithno" data-target="_CHANNEL_BANNER_RECOMMEND_LIST_WRAP">
# 						<div class="ofpr_thumb"><img src="{{logo}}" class="ofpr_m" alt=""></div>
# 						<div class="ofpr_text">{{name}}</div>
# 						<span class="ofpr_badge">언론사 추가</span>
# 					</a>
# 				</li>
# 				{{/recommendList}}
# 			</ul>
# 			<div class="ofpr_btn_wrap">
# 				<button type="button" class="ofpr_btn_more _ALL_OFFICE_LIST" data-clk="chwithall">언론사 전체보기</button>
# 				<button type="button" class="ofpr_btn_confirm _ALL_OFFICES_COMPLETE disabled" data-clk-disabled="chwithsetall" data-clk-enabled="chwithchoice" data-target="_CHANNEL_BANNER_RECOMMEND_LIST_WRAP">언론사 전체 선택</button>
# 			</div>
# 			<button type="button" class="ofpr_recommend_close _TOGGLE" data-target="channelBannerRecommendList" data-clk="chclosing">닫기</button>
# 		</div>
# 	</div>
# 	</div>
# 	</script>
# <div class="promotion">
# <ul class="p_list">
# <li class="p_item">
# <a class="p_link" data-clk="promo" href="https://www.dailian.co.kr/newsList?series=89">데일리안 만평보기</a>
# </li>
# <li class="p_item">
# <a class="p_link" data-clk="promo" href="https://m.dailian.co.kr/report">제보하기</a>
# </li>
# </ul>
# </div> <div class="media_end_linked">
# <h3 class="media_end_linked_title">
# <a class="media_end_linked_title_inner" href="http://www.dailian.co.kr/">
# <img alt="데일리안" class="media_end_linked_title_img light_type" height="26" src="https://mimgnews.pstatic.net/image/upload/office_logo/119/2020/09/15/logo_119_6_20200915174844.png" title="데일리안" width=""/>
# <img alt="데일리안" class="media_end_linked_title_img dark_type" height="26" src="https://mimgnews.pstatic.net/image/upload/office_logo/119/2020/09/15/dark_logo_119_6_20200915174833.png" title="데일리안" width=""/>
# </a>
# 			주요뉴스<span class="media_end_linked_title_desc">해당 언론사에서 선정하며 <em>언론사 페이지(아웃링크)</em>로 이동해 볼 수 있습니다.</span>
# </h3>
# <ul class="media_end_linked_list">
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"119","aid":"a53de53e0c95dbfe"}}' data-gdid="119" href="https://www.dailian.co.kr/news/view/1117038?sc=Naver" target="_blank">신한금융투자, 골프존과 가상 골프장 열어</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"119","aid":"212097608b323fe0"}}' data-gdid="119" href="https://www.dailian.co.kr/news/view/1117003?sc=Naver" target="_blank">신한금융, '신한 스퀘어브릿지 대전' 네트워킹 행사 개최</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"119","aid":"82df313c7adb8dfc"}}' data-gdid="119" href="https://www.dailian.co.kr/news/view/1116523?sc=Naver" target="_blank">신한금융, 인큐베이션 9기 스타트업 모집...총상금 1억</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"119","aid":"171025222f366c22"}}' data-gdid="119" href="https://www.dailian.co.kr/news/view/1116154?sc=Naver" target="_blank">신한금융투자, 응원하기 캠페인 영상 시즌4 공개</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"119","aid":"33aeb6b1c2f56571"}}' data-gdid="119" href="https://www.dailian.co.kr/news/view/1115709?sc=Naver" target="_blank">신한금융희망재단, 가족정책 유공 대통령 표창 수상</a></li>
# </ul>
# </div>
# <div class="r_group_comp ad_box _da_banner is_border_none">
# <div class="ad_area _AD_WRAP _PERSIST_HEIGHT" data-article="false" data-mobileonly="false" data-persist="1_ad" data-sync="false" data-unitid="p_news_newsend" id="nmap_c_119_0002608171_101_1"></div>
# </div>
# <script>
# 	window.__htExternalUrl = window.__htExternalUrl || {};
# 	window.__htExternalUrl["like"] = "https://news.like.naver.com/js/reaction/dist/reaction.min.js";
# 	window.__htLikeOption = {
# 		type: "multi",
# 		cssId: "news",
# 		domain: "https://news.like.naver.com",
# 		isMobile: true,
# 		isHiddenLabel: false,
# 		isHiddenCount: false,
# 		isHiddenZeroCount: false,
# 		isUsedLabelAsZeroCount: false,
# 		isDebugMode: false,
# 		isDuplication: false,
# 		isHiddenLayerAfterSelection: true,
# 		clicklog: function(el, name) {
# 			nclkWrap.send({
# 				$this: $(el),
# 				sArea: name
# 			});
# 		}
# 	};
# 	window.__htLikeOption["isZeroFace"] = true;
# 	</script>
# <div class="ends_btn _PERSIST_HEIGHT _LIKE_HIDE as_likeit_improve" data-persist="0_faceLike">
# <div class="ends_btn_head">
# <strong class="ends_head_title">이 기사를 추천합니다</strong>
# <button class="ends_help_btn _TOGGLE" data-classvalue="is_hidden" data-clk="RTC.info" data-target="_LIKE_INFO_LAYER" type="button"></button>
# <div class="ends_help_layer is_hidden" id="_LIKE_INFO_LAYER">
# <p class="ends_help_desc">기사 추천은 24시간 내 50회까지 참여할 수 있습니다.</p>
# <button class="ends_help_close _TOGGLE" data-classvalue="is_hidden" data-clk="RTC.infoclose" data-target="_LIKE_INFO_LAYER"><span class="blind">닫기</span></button>
# </div>
# </div>
# <div class="_reactionModule u_likeit" data-cid="ne_119_0002608171" data-sid="NEWS" id="likeItCountViewDiv" style="visibility: visible;">
# <ul class="u_likeit_layer _faceLayer" role="menu">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.useful|RTC.unuseful" data-type="useful" href="#" role="button">
# <span class="u_likeit_list_name _label">쏠쏠정보</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list wow" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.wow|RTC.unwow" data-type="wow" href="#" role="button">
# <span class="u_likeit_list_name _label">흥미진진</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list touched" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.touched|RTC.untouched" data-type="touched" href="#" role="button">
# <span class="u_likeit_list_name _label">공감백배</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list analytical" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.analytical|RTC.unanalytical" data-type="analytical" href="#" role="button">
# <span class="u_likeit_list_name _label">분석탁월</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list recommend" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.recommend|RTC.unrecommend" data-type="recommend" href="#" role="button">
# <span class="u_likeit_list_name _label">후속강추</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul> </div>
# <div class="u_likeit_module u_btn_likeit_on" id="likeItSTimeLineShareDiv" style="display:none"></div>
# <div class="u_likeit_module" id="likeItScrollDiv" style="display:none">
# <div class="u_likeit_friends" id="likeItFriendListDiv"></div>
# </div>
# </div> <div class="ends_addition" id="endAdditionContainer">
# <script>
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 			window.__htExternalUrl["share"] = "https://ssl.pstatic.net/spi/js/release/ko_KR/splugin.js";
# 			window.__htShareOption = {
# 				"scriptUrl": window.__htExternalUrl["share"],
# 				"evKey": "news",
# 				"dimmed": "fixed",
# 				"serviceName": "뉴스",
# 				"sourceName": "데일리안"
# 			};
# 			if (isAvailableDarkMode) {
# 				window.__htShareOption["darkMode"] = true;
# 			}
# 		</script>
# <div id="spiLayer" style="display:none;">
# <div class="spi_wrap layer_share_on">
# <div class="spi">
# <div class="spug">
# <a class="naver-splugin _spi_release spi_ico _btn_postbtn sns_share" data-band-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=band" data-blog-blog-id="naver" data-blog-source-type="3" data-blog-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=blog" data-button="postbtn" data-cafe-source-type="3" data-cafe-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=cafe" data-calendar-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=calendar" data-clk="dshr" data-facebook-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=facebook" data-friend-display="on" data-friend-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=friend" data-kakaostory-display="off" data-kakaotalk-image-url="https://imgnews.pstatic.net/image/119/2022/05/30/0002608171_001_20220530091601422.jpeg?type=nf300_200" data-kakaotalk-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=kakao" data-likecontentsid="ne_119_0002608171" data-likeserviceid="NEWS" data-line-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=line" data-mail-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=mail" data-memo-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=memo" data-mypeople-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=mypeople" data-style="type_a" data-title="신한금융, 국내 금융그룹 최초 ‘ESG 평가모형’ 개발" data-twitter-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101&amp;lfrom=twitter" data-url="https://n.news.naver.com/mnews/article/119/0002608171?sid=101" href="#"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="tomain_info _LIKE_HIDE" id="_TOMAIN_INFO" style="display: none;">
# <p class="tomain_info_layer">
# <strong class="tomain_info_head">모두에게 보여주고 싶은 기사라면<i>?</i><span class="tomain_info_betaicon">beta</span></strong>
# <span class="tomain_info_body">
# <strong class="tomain_info_point">이 기사를 추천합니다 </strong><span class="tomain_info_text">버튼을 눌러주세요. <br/> 집계 기간 동안 추천을 많이 받은 기사는 네이버 자동 기사배열 영역에 추천 요소로 활용됩니다.</span>
# </span>
# <a class="tomain_info_close _CLOSE" data-target="_TOMAIN_INFO" href="#">레이어 닫기</a>
# </p>
# </div>
# </div> <div class="media_end_linked_more">
# <div class="media_end_linked_more_inner">
# <a class="media_end_linked_more_link" data-clk="phome" data-gdid="119" href="https://media.naver.com/press/119"><em class="media_end_linked_more_point">데일리안</em> 언론사홈 바로가기</a>
# </div>
# </div>
# <script>
# 		window.__htExternalUrl = window.__htExternalUrl || {};
# 		window.__htExternalUrl["tip"] = "https://ssl.pstatic.net/dicimg/tip/tip_m.js";
# 		window.__htExternalUrl["pcTip"] = "https://ssl.pstatic.net/dicimg/tip/tip_pc.js";
#
# 		window.__htExternalUrl["handOff"] = {
# 			"category": "news_article",
# 			"apiDomain": "https://sidekick.fever.naver.com"
# 		};
# 	</script> <div class="subscribe_cta_layer" id="_MODAL_LAYER_FOR_UNSUBSCRIBER_PROMOTION">
# <button class="cta_btn as_subscribe _CHANNEL_ADD" data-clk-add="mediaflw" data-delay="1000" data-notification="true" type="button">
# <span class="cta_text"><em class="cta_text_em">언론사 구독 후</em> 기사보기</span>
# <i class="cta_arrow"></i>
# </button>
# <button class="cta_btn _UNSUBSCRIBER_PROMOTION_CLOSE" data-clk="medianoflw" type="button">
# <span class="cta_text"><em class="cta_text_em">구독 없이</em> 계속 보기</span>
# <i class="cta_arrow"></i>
# </button>
# </div>
# </div>
# </div>
# <div class="box1 more_news2">
# <h4>
# 프리미엄콘텐츠 창작자 발굴 프로젝트
# </h4>
# <div class="type2">
# <a class="thumb" href="https://blog.naver.com/premiumcontents/222738586098" onclick="nclk(event,'wit.img','','1');"><img alt="섬네일 이미지" height="80" onerror="javascript:this.src='https://imgnews.pstatic.net/image/news/2009/noimage_120x90.gif';this.style.width=115;this.style.height=80;" src="https://imgnews.pstatic.net/image/upload/item/2022/05/20/144806945_%25B8%25F0%25B9%25D9%25C0%25CF_%25B1%25E2%25BB%25E7_%25BA%25BB%25B9%25AE_460X320_03.%25B9%25CC%25BC%25FA%25B0%25FC%252C%25BF%25CD%25C0%25CC%25BE%25C6%25C6%25AE%252C%25BE%25C6%25C6%25AE%25B8%25D3%25B4%25CF.png" width="115"/><span class="frame"></span></a>
# <a href="https://blog.naver.com/premiumcontents/222738586098" onclick="nclk(event,'wit.tit','','1');">
# <strong>네이버에서 콘텐츠로 돈 벌 사람? 지금 바로 도전하세요! </strong>
# <p>프리미엄 스타 채널로 성장해나갈 창작자분들을 모십니다.
# </p>
# </a>
# </div>
# </div>
# <div class="check_visible" id="frontDetect"></div>
# <div class="office_headline more_news optional_hidden pc_hidden _FLICKING_WRAP _OFFICE_HEADLINE _PERSIST_HEIGHT _PERSIST_META" data-count="3" data-flicking-nclk="false" data-grid-template-column-aside="" data-nclk-prefix="art" data-persist="3_officeHeadline">
# <div class="ofhe_head">
# <div class="ofhe_head_inner">
# <h2 class="ofhe_head_title">
# <a class="ofhe_head_title_link" data-clk="art.pheadhome" href="https://media.naver.com/press/119">
# <em>데일리안</em> 헤드라인
# 					</a>
# </h2>
# </div>
# </div>
# <div class="ofhe_body flick">
# <div class="flick-container _FLICKING" style="height: 161px; opacity:0;">
# <div class="flick-panel">
# <ul class="ofhe_list">
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link" data-clk="art.phead" href="/mnews/article/119/0002608107">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/119/2022/05/30/2608107.jpg?type=nf336_206&amp;ut=20220530080801"/>
# </div>
# </div>
# <div class="ofhe_headline">박지현 "5대 혁신안 수용한 지도부 감사…내부 갈등에 거듭 죄송"</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">[데일리안 = 이한나 기자] 박지현 더불어민주당 공동비상대책위원장은 29일 "어제 우리 당 지도부가 제가 제안한 5대 혁신안을 모두 수용했다"며 "혁신안을 수용해 주신 윤호중 공동비대위원장님과 비대위원들께 깊은 감사</div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link" data-clk="art.phead" href="/mnews/article/119/0002608114">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/119/2022/05/30/2608114.jpg?type=nf336_206&amp;ut=20220530053001"/>
# </div>
# </div>
# <div class="ofhe_headline">[법조계에 물어보니 ㊴] 공무원에 한정 '구하라법'…언제 민간까지 적용될까?</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">[데일리안 = 이태준 기자] 양육 의무를 저버린 부모의 상속권을 박탈하는 이른바 '구하라법'이 공무원에게만 적용되자, 법조계에선 반쪽짜리 법안이라며 민간 영역까지 확대돼야 한다고 촉구했다. 당초 구하라법은 그룹 카라</div>
# </a>
# </li>
# </ul>
# </div>
# <div class="flick-panel">
# <ul class="ofhe_list">
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link" data-clk="art.phead" href="/mnews/article/119/0002608129">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/119/2022/05/30/2608129.jpg?type=nf336_206&amp;ut=20220530070801"/>
# </div>
# </div>
# <div class="ofhe_headline">민주당의 집단적 지능저하 현상 [이진곤의 그건 아니지요]</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">[데일리안 = 데스크] 약간 머리가 모자라는 두 친구가 한 마을에서 살고 있었다. 갑이 을을 보고 말했다. “사람들이 우리를 보고 머리가 모자라느니, 등신이라느니 하는데 도대체 무슨 까닭일까?” 을이 한참 생각한 끝</div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link" data-clk="art.phead" href="/mnews/article/119/0002608124">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/119/2022/05/30/2608124.jpg?type=nf336_206&amp;ut=20220530063301"/>
# </div>
# </div>
# <div class="ofhe_headline">아파트 매수심리는 주춤…'엔데믹' 효과, 상업·업무용 부동산 '방긋'</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">[데일리안 = 배수람 기자] 정부의 다주택자 양도소득세 중과 한시적 배제 조치로 시장에 주택매물이 늘고 있지만, 매수자들은 여전히 관망세를 보이고 있다. 반면 사회적 거리두기 완화 등으로 상권 회복세가 나타나며 상업</div>
# </a>
# </li>
# </ul>
# </div>
# <div class="flick-panel">
# <ul class="ofhe_list">
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link" data-clk="art.phead" href="/mnews/article/119/0002608118">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/119/2022/05/30/2608118.jpg?type=nf336_206&amp;ut=20220530060002"/>
# </div>
# </div>
# <div class="ofhe_headline">6월부터 MMORPG 대작 '정면승부'…출혈 경쟁 예고</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">[데일리안 = 최은수 기자] 지난해부터 국내 모바일 게임 시장에 ‘신작’ 가뭄이 이어졌던 가운데 올 6월부터는 출시가 지연됐던 국내 게임사들의 신작들이 줄줄이 쏟아질 예정이다. 특히 각 게임사 대표 지적재산권(IP)</div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link" data-clk="art.phead" href="/mnews/article/119/0002608111">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/119/2022/05/30/2608111.jpg?type=nf336_206&amp;ut=20220530044501"/>
# </div>
# </div>
# <div class="ofhe_headline">지하철 평일 새벽 1시까지 달린다…서울시 '지하철 연장 운행' 노조 합의</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">[데일리안 = 정채영 기자] 사회적 거리두기 해제 후 발생한 교통 대란의 대책인 서울시의 지하철 심야 연장 운행 방침에 노동조합이 합의했다. 이에 따라 평일 열차 운행 시간이 오전 1시까지 연장된다. 서울 지하철을 </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="ofhe_paginate pg">
# <div class="pg_num_area pg_num_area_v2">
# <button class="pg_btn_prev _FLICKING_PREV" type="button"><span class="blind">이전 뉴스들 보기</span></button>
# <div class="_FLICKING_INDICATOR" data-count="3"></div>
# <div class="pg_line"></div>
# <div class="pg_num pg_num">3</div>
# <button class="pg_btn_next _FLICKING_NEXT" type="button"><span class="blind">다음 뉴스들 보기</span></button>
# </div>
# </div>
# <script class="_FLICKING_INDICATOR_TEMPLATE _PC" type="x-tmpl-mustache">
# 	{{#selected}}
# 		<div class="pg_num pg_num_cur">{{number}}</div>
# 	{{/selected}}
# 	</script>
# </div>
# <script>
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 			window.__htExternalUrl["comment"] = "https://ssl.pstatic.net/static.cbox/js/cbox.core.js";
# ...
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item as_badge_in_content _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-recommended-type="GLOBAL" data-score="0.8960606544700037" href="https://contents.premium.naver.com/historia9110/historia91/contents/220527182047298jd">
# <div class="rl_content">
# <p class="rl_txt">
# <mark class="rl_content_tag paid">유료</mark>
# 										중소 규모의 국가의 지도자는 어떻게 탄생하고 무엇을 지향해야 하는가? : 울로프 팔메에 관한 간략한 추천글
# 									</p>
# <div class="rl_author">
# <div class="rl_author_name">혁명 읽는 사람</div>
# </div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMjA1MjdfOTcg/MDAxNjUzNjQzMjAyMzQ1.eVY3y2CejTh3pqjWSAeuw11CeJT5EoDqulqQ6mFYaW8g.XnVVjoD2PTN7iAYKasihbA-3bQQw4r3nAj6NUmaWmdgg.JPEG/%ED%8C%94%EB%A9%94.jpg?type=nf190_130" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item as_badge_in_content _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-recommended-type="GLOBAL" data-score="3.080888799941116" href="https://contents.premium.naver.com/thesem/thesemkorea/contents/220525115114780lk">
# <div class="rl_content">
# <p class="rl_txt">
# <mark class="rl_content_tag paid">유료</mark>
# 										파니와 같이 하루 한 동작!!(+thesem)
# 									</p>
# <div class="rl_author">
# <div class="rl_author_name">THESEM홈트레이닝</div>
# </div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMjA1MjVfMjM0/MDAxNjUzNDQ2NDY4NTM3.sfntScJGtwbxf8IE339eRWMqp301EqTLJwIesd1kW_cg.t0Knx97HgTbPsIYSfuFEj0bRcn6d02hT9sq-7Vm3iz8g.JPEG/post1.jpg?type=nf190_130" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# <div class="flick-panel">
# <ul class="ranking_list _FLICKING_CONTENT">
# <li class="rl_item as_badge_in_content _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-recommended-type="GLOBAL" data-score="3.324041530443596" href="https://contents.premium.naver.com/snowball/moneyneversleep/contents/220525082945462zo">
# <div class="rl_content">
# <p class="rl_txt">
# 										포드, 허위광고 논란 진화 총력
# 									</p>
# <div class="rl_author">
# <div class="rl_author_name">머니네버슬립</div>
# </div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMjA1MjVfNDgg/MDAxNjUzNDM0OTk2NDg5.UYhUkM9mmLndtv-LfDGn5eY7QAlAQZnJKDhGJqqUCK8g.GpZ-2VZih1PjEYNuBNeRv9EGCpyQDOXvasuK6fmrnMIg.JPEG/2._%ED%8F%AC%EB%93%9C_(%EC%B6%9C%EC%B2%98_=_%ED%8F%AC%EB%93%9C_%ED%99%88%ED%8E%98%EC%9D%B4%EC%A7%80).jpg?type=nf190_130" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item as_badge_in_content _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-recommended-type="GLOBAL" data-score="1.1126386188154183" href="https://contents.premium.naver.com/golfguy/golfnrules/contents/220526211626156vz">
# <div class="rl_content">
# <p class="rl_txt">
# <mark class="rl_content_tag paid">유료</mark>
# 										[룰을 알면 스코어가 준다] &lt;37&gt; 플레이어의 정지한 볼을 다른 플레이어·상대방이 움직이면 스트로크플레이에서는 무벌타, 매치플레이에서는 1벌타
# 									</p>
# <div class="rl_author">
# <div class="rl_author_name">골프&amp;룰스 가이</div>
# </div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMjA1MjZfMjQ0/MDAxNjUzNTY3OTQyOTcw.ZellxrRegweMV67aP99_SqC8LHBPRG6mlnLBpTiChFgg.d6rlhqpZIyUKrV1hi9i1TJz7g_f9eFpsdgoHq07dIjEg.JPEG/%EB%AF%B8%EA%B5%AD_NCAA_%EB%94%94%EB%B9%84%EC%A0%841_%EC%97%AC%EC%9E%90%EA%B3%A8%ED%94%84_%EC%B1%94_%EA%B2%B0%EC%8A%B9_2022_5_25_%EC%8A%A4%ED%83%A0%ED%8D%BC%EB%93%9C_%EC%99%BC%EC%AA%BD_%EC%98%A4%EB%A6%AC%EA%B1%B4_%EC%8A%A4%ED%83%A0%ED%8D%BC%EB%93%9C_%EC%9A%B0%EC%8A%B9_%EC%8A%A4%ED%83%A0%ED%8D%BC%EB%93%9C2.jpg?type=nf190_130" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item as_badge_in_content _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-recommended-type="GLOBAL" data-score="1.4875783241043135" href="https://contents.premium.naver.com/chosun/home/contents/220527055513925dq">
# <div class="rl_content">
# <p class="rl_txt">
# <mark class="rl_content_tag paid">유료</mark>
# 										[T]  운전면허시험 「자동(自動)변속 차량」추가
# 									</p>
# <div class="rl_author">
# <div class="rl_author_name">프리미엄 조선</div>
# </div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMjA1MjdfOTIg/MDAxNjUzNTk4MjA1Nzgz.RqKZif1OQwR4rG_-_EF-HvJgfPKbnpLnYm25jsBfOQsg.46oT62HnaS8o7jiLiIN6iXtSFFdCNeZNt1gU-iibkhEg.JPEG/news-cs-22002-19920528-m-1-23-300-b1-bw-thumb-1100.jpg?type=nf190_130" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item as_badge_in_content _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-recommended-type="GLOBAL" data-score="0.9212734989804083" href="https://contents.premium.naver.com/numbers/members/contents/220528235428149pq">
# <div class="rl_content">
# <p class="rl_txt">
# <mark class="rl_content_tag paid">유료</mark>
# 										쏘카는 어떻게 '일상'이 됐나② 롯데렌탈은 기회일까?
# 									</p>
# <div class="rl_author">
# <div class="rl_author_name">넘버스</div>
# </div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMjA1MjdfMjIw/MDAxNjUzNjI4Mzg1Njgy.Su2Rwz7w6SLTqN12DEf-ag8GsNZXNZrGa4o2myBp0qEg.RksHeqXncqE2Iys_cjB5OHAkiC6P8DZnLQDQT89irKgg.JPEG/%EB%B9%84%EC%83%81%EC%9E%A5.jpg?type=nf190_130" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="pg ra_paginate">
# <div class="pg_num_area pg_num_area_v2">
# <button class="pg_btn_prev _FLICKING_PREV" data-clk="arp.bprv" type="button"><span class="blind">이전 콘텐츠들 보기</span></button>
# <div class="_FLICKING_INDICATOR" data-count="3"></div>
# <div class="pg_line"></div>
# <div class="pg_num pg_num">3</div>
# <button class="pg_btn_next _FLICKING_NEXT" data-clk="arp.bnxt" type="button"><span class="blind">다음 콘텐츠들 보기</span></button>
# </div>
# </div>
# <script class="_FLICKING_INDICATOR_TEMPLATE _PC" type="x-tmpl-mustache">
# 			{{#selected}}
# 			<div class="pg_num pg_num_cur">{{number}}</div>
# 			{{/selected}}
# 		</script>
# </div>
# </div>
# </div>
# <div class="outside_area _OUTSIDE_AREA">
# <div class="outside_area_inner _GRID_TEMPLATE_COLUMN_ASIDE _OUTSIDE_AREA_INNER"></div>
# </div>
# <aside class="main_aside _MAIN_ASIDE">
# <div class="main_aside_inner _MAIN_ASIDE_INNER">
# <h3 class="blind">구독</h3>
# <script class="_LAZY_LOADING_IFRAME" type="x-tmpl-mustache">
# 			<iframe class="_aside _GRID_TEMPLATE_ASIDE_IFRAME" src="https://news.naver.com/aside" data-allow-domain="https://news.naver.com" style="visibility: hidden;" frameborder="no" scrolling="no" width="100%"></iframe>
# 			</script>
# </div>
# </aside>
# </div>
# </div>
# <div class="media_end_tts_ticker _FADE_LAYER" id="_media_end_tts_ticker" style="display: none;">
# <p class="media_end_tts_ticker_text" style="display: block;">본문 듣기를 <em class="media_end_tts_ticker_point">종료</em>하였습니다.</p>
# </div>
# <div class="tomain_ticker _TOMAIN_RECOMMAND_LAYER _FADE_LAYER" style="display: none;">이 기사를 <em class="tomain_ticker_point">추천</em>했습니다.
# </div>
# <div class="tomain_ticker _TOMAIN_CANCEL_LAYER _FADE_LAYER" style="display: none;">추천을 <em class="tomain_ticker_point">취소</em>했습니다.
# </div><hr/>
# <div class="u_ft">
# <a class="r_pg_top show _MOVE_TOP" data-clk="fot.top" href="#" id="goTop" style="display:none;">맨위로</a>
# <footer role="contentinfo">
# <p class="u_ftlkw" id="u_ftlkw">
# <a class="u_ftlk _LINK" data-clk="fot.login" data-pc-url="https://nid.naver.com/nidlogin.login" data-url="https://nid.naver.com/nidlogin.login?svctype=262144" href="https://nid.naver.com/nidlogin.login?svctype=262144">로그인</a>
# <a class="u_ftlk _LINK" data-clk="fot.sitemap" data-pc-url="https://www.naver.com/more.html" data-url="https://m.naver.com/services.html?f=svc.news" href="https://m.naver.com/services.html?f=svc.news">전체서비스</a>
# </p>
# <p class="u_cr">
# <span class="u_ftm">
# <span class="u_cri u_cri_v1"><a class="u_cra _LINK" data-pc-url="https://news.naver.com/main/ombudsman/index.naver" data-url="https://m.news.naver.com/ombudsman/index" href="https://m.news.naver.com/ombudsman/index">서비스안내</a></span>
# <span class="u_cri u_cri_v1"><a class="u_cra _LINK" data-clk="fot.help" data-pc-url="https://help.naver.com/support/service/main.help?serviceNo=997&amp;_news_news_1" data-url="https://m.help.naver.com/support/alias/news/news_m1.naver" href="https://m.help.naver.com/support/alias/news/news_m1.naver">뉴스도움말</a></span>
# <span class="u_cri u_cri_v1"><a class="u_cra _LINK" data-clk="fot.report" data-pc-url="https://help.naver.com/support/contents/contents.help?serviceNo=997&amp;categoryNo=8158" data-url="https://m.help.naver.com/support/alias/news/news_001.naver" href="https://m.help.naver.com/support/alias/news/news_001.naver">오류신고</a></span>
# </span>
# <span class="u_copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며, 이를 무단<br/>이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</span>
# <span class="u_cri"><span class="copymark">ⓒ</span> <a class="u_cra_v1" data-clk="fot.navercorp" href="https://www.navercorp.com">NAVER Corp.</a></span>
# <span class="u_cri"><span class="copymark">ⓒ</span> <a class="u_cra_v1">데일리안</a></span>
# </p>
# </footer>
# </div><div class="subscribe_dimmed is_hidden" id="_MY_FEED_CANCEL_MODAL" style="display:none;">
# <div class="subscribe_alert">
# <p class="subscribe_alert_p _message _MY_FFED_CANCEL_MODAL_MESSAGE">
# </p>
# <div class="subscribe_alert_btns">
# <a class="subscribe_alert_btn _CANCEL_YES_BTN _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">예</a>
# <a class="subscribe_alert_btn _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">아니오</a>
# </div>
# </div>
# </div>
# <script class="_MY_FEED_CANCEL_MODAL_TEMPLATE" type="x-tmpl-mustache">
# 			{{#series}}
# 			<span class="subscribe_alert_p_ellipsis">{{value}}</span><br>연재 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc">해당 기사는 <em>구독</em>에서 제외됩니다.</span>
# 			{{/series}}
# 			{{#journalist}}
# 			{{value}} 기자의 기사<br> 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc"><em>구독</em>에서 해당 기자의 기사가 제외됩니다.</span>
# 			{{/journalist}}
# </script>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION"></div>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION_ALL"></div>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification is_single">
# 	<strong class="mn_ok">구독완료</strong>
# 	{{#officeInfos}}
# 	<div class="mn_text">
# 		<h4 class="mn_h">{{officeName}} 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<p class="mn_p">언론사의 주요 콘텐츠를 <br> 네이버에서 빠르게 확인할 수 있습니다.</p>
# 	</div>
# 	{{/officeInfos}}
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE" data-clk="{{nclk}}yes">알림받기</button>
# 	</div>
# </div>
# </script>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_ALL" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification">
# 	<strong class="mn_ok">구독완료</strong>
# 	<div class="mn_text">
# 		<h4 class="mn_h">언론사의 주요 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<ul class="mn_list">
# 			{{#officeInfos}}
# 			<li class="mn_item">
# 				<div class="mn_head">
# 					<div class="mn_img">
# 						<img src="{{logo}}" alt="">
# 					</div>
# 					<div class="mn_name">{{officeName}}</div>
# 				</div>
# 				<div class="mn_body">
# 					<button type="button" class="mn_noti _ALL_OFFICES_NOTIFICATION_ITEM" data-oid="{{officeId}}" data-clk-add="notchnon" data-clk-remove="notchnoff">알림받기 사용함</button>
# 				</div>
# 			</li>
# 			{{/officeInfos}}
# 		</ul>
# 	</div>
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE _CHANNEL_BANNER_ITEM_NOTICE_COMPLETE" data-clk="{{nclk}}yes">완료</button>
# 	</div>
# </div>
# </script>
# <div class="ticker" id="_TICKER_LAYER_FOR_NOTIFICATION" style="display: none;"></div>
# <script class="_TICKER_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# {{#officeInfos}}
# <p class="t_inner"><em class="t_point">{{officeName}}</em> 언론사 알림이 설정되었습니다.</p>
# {{/officeInfos}}
# </script>
# <script src="https://static-nnews.pstatic.net/js/min/20220526/library.min.js"></script>
# <script src="https://static-nnews.pstatic.net/js/min/20220526/read.min.js"></script>
# <script>
# 	if (nil) {
#
# 		var section = {"id":"101","name":"경제"};
# 		var redirectSection = {"id":"101","name":"경제"};
#
# 		nil.init("naver_news", article.officeId);
#
# 		// 기타 또는 주요 섹션 이름
# 		var nilSendSectionName = "기타";
# 		if (/100|101|102|103|104|105|106|107/.test(section.id)) {
# 			nilSendSectionName = section.name;
# 		}
#
# 		// 기사 타입
# 		var htArticleTypeName = { "0": "text", "1": "photo", "2": "tv" };
# 		var articleTypeName = htArticleTypeName[article.type] || "";
#
# 		var nilInfo = {
# 			"uri": "http://news.naver.com/main/read.nhn?oid=119&aid=0002608171",
# 			"dimension_1": encodeURIComponent(nilSendSectionName),
# 			"dimension_4": articleTypeName
# 		};
#
# 		var journalistIdList = [];
#
# 		// 기자 목록
# 		$("._JOURNALIST_CARD ._JOURNALIST_ID").each(function (index, object) {
# 			var $this = $(object);
# 			var journalistId = $this.attr("data-journalistId");
#
# 			if (journalistId && journalistIdList.indexOf(journalistId) === -1) {
# 				journalistIdList.push(journalistId);
# 			}
# 		});
#
# 		if (journalistIdList.length > 0) {
# 			nilInfo["dimension_3"] = journalistIdList.join("___");
# 		}
#
# 		if (location.href.match(/ntype=RANKING/)) {
# 			nilInfo["dimension_5"] = "y";
# 		}
#
# 		if (service.sports) {
# 			nilInfo["dimension_2"] = article.sectionInfo.secondSection + "." + article.sectionInfo.thirdSection;
# 		}
#
# 		nil.add(nilInfo);
#
# 		if (/\/article\/comment\//.test(location.href) == false) {
# 			if (window.addEventListener) {
# 				window.addEventListener("load", function () {
# 					nil.send("cv", "post_view");
# 				}, false);
# 				window.addEventListener("unload", function () {
# 					nil.send("leave");
# 				}, false);
# 			} else if (window.attachEvent) {
# 				window.attachEvent("onload", function () {
# 					nil.send("cv", "post_view");
# 				});
# 				window.attachEvent("onunload", function () {
# 					nil.send("leave");
# 				});
# 			} else {
# 				var fnOnUnload = window.onunload;
# 				window.onunload = function () {
# 					nil.send("leave");
# 					if (fnOnUnload) {
# 						fnOnUnload();
# 					}
# 				};
#
# 				var fnOnload = window.onload;
# 				window.onload = function () {
# 					nil.send("cv", "post_view");
# 					if (fnOnload) {
# 						fnOnload();
# 					}
# 				};
# 			}
# 		}
# 	}
#
# 	if (typeof BMR !== "undefined") {
# 		BMR.run("https://sp.naver.com/sp");
# 	}
# </script>
# </div>
# <script>
# 			var eventType = "onpageshow" in window ? "pageshow" : "load";
# 			$(window).on(eventType, function() {
# 				lcs_do_gdid("8812A0A8_000000000000000002608171");
#
# 				// ma 로그 전송
# 				var data = {
# 					"service": "news",
# 					"baseInfo": {
# 						"category": (/\/article\/comment\//.test(location.href) == true) ? "댓글" : "본문",
# 					},
# 					"extraInfo": {
# 						"articleId": article.articleId,
# 						"sectionId": article.sectionId,
# 						"officeId": article.officeId,
# 						"articleType": article.type
# 					}
# 				};
#
# 				if (typeof ma !== "undefined") {
# 					ma.init({
# 						api: "https://ma.news.naver.com/l",
# 						data: data,
# 						contentBodyEl: document.querySelector("._article_content"),
# 						contentBodyVideoWrapperSelector: "._VIDEO_AREA"
# 					});
# 				}
#
# 				if (window.matchMedia("(prefers-color-scheme)").media === "not all") {
# 					$("html").removeClass("DARK_THEME");
# 				}
# 			});
# 		</script>
# </body>
# </html>

# %%
bs.find("div", id="newsct_article").text.strip()
# Out:
# '그룹사 여신 및 투자 의사결정에 활용\n\n\n\n신한금융그룹 사옥 ⓒ 신한금융그룹[데일리안 = 이호연 기자] 신한금융그룹은 30일 국내 금융그룹 최초로 기업의 ESG 수준 평가를 통해 여신과 투자 등 다양한 의사결정에 활용하기 위한 ‘ESG 평가모형’을 개발했다고 밝혔다.신한금융지주와 신한은행이 공동 개발한 평가모형은 기업의 ESG 투자 수준을 평가하는 ‘신한 ESG 모형’과 해당 투자에 따른 영향과 지속가능 수준을 평가하는 ‘신한 지속가능 모형’ 두 가지로 구분된다.ESG 평가모형은 기업의 전반적인 ESG 수준을 A+~A-(우수), B+~B-(보통), C(미흡) 등 7개 등급으로 평가한다. 데이터 공개 규모가 비교적 큰 IFRS와 외감 기업에 대한 평가를 시작으로, 향후 관련 데이터 누적을 통해 비외감 중소기업까지 평가를 확대하도록 모형을 더욱 정교화 할 계획이다.신한은행은 ESG 평가모형을 통해 산출된 등급을 ‘신한 ESG 우수 상생지원대출’의 대상 선정기준으로 활용할 예정이다. 또한 신한금융그룹은 그룹사들이 ESG 평가 결과를 다양하게 활용할 수 있는 방안을 지속적으로 강구해 나갈 계획이다.신한금융 조용병 회장은 “이번 ESG 평가모형은 기업의 ESG 수준을 데이터에 기반해 정량적으로 평가 가능하다는 데 큰 의의가 있다”며, “ESG 리딩 금융그룹으로서 탄소배출량 넷제로 달성을 목표로 ESG 실천을 더욱 가속화해 나가겠다”고 말했다.한편 신한금융은 지난 3월 국내 금융그룹 최초로 금융자산의 탄소배출량을 효율적으로 관리하기 위한 ‘금융배출량 측정 시스템’을 개발해 체계적인 ESG 리스크 관리를 위한 기반을 마련했다.'

# %%
# 정규식
# [가-힣]  -> 모든 한글 2~4 그리고 공백(0개이상 0 ~ ) 기자 
reporter = re.compile("[가-힣]{2,4}\s*기자")
text = bs.find("div", id="newsct_article").text.strip()
re.sub(reporter, "", text)
# Out:
# '그룹사 여신 및 투자 의사결정에 활용\n\n\n\n신한금융그룹 사옥 ⓒ 신한금융그룹[데일리안 = ] 신한금융그룹은 30일 국내 금융그룹 최초로 기업의 ESG 수준 평가를 통해 여신과 투자 등 다양한 의사결정에 활용하기 위한 ‘ESG 평가모형’을 개발했다고 밝혔다.신한금융지주와 신한은행이 공동 개발한 평가모형은 기업의 ESG 투자 수준을 평가하는 ‘신한 ESG 모형’과 해당 투자에 따른 영향과 지속가능 수준을 평가하는 ‘신한 지속가능 모형’ 두 가지로 구분된다.ESG 평가모형은 기업의 전반적인 ESG 수준을 A+~A-(우수), B+~B-(보통), C(미흡) 등 7개 등급으로 평가한다. 데이터 공개 규모가 비교적 큰 IFRS와 외감 기업에 대한 평가를 시작으로, 향후 관련 데이터 누적을 통해 비외감 중소기업까지 평가를 확대하도록 모형을 더욱 정교화 할 계획이다.신한은행은 ESG 평가모형을 통해 산출된 등급을 ‘신한 ESG 우수 상생지원대출’의 대상 선정기준으로 활용할 예정이다. 또한 신한금융그룹은 그룹사들이 ESG 평가 결과를 다양하게 활용할 수 있는 방안을 지속적으로 강구해 나갈 계획이다.신한금융 조용병 회장은 “이번 ESG 평가모형은 기업의 ESG 수준을 데이터에 기반해 정량적으로 평가 가능하다는 데 큰 의의가 있다”며, “ESG 리딩 금융그룹으로서 탄소배출량 넷제로 달성을 목표로 ESG 실천을 더욱 가속화해 나가겠다”고 말했다.한편 신한금융은 지난 3월 국내 금융그룹 최초로 금융자산의 탄소배출량을 효율적으로 관리하기 위한 ‘금융배출량 측정 시스템’을 개발해 체계적인 ESG 리스크 관리를 위한 기반을 마련했다.'

# %%
# 정규식 테스트
re.sub(reporter, "", "손흥민       기자")
# Out:
# ''

# %%
# 이메일 정규식 
email   = re.compile("[\w._%+-]+@[\w.-]+\.[a-zA-Z]{2,4}")
re.findall(email, "하하하 afas@gmail.com 입니다.")
# Out:
# ['afas@gmail.com']

# %%
# 기자 이름과 이메일 정규식으로 삭제 
re.sub(reporter, "", re.sub(email, "", "오상헌 기자 (bborirang@mt.co.kr)"))
# Out:
# ' ()'

# %% [markdown]
# ######################################

# %%
reporter = re.compile("[가-힣]{2,4}\s*기자")
email   = re.compile("[\w._%+-]+@[\w.-]+\.[a-zA-Z]{2,4}")
reporter2 = re.compile("[가-힣]{2,4}\s*특파원")

text = bs.find("div", id="newsct_article").text.strip()

text = re.sub(email, "", text)
text = re.sub(reporter, "", text)    
text = re.sub(reporter2, "", text)

# %% [markdown]
# ######################################

# %%
'2022-05-23'.replace("-", "")
# Out:
# '20220523'

# %%
[str(x).replace("-", "")[:8] for x in pd.date_range('2022-05-23', '2022-05-30')]
# Out:
# ['20220523',
#  '20220524',
#  '20220525',
#  '20220526',
#  '20220527',
#  '20220528',
#  '20220529',
#  '20220530']

# %%
def article(date_, url):
    reporter = re.compile("[가-힣]{2,4}\s*기자")
    email   = re.compile("[\w._%+-]+@[\w.-]+\.[a-zA-Z]{2,4}")
    r = requests.get(url, headers= head)
    bs = BeautifulSoup(r.text)
    try:
        rt = bs.find("div", id="newsct_article")
        text = rt.text.strip()
    except:
        return  
    
    try:
        text = text[:text.find(rt.select_one("a").text)]
    except:
        pass    
    text = re.sub(email, "", text)
    text = re.sub(reporter, "", text)    
    if not os.path.isdir(date_):
        os.mkdir(date_)
    f = open("./" + date_ + "/" + url.split("?")[0].split("/")[-1] + ".txt", "w", encoding='utf-8')
    f.write(text)
    f.close()

# %%
def naver_news(start_date = None, end_date = None):
    sid2_cate = [259, 258, 261, 771, 260, 310, 263]
    url = "https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid2={}&sid1=101&date={}&page={}"
    head = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36 Edg/86.0.622.38'}
    for date_ in [str(x).replace("-", "")[:8] for x in pd.date_range(start_date, end_date)]:
        for cate in sid2_cate:
            r= requests.get(url.format(cate, date_, 200 ), headers= head)
            bs = BeautifulSoup(r.text, "lxml")
            #print(x , end=' : ')
            last_page = bs.find("div", class_='paging').find("strong").text
            #print ("last page:{}".format(last_page)
            for page_num in range(1, int(last_page)+1):
                r2= requests.get(url.format(cate, date_, page_num ), headers= head)
                bs2 = BeautifulSoup(r2.text, 'lxml')
                for x in bs2.find("div", class_="list_body newsflash_body").findAll("dt"):
                    article(date_, x.a['href'])

# %%
naver_news("2022-05-23", "2022-05-30")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5936/3003559362.py in <module>
# ----> 1 naver_news("2022-05-23", "2022-05-30")
#
# ~\AppData\Local\Temp/ipykernel_5936/2536669345.py in naver_news(start_date, end_date)
#      14                 bs2 = BeautifulSoup(r2.text, 'lxml')
#      15                 for x in bs2.find("div", class_="list_body newsflash_body").findAll("dt"):
# ---> 16                     article(date_, x.a['href'])
#
# ~\AppData\Local\Temp/ipykernel_5936/1396681728.py in article(date_, url)
#       2     reporter = re.compile("[가-힣]{2,4}\s*기자")
#       3     email   = re.compile("[\w._%+-]+@[\w.-]+\.[a-zA-Z]{2,4}")
# ----> 4     r = requests.get(url, headers= head)
#       5     bs = BeautifulSoup(r.text)
#       6     try:
#
# D:\anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# D:\anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# D:\anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# D:\anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     695
#     696         if not stream:
# --> 697             r.content
#     698
#     699         return r
#
# D:\anaconda\lib\site-packages\requests\models.py in content(self)
#     834                 self._content = None
#     835             else:
# --> 836                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     837
#     838         self._content_consumed = True
#
# D:\anaconda\lib\site-packages\requests\models.py in generate()
#     756             if hasattr(self.raw, 'stream'):
#     757                 try:
# --> 758                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     759                         yield chunk
#     760                 except ProtocolError as e:
#
# D:\anaconda\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     570         """
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#     574         else:
#
# D:\anaconda\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     762
#     763             while True:
# --> 764                 self._update_chunk_length()
#     765                 if self.chunk_left == 0:
#     766                     break
#
# D:\anaconda\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     692         if self.chunk_left is not None:
#     693             return
# --> 694         line = self._fp.fp.readline()
#     695         line = line.split(b";", 1)[0]
#     696         try:
#
# D:\anaconda\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# D:\anaconda\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# D:\anaconda\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
