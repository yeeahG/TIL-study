# %% [markdown]
# ## 1번 start
# - 1~12월 데이터를 하나의 DataFrame으로 만들어주세요

# %%
import pandas as pd
import numpy as np
import os

# %%
forders = os.listdir('./data/Subway')
forders[:11]
# Out:
# ['Subway_201601.csv',
#  'Subway_201602.csv',
#  'Subway_201603.csv',
#  'Subway_201604.csv',
#  'Subway_201605.csv',
#  'Subway_201606.csv',
#  'Subway_201607.csv',
#  'Subway_201608.csv',
#  'Subway_201609.csv',
#  'Subway_201610.csv',
#  'Subway_201611.csv']

# %%
# for files in forders: 
#     df= pd.read_csv(files, dtype={'Code':str}, parse_dates=['Date']) 
#     df_all_years = pd.concat([df_all_years, df])

#'./data/Subway/Subway_201601.csv'

# %%
len(pd.read_csv('./data/Subway/Subway_201602.csv', encoding='cp949'))
# Out:
# 50050

# %%
len(pd.read_csv('./data/Subway/Subway_201601.csv', encoding='cp949'))
# Out:
# 52670

# %%
# dfdf = []
# for x in forders[:11]:
#     dd = pd.read_csv('./data/Subway/{}'.format(x), encoding='cp949')
#     dfdf.append(dd)
# df = pd.concat(dfdf)

# %% [markdown]
# ### 콘캣하면 왜 null인가 했더니 컬럼이 다르네?

# %%
dd1 = pd.read_csv('./data/Subway/Subway_201601.csv', encoding='cp949')
dd2 = pd.read_csv('./data/Subway/Subway_201602.csv', encoding='cp949')
dd3 = pd.read_csv('./data/Subway/Subway_201603.csv', encoding='cp949')
dd4 = pd.read_csv('./data/Subway/Subway_201604.csv', encoding='cp949')
dd5 = pd.read_csv('./data/Subway/Subway_201605.csv', encoding='cp949')
dd6 = pd.read_csv('./data/Subway/Subway_201606.csv', encoding='cp949')
dd7 = pd.read_csv('./data/Subway/Subway_201607.csv', encoding='cp949')
dd8 = pd.read_csv('./data/Subway/Subway_201608.csv', encoding='cp949')
dd9 = pd.read_csv('./data/Subway/Subway_201609.csv', encoding='cp949')
dd10 = pd.read_csv('./data/Subway/Subway_201610.csv', encoding='cp949')
dd11 = pd.read_csv('./data/Subway/Subway_201611.csv', encoding='cp949')
dd12 = pd.read_csv('./data/Subway/Subway_201612.csv', encoding='cp949')

# %%
dd1.columns
# Out:
# Index(['날짜', '호선', '역명', '구 분', '할인', '04 ~ 05', '05 ~ 06', '06 ~ 07',
#        '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13',
#        '13 ~ 14', '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19',
#        '19 ~ 20', '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '00 ~ 01',
#        '01 ~ 02', '02 ~ 03', '03 ~ 04'],
#       dtype='object')

# %%
dd2.columns
# Out:
# Index(['날짜', '호선', '역명', '구 분', '할인', '04 ~ 05', '05 ~ 06', '06 ~ 07',
#        '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13',
#        '13 ~ 14', '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19',
#        '19 ~ 20', '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '00 ~ 01',
#        '01 ~ 02', '02 ~ 03', '03 ~ 04'],
#       dtype='object')

# %%
dd3.columns
# Out:
# Index(['날짜', '호선', '역명', '구 분', '할인', '04 ~ 05', '05 ~ 06', '06 ~ 07',
#        '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13',
#        '13 ~ 14', '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19',
#        '19 ~ 20', '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '00 ~ 01',
#        '01 ~ 02', '02 ~ 03', '03 ~ 04'],
#       dtype='object')

# %%
dd4.columns
# Out:
# Index(['날짜', '호선', '역명', '구 분', '할인', '04 ~ 05', '05 ~ 06', '06 ~ 07',
#        '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13',
#        '13 ~ 14', '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19',
#        '19 ~ 20', '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '00 ~ 01',
#        '01 ~ 02', '02 ~ 03', '03 ~ 04'],
#       dtype='object')

# %%
dd5.columns
# Out:
# Index(['날짜', '호선', '역명', '구 분', '할인', '04 ~ 05', '05 ~ 06', '06 ~ 07',
#        '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13',
#        '13 ~ 14', '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19',
#        '19 ~ 20', '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '00 ~ 01',
#        '01 ~ 02', '02 ~ 03', '03 ~ 04'],
#       dtype='object')

# %%
dd6.columns
# Out:
# Index(['역명', '날짜', '구분', '05~06', '06~07', '07~08', '08~09', '09~10', '10~11',
#        '11~12', '12~13', '13~14', '14~15', '15~16', '16~17', '17~18', '18~19',
#        '19~20', '20~21', '21~22', '22~23', '23~24', '00~01', '01~02'],
#       dtype='object')

# %%
dd7.columns
# Out:
# Index(['역명', '날짜', '구분', '05~06', '06~07', '07~08', '08~09', '09~10', '10~11',
#        '11~12', '12~13', '13~14', '14~15', '15~16', '16~17', '17~18', '18~19',
#        '19~20', '20~21', '21~22', '22~23', '23~24', '00~01', '01~02'],
#       dtype='object')

# %%
dd8.columns
# Out:
# Index(['역명', '날짜', '구분', '05~06', '06~07', '07~08', '08~09', '09~10', '10~11',
#        '11~12', '12~13', '13~14', '14~15', '15~16', '16~17', '17~18', '18~19',
#        '19~20', '20~21', '21~22', '22~23', '23~24', '00~01', '01~02'],
#       dtype='object')

# %%
dd9.columns
# Out:
# Index(['역명', '날짜', '구분', '05~06', '06~07', '07~08', '08~09', '09~10', '10~11',
#        '11~12', '12~13', '13~14', '14~15', '15~16', '16~17', '17~18', '18~19',
#        '19~20', '20~21', '21~22', '22~23', '23~24', '00~01', '01~02'],
#       dtype='object')

# %%
dd10.columns
# Out:
# Index(['역명', '날짜', '구분', '05~06', '06~07', '07~08', '08~09', '09~10', '10~11',
#        '11~12', '12~13', '13~14', '14~15', '15~16', '16~17', '17~18', '18~19',
#        '19~20', '20~21', '21~22', '22~23', '23~24', '00~01', '01~02'],
#       dtype='object')

# %%
dd11.columns
# Out:
# Index(['역명', '날짜', '구분', '05~06', '06~07', '07~08', '08~09', '09~10', '10~11',
#        '11~12', '12~13', '13~14', '14~15', '15~16', '16~17', '17~18', '18~19',
#        '19~20', '20~21', '21~22', '22~23', '23~24', '00~01', '01~02'],
#       dtype='object')

# %%
dd12.columns
# Out:
# Index(['역명', '날짜', '구분', '05~06시', '06~07시', '07~08시', '08~09시', '09~10시',
#        '10~11시', '11~12시', '12~13시', '13~14시', '14~15시', '15~16시', '16~17시',
#        '17~18시', '18~19시', '19~20시', '20~21시', '21~22시', '22~23시', '23~24시',
#        '00~01시', '01~02시'],
#       dtype='object')

# %%
len(dd12) + len(dd11) + len(dd10) + len(dd9) +len(dd8) + len(dd7) + len(dd6) + len(dd5) + len(dd4) + len(dd3) + len(dd2) + len(dd1)
# Out:
# 312366

# %%
dd5.drop(['호선', '할인', '04 ~ 05', '02 ~ 03', '03 ~ 04'], axis=1)

# %%
list54 = [dd1, dd2, dd3, dd4, dd5]

# %%
list544 = []
for x in list54:
    x = x.drop(['호선', '할인', '04 ~ 05', '02 ~ 03', '03 ~ 04'], axis=1)
    x = x[['역명', '날짜', '구 분', '05 ~ 06', '06 ~ 07', '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13', '13 ~ 14', '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19', '19 ~ 20', '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '00 ~ 01', '01 ~ 02']]
    x.columns = ['역명', '날짜', '구분', '05~06', '06~07', '07~08', '08~09', '09~10', '10~11', '11~12', '12~13', '13~14', '14~15', '15~16', '16~17', '17~18', '18~19', '19~20', '20~21', '21~22', '22~23', '23~24', '00~01', '01~02']
    list544.append(x)

# %%
df_12345 = pd.concat(list544)

# %%
df_12345
# Out:
#              역명          날짜  구분  05~06  06~07  07~08  08~09  09~10  10~11  \
# 0      서울역(150)  2016-01-01  승차    298    243    490    909   1347   1618
# 1      서울역(150)  2016-01-01  승차      4      0      4     18     60     57
# 2      서울역(150)  2016-01-01  승차     33     15     16     54     89     94
# 3      서울역(150)  2016-01-01  승차      0      0      0      0      0      0
# 4      서울역(150)  2016-01-01  승차     70     78     65    151    207    277
# ...         ...         ...  ..    ...    ...    ...    ...    ...    ...
# 52981  남태령(434)  2016-05-31  승차      9     11     10     24     40     21
# 52982  남태령(434)  2016-05-31  하차      0     78    106    165     47     16
# 52983  남태령(434)  2016-05-31  하차      0      0     14      0      0      0
# 52984  남태령(434)  2016-05-31  하차      0      1    149     42      1      2
# 52985  남태령(434)  2016-05-31  하차      1     13     21     11     13     20
#
#        11~12  ...  16~17  17~18  18~19  19~20  20~21  21~22  22~23  23~24  \
# ...

# %%
df_67891011 = pd.concat([dd6, dd7, dd8, dd9, dd10, dd11])

# %%
df_67891011
# Out:
#             역명          날짜  구분  05~06  06~07  07~08  08~09  09~10  10~11  \
# 0     서울역(150)  2016-06-01  승차    521    538   2111   3391   2454   2385
# 1     서울역(150)  2016-06-01  하차    355   1884   5611  11273   4688   2964
# 2     서울역(150)  2016-06-02  승차    535    548   1946   3446   2636   2481
# 3     서울역(150)  2016-06-02  하차    350   1823   5278  11206   4891   3102
# 4     서울역(150)  2016-06-03  승차    480    529   1879   3418   2620   2469
# ...        ...         ...  ..    ...    ...    ...    ...    ...    ...
# 7135  남태령(434)  2016-11-28  하차      0     54    202    240     55     42
# 7136  남태령(434)  2016-11-29  승차     20     32    173    204    141     76
# 7137  남태령(434)  2016-11-29  하차      2     47    202    235     81     59
# 7138  남태령(434)  2016-11-30  승차     24     31    178    212    129     70
# 7139  남태령(434)  2016-11-30  하차      1     56    179    255     61     56
#
#       11~12  ...  16~17  17~18  18~19  19~20  20~21  21~22  22~23  23~24  \
# ...

# %%
dd12.columns = ['역명', '날짜', '구분', '05~06', '06~07', '07~08', '08~09', '09~10', '10~11', '11~12', '12~13', '13~14', '14~15', '15~16', '16~17', '17~18', '18~19', '19~20', '20~21', '21~22', '22~23', '23~24', '00~01', '01~02']

# %%
df_112 = pd.concat([df_12345, df_67891011, dd12])

# %% [markdown]
# ## 1번답
# - 데이터마다 컬럼이 다르다
# - 뭔가를 모르는것같다.. 노가다성

# %%
df_112
# Out:
#             역명          날짜  구분  05~06  06~07  07~08  08~09  09~10  10~11  \
# 0     서울역(150)  2016-01-01  승차    298    243    490    909   1347   1618
# 1     서울역(150)  2016-01-01  승차      4      0      4     18     60     57
# 2     서울역(150)  2016-01-01  승차     33     15     16     54     89     94
# 3     서울역(150)  2016-01-01  승차      0      0      0      0      0      0
# 4     서울역(150)  2016-01-01  승차     70     78     65    151    207    277
# ...        ...         ...  ..    ...    ...    ...    ...    ...    ...
# 7373  남태령(434)  2016-12-29  하차      2     26    189    238     68     64
# 7374  남태령(434)  2016-12-30  승차     18     23    125    165    111     80
# 7375  남태령(434)  2016-12-30  하차      4     39     75    154     61     30
# 7376  남태령(434)  2016-12-31  승차     16     22     19     93     81     71
# 7377  남태령(434)  2016-12-31  하차      0     17     23     40     26     55
#
#       11~12  ...  16~17  17~18  18~19  19~20  20~21  21~22  22~23  23~24  \
# ...

# %% [markdown]
# ## 2번 start
# - 같은 역이지만 다른 이름을 가진역들이 있는데 역명에서 숫자를 제외한 역의 이름만 추출하여
# - 역명 컬럼에 저장하고 중복되는 역명은 하나의 역명으로 합쳐주세요

# %%
str(df_112['역명'])[8:].split('       ')
# Out:
# ['서울역\n1',
#  '서울역\n2',
#  '서울역\n3',
#  '서울역\n4',
#  '서울역\n',
#  '... \n7373    남태령\n7374    남태령\n7375    남태령\n7376    남태령\n7377    남태령\nName: 역명, Length: 312366, dtype: object']

# %%
'서울역(150)\n1'.split('(')[0]
# Out:
# '서울역'

# %%
df_112['역명'] = df_112['역명'].apply(lambda x : str(x).split('(')[0])

# %%
df_112['역명']
# Out:
# 0       서울역
# 1       서울역
# 2       서울역
# 3       서울역
# 4       서울역
#        ...
# 7373    남태령
# 7374    남태령
# 7375    남태령
# 7376    남태령
# 7377    남태령
# Name: 역명, Length: 312366, dtype: object

# %%
df_112
# Out:
#        역명          날짜  구분  05~06  06~07  07~08  08~09  09~10  10~11  11~12  \
# 0     서울역  2016-01-01  승차    298    243    490    909   1347   1618   2399
# 1     서울역  2016-01-01  승차      4      0      4     18     60     57     86
# 2     서울역  2016-01-01  승차     33     15     16     54     89     94    136
# 3     서울역  2016-01-01  승차      0      0      0      0      0      0      0
# 4     서울역  2016-01-01  승차     70     78     65    151    207    277    308
# ...   ...         ...  ..    ...    ...    ...    ...    ...    ...    ...
# 7373  남태령  2016-12-29  하차      2     26    189    238     68     64     30
# 7374  남태령  2016-12-30  승차     18     23    125    165    111     80     61
# 7375  남태령  2016-12-30  하차      4     39     75    154     61     30     20
# 7376  남태령  2016-12-31  승차     16     22     19     93     81     71     60
# 7377  남태령  2016-12-31  하차      0     17     23     40     26     55     57
#
# ...

# %%
df_station_sum = pd.DataFrame(df_112.groupby('역명').sum().sum(axis=1))

# %%
df_station_sum = df_station_sum.reset_index()

# %%
df_station_sum = df_station_sum.rename(columns = {0 : 'counts'})

# %%
df_station_sum = df_station_sum.sort_values(by=['counts'], ascending=False)

# %%
df_station_sum = df_station_sum.reset_index(drop=True)

# %%
df_112
# Out:
#        역명          날짜  구분  05~06  06~07  07~08  08~09  09~10  10~11  11~12  \
# 0     서울역  2016-01-01  승차    298    243    490    909   1347   1618   2399
# 1     서울역  2016-01-01  승차      4      0      4     18     60     57     86
# 2     서울역  2016-01-01  승차     33     15     16     54     89     94    136
# 3     서울역  2016-01-01  승차      0      0      0      0      0      0      0
# 4     서울역  2016-01-01  승차     70     78     65    151    207    277    308
# ...   ...         ...  ..    ...    ...    ...    ...    ...    ...    ...
# 7373  남태령  2016-12-29  하차      2     26    189    238     68     64     30
# 7374  남태령  2016-12-30  승차     18     23    125    165    111     80     61
# 7375  남태령  2016-12-30  하차      4     39     75    154     61     30     20
# 7376  남태령  2016-12-31  승차     16     22     19     93     81     71     60
# 7377  남태령  2016-12-31  하차      0     17     23     40     26     55     57
#
# ...

# %% [markdown]
# ## 2번 답
# - 흠...
# - 같은 역이지만 다른 이름을 가진역들이 있는데 역명에서 숫자를 제외한 역의 이름만 추출하여
# - 역명 컬럼에 저장하고 중복되는 역명은 하나의 역명으로 합쳐주세요

# %%
df_station_sum
# Out:
#        역명    counts
# 0      강남  72989920
# 1      잠실  59959378
# 2    홍대입구  57959028
# 3     서울역  55481511
# 4      사당  54818151
# ..    ...       ...
# 105    용두   1706585
# 106    신답   1049878
# 107    지축    995325
# 108   남태령    990047
# 109   도림천    804083
#
# [110 rows x 2 columns]

# %% [markdown]
# ## 3번 start
# - 강남역 데이터만 추출하여 월별 시간대별 승하철 합계 값, 월별 총 합계 값

# %%
df_112.groupby(['역명', '날짜']).sum()
# Out:
#                  05~06  06~07  07~08  08~09  09~10  10~11  11~12  12~13  \
# 역명   날짜
# 가락시장 2016-01-01     78    183    143    261    286    316    393    424
#      2016-01-02     56    147    196    469    565    529    773    747
#      2016-01-03     52    140    143    282    396    476    484    520
#      2016-01-04    130    578   1422   2037   1104    846    864    890
#      2016-01-05    126    483   1287   2167   1146    896    942    947
# ...                ...    ...    ...    ...    ...    ...    ...    ...
# 회현   2016-12-27    122   1360   2837   7440   4933   3610   4454   4281
#      2016-12-28    121   1299   2801   7301   4917   3571   4131   3660
#      2016-12-29    161   1295   2901   7113   4769   3715   4237   3966
#      2016-12-30    118   1235   2699   6633   4608   3390   4231   4141
#      2016-12-31     97    545    850   1945   2985   2871   4080   4427
#
#                  13~14  14~15  ...  16~17  17~18  18~19  19~20  20~21  21~22  \
# ...

# %%
df_gangnam = df_112.groupby(['역명', '날짜']).sum().loc['강남', :]

# %%
df_gangnam # 강사님이랑 상당히 다른데 어디서 틀렸지? 했는데 내껀 일자별 이었다. 월별로 바꿔보자
# Out:
#             05~06  06~07  07~08  08~09  09~10  10~11  11~12  12~13  13~14  \
# 날짜
# 2016-01-01   1555   1890   1436   1878   2683   2673   2884   3884   4411
# 2016-01-02    766   1527   1783   3587   6237   5884   6189   8193   9847
# 2016-01-03    856   1312   1330   2115   3799   3516   4348   5651   6937
# 2016-01-04    885   4273  12523  20800  20241  10483  10385  11224  14240
# 2016-01-05    969   4216  11448  20865  20613  10652  10611  11372  14673
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2016-12-27    962   3050   8610  18328  15188   9109   9133   9218  11826
# 2016-12-28   1007   2935   8703  17631  14795   9055   8579   9072  11618
# 2016-12-29   1075   2845   7960  17342  14689   8647   9000   8915  11731
# 2016-12-30   1092   2740   6862  16132  12714   8616   8623   9594  12087
# 2016-12-31   1435   2028   1977   3686   6679   6147   7109   8930  10147
#
#             14~15  ...  16~17  17~18  18~19  19~20  20~21  21~22  22~23  \
# ...

# %%
df_gangnam.index[0][:7]
# Out:
# '2016-01'

# %%
df_gangnam.index[365][:7]
# Out:
# '2016-12'

# %%
df_gangnam.reset_index(inplace=True)

# %%
df_gangnam['날짜'] = df_gangnam['날짜'].apply(lambda x : x[:7])

# %%
df_gangnam
# Out:
#           날짜  05~06  06~07  07~08  08~09  09~10  10~11  11~12  12~13  13~14  \
# 0    2016-01   1555   1890   1436   1878   2683   2673   2884   3884   4411
# 1    2016-01    766   1527   1783   3587   6237   5884   6189   8193   9847
# 2    2016-01    856   1312   1330   2115   3799   3516   4348   5651   6937
# 3    2016-01    885   4273  12523  20800  20241  10483  10385  11224  14240
# 4    2016-01    969   4216  11448  20865  20613  10652  10611  11372  14673
# ..       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 361  2016-12    962   3050   8610  18328  15188   9109   9133   9218  11826
# 362  2016-12   1007   2935   8703  17631  14795   9055   8579   9072  11618
# 363  2016-12   1075   2845   7960  17342  14689   8647   9000   8915  11731
# 364  2016-12   1092   2740   6862  16132  12714   8616   8623   9594  12087
# 365  2016-12   1435   2028   1977   3686   6679   6147   7109   8930  10147
#
# ...

# %% [markdown]
# ## 3번 답

# %%
df_gangnam_sum = df_gangnam.groupby('날짜').sum()
df_gangnam_sum
# Out:
#          05~06   06~07   07~08   08~09   09~10   10~11   11~12   12~13  \
# 날짜
# 2016-01  30688   96142  248023  452633  452117  272407  280048  309447
# 2016-02  26341   81838  215295  388182  382820  233906  238445  267631
# 2016-03  29912   96401  272901  472917  428080  257963  245185  263924
# 2016-04  29277   91237  237741  432805  401148  245302  230894  253786
# 2016-05  31472   94893  236848  439614  395280  242650  234098  254314
# 2016-06  30463   95618  238381  437429  400581  238476  232159  250864
# 2016-07  31150  103760  245736  460381  471990  281334  287233  320706
# 2016-08  29540   95131  236381  444226  428565  262546  264286  289856
# 2016-09  26719   82176  212991  390194  363317  220007  212504  234621
# 2016-10  29379   88972  220838  412845  396363  240666  232135  255853
# 2016-11  27995   87867  222572  434453  407457  237819  225710  246627
# 2016-12  31910   86947  209911  431968  402138  249033  251604  273746
#
# ...

# %%
df_gangnam_sumsum = pd.DataFrame(df_gangnam_sum.sum(axis=1))

# %%
df_gangnam_sumsum.columns = ['승하차 인원']

# %%
df_gangnam_sumsum.reset_index(inplace=True)

# %%
df_gangnam_sumsum
# Out:
#          날짜   승하차 인원
# 0   2016-01  6565737
# 1   2016-02  5755230
# 2   2016-03  6308157
# 3   2016-04  5856535
# 4   2016-05  5919827
# 5   2016-06  5826363
# 6   2016-07  6788786
# 7   2016-08  6355968
# 8   2016-09  5460894
# 9   2016-10  5851270
# 10  2016-11  5929904
# 11  2016-12  6371249

# %% [markdown]
# ## 4번 답

# %%
df_gangnam_sumsum.plot.bar(x = '날짜', y = '승하차 인원', rot=0, figsize=(12, 5))
plt.title("2016년 강남역 승하차 인원", fontdict = {'fontsize' : 15})
plt.ylim(0, 8000000)

plt.show()

# %% [markdown]
# ## 5번

# %%
df_112.groupby('구분',).sum()
# Out:
#        05~06     06~07     07~08      08~09     09~10     10~11     11~12  \
# 구분
# 승차  12434691  24059333  63231816   78720489  54181938  42698072  45113431
# 하차   3217892  21237746  52117982  121746699  85306991  55562884  52547201
#
#        12~13     13~14     14~15  ...     17~18      18~19     19~20  \
# 구분                                ...
# 승차  49823144  55104520  55681899  ...  82791933  118863261  78276178
# 하차  53355748  58325800  56853685  ...  69376427   91246863  83025558
#
#        20~21     21~22     22~23     23~24    00~01   01~02  총승하차
# 구분
# 승차  60183458  60299807  52517528  24388093  3470173   28636   0.0
# 하차  51165241  45425242  44213364  29225997  9477513  488775   0.0
#
# [2 rows x 22 columns]

# %%
df_rkdska_tmdgk = df_112.groupby(['날짜', '구분']).sum()
df_rkdska_tmdgk
# Out:
#                05~06  06~07   07~08   08~09   09~10   10~11   11~12   12~13  \
# 날짜         구분
# 2016-01-01 승차  28617  32692   30954   44507   57583   64281   74574   85880
#            하차   6185  34994   30832   43729   60920   66260   79110   93096
# 2016-01-02 승차  20371  28764   41667   73300   90859   93279  111225  129261
#            하차   5397  30920   38210   73843  107786  106094  124997  146543
# 2016-01-03 승차  19451  24618   29967   56083   81026   83215   87706  105968
# ...              ...    ...     ...     ...     ...     ...     ...     ...
# 2016-12-29 하차   8961  57028  155056  413012  269458  159874  153041  149636
# 2016-12-30 승차  32134  61683  177567  233462  148073  119158  130055  147186
#            하차   8852  53434  135739  376123  242055  151718  150788  156896
# 2016-12-31 승차  27726  35379   47899   81360   97731  101778  122787  142363
#            하차   6794  38114   45011   85243  120021  115148  136878  160151
#
# ...

# %%
df_rkdska_tmdgk.reset_index(inplace=True)

# %%
df_rkdska_tmdgk['날짜'] = df_rkdska_tmdgk['날짜'].apply(lambda x : x[:7])

# %%
df_rkdska_tmdgk
# Out:
#           날짜  구분  05~06  06~07   07~08   08~09   09~10   10~11   11~12  \
# 0    2016-01  승차  28617  32692   30954   44507   57583   64281   74574
# 1    2016-01  하차   6185  34994   30832   43729   60920   66260   79110
# 2    2016-01  승차  20371  28764   41667   73300   90859   93279  111225
# 3    2016-01  하차   5397  30920   38210   73843  107786  106094  124997
# 4    2016-01  승차  19451  24618   29967   56083   81026   83215   87706
# ..       ...  ..    ...    ...     ...     ...     ...     ...     ...
# 727  2016-12  하차   8961  57028  155056  413012  269458  159874  153041
# 728  2016-12  승차  32134  61683  177567  233462  148073  119158  130055
# 729  2016-12  하차   8852  53434  135739  376123  242055  151718  150788
# 730  2016-12  승차  27726  35379   47899   81360   97731  101778  122787
# 731  2016-12  하차   6794  38114   45011   85243  120021  115148  136878
#
#       12~13  ...   17~18   18~19   19~20   20~21   21~22   22~23  23~24  \
# ...

# %%
df_rkdska_tmdgk_sum = df_rkdska_tmdgk.groupby(['날짜', '구분']).sum()

# %%
df_rkdska_tmdgk_sum_sort = df_rkdska_tmdgk_sum.reset_index().sort_values('구분').reset_index(drop=True)

# %%
df_rkdska_tmdgk_sum_sort
# Out:
#          날짜  구분    05~06    06~07    07~08     08~09    09~10    10~11  \
# 0   2016-01  승차   921892  1801289  4681145   6268603  4301139  3368955
# 1   2016-02  승차   820378  1634402  4295036   5625873  3908171  3141370
# 2   2016-11  승차  1055082  1978145  5495568   6963326  4683802  3562796
# 3   2016-03  승차  1026325  2151774  5978299   7233243  4879778  3733446
# 4   2016-04  승차  1041694  2138350  5559722   6759889  4724013  3698887
# 5   2016-10  승차  1112654  2051118  5387013   6680480  4679764  3731554
# 6   2016-05  승차  1126460  2199910  5595680   6836646  4807070  3785608
# 7   2016-06  승차  1141920  2162070  5571923   6652489  4533140  3580779
# 8   2016-12  승차  1020013  1892622  5133368   6741421  4599105  3681238
# 9   2016-07  승차  1101671  2086949  5307904   6500509  4475624  3567140
# 10  2016-09  승차   994876  1909233  5055881   6140420  4235883  3360524
# 11  2016-08  승차  1071726  2053471  5170277   6317590  4354449  3485775
# ...

# %%
df_rkdska_tmdgk_sum_sort_gkck.set_index('날짜')
# Out:
#          구분   05~06    06~07    07~08     08~09    09~10    10~11    11~12  \
# 날짜
# 2016-11  하차  269017  1739933  4387323  10632140  7572443  4747083  4335758
# 2016-10  하차  278402  1856052  4401468  10125591  7351686  4885767  4546922
# 2016-09  하차  253251  1665840  4167132   9505164  6605348  4386846  4102985
# 2016-06  하차  295608  1920735  4713190  10448830  7112887  4614857  4371348
# 2016-07  하차  283237  1854584  4470983  10201196  7122466  4600497  4404716
# 2016-05  하차  286759  1953905  4711738  10514540  7398711  4955636  4586723
# 2016-04  하차  270578  1867616  4666986  10422972  7287180  4813886  4461333
# 2016-03  하차  273494  1841429  4883347  11291501  7670839  4951144  4575832
# 2016-02  하차  222665  1450132  3474931   8695689  6135017  4023849  3951954
# 2016-01  하차  247772  1614732  3781281   9630344  6820308  4344980  4250700
# 2016-08  하차  272846  1809513  4361463   9919938  6839552  4460354  4272727
# ...

# %%
df_rkdska_tmdgk_sum_sort_tmdck = df_rkdska_tmdgk_sum_sort[df_rkdska_tmdgk_sum_sort.loc[:, '구분'] == '승차']
df_rkdska_tmdgk_sum_sort_gkck = df_rkdska_tmdgk_sum_sort[df_rkdska_tmdgk_sum_sort.loc[:, '구분'] == '하차']

# %%
df_rkdska_tmdgk_sum_sort_tmdck1 = pd.DataFrame(df_rkdska_tmdgk_sum_sort_tmdck.set_index('날짜').sum(axis=1))
# Out:
# C:\Users\82103\AppData\Local\Temp/ipykernel_19604/1222538879.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_rkdska_tmdgk_sum_sort_tmdck1 = pd.DataFrame(df_rkdska_tmdgk_sum_sort_tmdck.set_index('날짜').sum(axis=1))

# %%
df_rkdska_tmdgk_sum_sort_tmdck1.columns=['총승차']

# %%
df_rkdska_tmdgk_sum_sort_tmdck1 = df_rkdska_tmdgk_sum_sort_tmdck1.sort_values(by=['날짜'])

# %%
df_rkdska_tmdgk_sum_sort_tmdck1
# Out:
#                 총승차
# 날짜
# 2016-01  87511442.0
# 2016-02  80745171.0
# 2016-03  97058193.0
# 2016-04  92782247.0
# 2016-05  95037927.0
# 2016-06  90929991.0
# 2016-07  91055687.0
# 2016-08  88493154.0
# 2016-09  85299108.0
# 2016-10  93154937.0
# 2016-11  93920254.0
# 2016-12  96432378.0

# %%
df_rkdska_tmdgk_sum_sort_tmdck1['총승차']
# Out:
# 날짜
# 2016-01    87511442.0
# 2016-02    80745171.0
# 2016-11    93920254.0
# 2016-03    97058193.0
# 2016-04    92782247.0
# 2016-10    93154937.0
# 2016-05    95037927.0
# 2016-06    90929991.0
# 2016-12    96432378.0
# 2016-07    91055687.0
# 2016-09    85299108.0
# 2016-08    88493154.0
# Name: 총승차, dtype: float64

# %%
df_rkdska_tmdgk_sum_sort_gkck1 = pd.DataFrame(df_rkdska_tmdgk_sum_sort_gkck.set_index('날짜').sum(axis=1))
# Out:
# C:\Users\82103\AppData\Local\Temp/ipykernel_19604/1073577273.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_rkdska_tmdgk_sum_sort_gkck1 = pd.DataFrame(df_rkdska_tmdgk_sum_sort_gkck.set_index('날짜').sum(axis=1))

# %%
df_rkdska_tmdgk_sum_sort_gkck1.columns=['총하차']

# %%
df_rkdska_tmdgk_sum_sort_gkck1 = df_rkdska_tmdgk_sum_sort_gkck1.sort_values(by=['날짜'])

# %%
df_rkdska_tmdgk_sum_sort_gkck1
# Out:
#                 총하차
# 날짜
# 2016-01  88104993.0
# 2016-02  81298378.0
# 2016-03  97775171.0
# 2016-04  93606005.0
# 2016-05  95943379.0
# 2016-06  91741812.0
# 2016-07  91731773.0
# 2016-08  89111219.0
# 2016-09  86112083.0
# 2016-10  94008955.0
# 2016-11  94629364.0
# 2016-12  97156962.0

# %%
df_rkdska_tmdgk_sum_sort_gkck1.index
# Out:
# Index(['2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06',
#        '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12'],
#       dtype='object', name='날짜')

# %%
df_rkdska_tmdgk_sum_sort_tmdck2 = df_rkdska_tmdgk_sum_sort_tmdck1.reset_index()

# %%
df_rkdska_tmdgk_sum_sort_tmdck2
# Out:
#          날짜         총승차
# 0   2016-01  87511442.0
# 1   2016-02  80745171.0
# 2   2016-03  97058193.0
# 3   2016-04  92782247.0
# 4   2016-05  95037927.0
# 5   2016-06  90929991.0
# 6   2016-07  91055687.0
# 7   2016-08  88493154.0
# 8   2016-09  85299108.0
# 9   2016-10  93154937.0
# 10  2016-11  93920254.0
# 11  2016-12  96432378.0

# %%
df_rkdska_tmdgk_sum_sort_gkck2 = df_rkdska_tmdgk_sum_sort_gkck1.reset_index()

# %%
df_rkdska_tmdgk_sum_sort_gkck2
# Out:
#          날짜         총하차
# 0   2016-01  88104993.0
# 1   2016-02  81298378.0
# 2   2016-03  97775171.0
# 3   2016-04  93606005.0
# 4   2016-05  95943379.0
# 5   2016-06  91741812.0
# 6   2016-07  91731773.0
# 7   2016-08  89111219.0
# 8   2016-09  86112083.0
# 9   2016-10  94008955.0
# 10  2016-11  94629364.0
# 11  2016-12  97156962.0

# %%
df_rkdska_tmdgk_sum_sort_gkck2.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
df_rkdska_tmdgk_sum_sort_tmdck2['날짜']
# Out:
# pandas.core.series.Series

# %%
# fig = plt.figure(figsize=(20,5))
#ax = fig.add_subplot(1,1,1)

# ax.bar(df_rkdska_tmdgk_sum_sort_gkck1.index, df_rkdska_tmdgk_sum_sort_tmdck1['총승차'], width=0.5, color="#F4EC00")
# ax.bar(df_rkdska_tmdgk_sum_sort_gkck1.index, df_rkdska_tmdgk_sum_sort_gkck1['총하차'], width=0.2, color="#000000")



df_rkdska_tmdgk_sum_sort_tmdck2.plot.bar(x='날짜', y='총승차', rot=0, figsize=(12, 5))
df_rkdska_tmdgk_sum_sort_gkck2.plot.bar(x='날짜', y='총하차', rot=0, figsize=(12, 5))

# df_tmdgkck_ri.plot.barh(x='역명', y='총 승하차', rot=0, figsize=(12, 5))
# plt.show()


plt.show()

# %% [markdown]
# ## 5번 답

# %%
fig = plt.figure(figsize=(20,5))
ax = fig.add_subplot(1,1,1)

ax.bar(df_rkdska_tmdgk_sum_sort_tmdck1.index, df_rkdska_tmdgk_sum_sort_tmdck2['총승차'], width=0.2, color="green", label='총 승차')
ax.bar(df_rkdska_tmdgk_sum_sort_gkck2.index+0.2, df_rkdska_tmdgk_sum_sort_gkck2['총하차'], width=0.2, color="darkgray", label='총 하차')
ax.set_ylim(0, 120000000)
ax.legend(loc='best')

plt.show()

# %% [markdown]
# ## 6번 start
# - 가상 승차가 역이 많은 ..? 상위 15개

# %%
df_tmdgk = df_112.groupby(['구분', '역명']).sum().reset_index()
df_tmdgk
# Out:
#      구분    역명   05~06   06~07    07~08    08~09    09~10    10~11    11~12  \
# 0    승차  가락시장   34321   97951   272824   318920   230877   189330   190703
# 1    승차    강남  199341  320873   618839   960305   827104   821935  1096183
# 2    승차    강변  131474  395526  1276812  1884271  1379959  1143842  1090815
# 3    승차  건대입구  280894  368079   870377  1401815   917558   575074   564419
# 4    승차   경복궁   35262   82486   201264   308313   296605   256254   331604
# ..   ..   ...     ...     ...      ...      ...      ...      ...      ...
# 215  하차    합정   49660  225326   483746  1181175   909390   556453   509288
# 216  하차    혜화   30532  244176   668542  1606465  1381800  1054497   956334
# 217  하차  홍대입구   46565  207852   500139  1568784  1613810  1208137  1341045
# 218  하차    홍제   16501   96503   160478   384873   337365   274916   251455
# 219  하차    회현   12389  380063   786716  1909858  1353393   985747  1093204
#
# ...

# %%
df_tmdck = df_tmdgk[df_tmdgk.loc[:, '구분'] == '승차']
df_tmdck
# Out:
#      구분    역명   05~06   06~07    07~08    08~09    09~10    10~11    11~12  \
# 0    승차  가락시장   34321   97951   272824   318920   230877   189330   190703
# 1    승차    강남  199341  320873   618839   960305   827104   821935  1096183
# 2    승차    강변  131474  395526  1276812  1884271  1379959  1143842  1090815
# 3    승차  건대입구  280894  368079   870377  1401815   917558   575074   564419
# 4    승차   경복궁   35262   82486   201264   308313   296605   256254   331604
# ..   ..   ...     ...     ...      ...      ...      ...      ...      ...
# 105  승차    합정  128781  246012   653482   777088   518644   409329   426618
# 106  승차    혜화   58475  117034   239693   335316   353324   437166   539100
# 107  승차  홍대입구  562152  535548  1015244  1215550   849855   754163   806816
# 108  승차    홍제  133191  312389   895795  1046194   632461   450321   418040
# 109  승차    회현   35548   54298    80824   133110   199494   280575   415609
#
# ...

# %%
df_tmdck_dur = df_tmdck.set_index('역명')

# %%
df_tmdck_dur_sum = pd.DataFrame(df_tmdck_dur.iloc[:, 1:].sum(axis=1))
df_tmdck_dur_sum #### 여기가 틀렸는데 왜 틀린지 모르겠다
# Out:
#                 0
# 역명
# 가락시장   10160151.0
# 강남    108788019.0
# 강변     54925905.0
# 건대입구   50079909.0
# 경복궁    28201929.0
# ...           ...
# 합정     36477546.0
# 혜화     47519295.0
# 홍대입구   84046863.0
# 홍제     22513944.0
# 회현     32885301.0
#
# [110 rows x 1 columns]

# %%
df_tmdck_dur_sum.columns=['총 승차']

# %%
df_tmdck_dur_sum
# Out:
#              총 승차
# 역명
# 가락시장   10160151.0
# 강남    108788019.0
# 강변     54925905.0
# 건대입구   50079909.0
# 경복궁    28201929.0
# ...           ...
# 합정     36477546.0
# 혜화     47519295.0
# 홍대입구   84046863.0
# 홍제     22513944.0
# 회현     32885301.0
#
# [110 rows x 1 columns]

# %% [markdown]
# ## 6번 답

# %%
df_tmdck_dur_sum.sort_values(by=['총 승차'], ascending=False).head(15)
# Out:
#                 총 승차
# 역명
# 강남       108788019.0
# 잠실        93240510.0
# 홍대입구      84046863.0
# 사당        82296639.0
# 서울역       81950004.0
# 신림        80042040.0
# 구로디지털단지   69312747.0
# 신도림       68897175.0
# 고속터미널     62715531.0
# 삼성        61614801.0
# 선릉        59473167.0
# 서울대입구     57908886.0
# 교대        56632533.0
# 신촌        56398812.0
# 을지로입구     56321907.0

# %%
df_112.groupby('역명').sum()
# Out:
#        05~06    06~07    07~08    08~09    09~10    10~11    11~12    12~13  \
# 역명
# 가락시장   40974   163385   398189   632286   392997   312079   321725   322024
# 강남    354846  1100982  2797618  5197647  4929856  2982109  2934301  3221375
# 강변    188569   868379  1828187  2711045  2144760  1857176  1808904  1873329
# 건대입구  304957   582505  1242513  2356139  1629975  1235748  1257565  1500994
# 경복궁    56735   265446   832675  1950182  1283043   978981   987923  1021352
# ...      ...      ...      ...      ...      ...      ...      ...      ...
# 합정    178441   471338  1137228  1958263  1428034   965782   935906  1016437
# 혜화     89007   361210   908235  1941781  1735124  1491663  1495434  1714457
# 홍대입구  608717   743400  1515383  2784334  2463665  1962300  2147861  2605056
# 홍제    149692   408892  1056273  1431067   969826   725237   669495   706350
# 회현     47937   434361   867540  2042968  1552887  1266322  1508813  1480633
#
# ...

# %% [markdown]
# ## 6번 답 수정

# %%
df_tmdgk1 = df_112.groupby(['구분', '역명']).sum().reset_index()

# %%
df_tmdck1 = df_tmdgk1[df_tmdgk.loc[:, '구분'] == '승차']
df_tmdck1
# Out:
#      구분    역명   05~06   06~07    07~08    08~09    09~10    10~11    11~12  \
# 0    승차  가락시장   34321   97951   272824   318920   230877   189330   190703
# 1    승차    강남  199341  320873   618839   960305   827104   821935  1096183
# 2    승차    강변  131474  395526  1276812  1884271  1379959  1143842  1090815
# 3    승차  건대입구  280894  368079   870377  1401815   917558   575074   564419
# 4    승차   경복궁   35262   82486   201264   308313   296605   256254   331604
# ..   ..   ...     ...     ...      ...      ...      ...      ...      ...
# 105  승차    합정  128781  246012   653482   777088   518644   409329   426618
# 106  승차    혜화   58475  117034   239693   335316   353324   437166   539100
# 107  승차  홍대입구  562152  535548  1015244  1215550   849855   754163   806816
# 108  승차    홍제  133191  312389   895795  1046194   632461   450321   418040
# 109  승차    회현   35548   54298    80824   133110   199494   280575   415609
#
# ...

# %%
df_tmdck1 = df_tmdck1.set_index('역명')

# %%
df_tmdck1
# Out:
#       구분   05~06   06~07    07~08    08~09    09~10    10~11    11~12  \
# 역명
# 가락시장  승차   34321   97951   272824   318920   230877   189330   190703
# 강남    승차  199341  320873   618839   960305   827104   821935  1096183
# 강변    승차  131474  395526  1276812  1884271  1379959  1143842  1090815
# 건대입구  승차  280894  368079   870377  1401815   917558   575074   564419
# 경복궁   승차   35262   82486   201264   308313   296605   256254   331604
# ...   ..     ...     ...      ...      ...      ...      ...      ...
# 합정    승차  128781  246012   653482   777088   518644   409329   426618
# 혜화    승차   58475  117034   239693   335316   353324   437166   539100
# 홍대입구  승차  562152  535548  1015244  1215550   849855   754163   806816
# 홍제    승차  133191  312389   895795  1046194   632461   450321   418040
# 회현    승차   35548   54298    80824   133110   199494   280575   415609
#
#         12~13    13~14  ...    17~18    18~19    19~20    20~21    21~22  \
# 역명                      ...
# ...

# %%
df_tmdck1_sum = pd.DataFrame(df_tmdck1.sum(axis=1))
df_tmdck1_sum
# Out:
# C:\Users\82103\AppData\Local\Temp/ipykernel_19604/705147481.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_tmdck1_sum = pd.DataFrame(df_tmdck1.sum(axis=1))
#                0
# 역명
# 가락시장   3386717.0
# 강남    36262673.0
# 강변    18308635.0
# 건대입구  16693303.0
# 경복궁    9400643.0
# ...          ...
# 합정    12159182.0
# 혜화    15839765.0
# 홍대입구  28015621.0
# 홍제     7504648.0
# 회현    10961767.0
#
# [110 rows x 1 columns]

# %%
df_tmdck1_sum.columns = ['총승차']

# %%
df_tmdck1_sum_sort = df_tmdck1_sum.sort_values(by=['총승차'], ascending=False)
df_tmdck1_sum_sort
# Out:
#              총승차
# 역명
# 강남    36262673.0
# 잠실    31080170.0
# 홍대입구  28015621.0
# 사당    27432213.0
# 서울역   27316668.0
# ...          ...
# 용두      830473.0
# 남태령     597887.0
# 신답      494357.0
# 지축      489233.0
# 도림천     376511.0
#
# [110 rows x 1 columns]

# %%
df_tmdck1_sum_sort.head(15)
# Out:
#                 총승차
# 역명
# 강남       36262673.0
# 잠실       31080170.0
# 홍대입구     28015621.0
# 사당       27432213.0
# 서울역      27316668.0
# 신림       26680680.0
# 구로디지털단지  23104249.0
# 신도림      22965725.0
# 고속터미널    20905177.0
# 삼성       20538267.0
# 선릉       19824389.0
# 서울대입구    19302962.0
# 교대       18877511.0
# 신촌       18799604.0
# 을지로입구    18773969.0

# %% [markdown]
# ## 7번 start
# - 승하차가 가장 많은 상위 15개의 데이터 추출
#
# ## and 답

# %%
df_112.groupby('역명').sum()
# Out:
#        05~06    06~07    07~08    08~09    09~10    10~11    11~12    12~13  \
# 역명
# 가락시장   40974   163385   398189   632286   392997   312079   321725   322024
# 강남    354846  1100982  2797618  5197647  4929856  2982109  2934301  3221375
# 강변    188569   868379  1828187  2711045  2144760  1857176  1808904  1873329
# 건대입구  304957   582505  1242513  2356139  1629975  1235748  1257565  1500994
# 경복궁    56735   265446   832675  1950182  1283043   978981   987923  1021352
# ...      ...      ...      ...      ...      ...      ...      ...      ...
# 합정    178441   471338  1137228  1958263  1428034   965782   935906  1016437
# 혜화     89007   361210   908235  1941781  1735124  1491663  1495434  1714457
# 홍대입구  608717   743400  1515383  2784334  2463665  1962300  2147861  2605056
# 홍제    149692   408892  1056273  1431067   969826   725237   669495   706350
# 회현     47937   434361   867540  2042968  1552887  1266322  1508813  1480633
#
# ...

# %%
tmdgkck = df_112.groupby('역명').sum().sum(axis=1).sort_values(ascending=False).head(15)

# %%
tmdgkck
# Out:
# 역명
# 강남         72989920.0
# 잠실         59959378.0
# 홍대입구       57959028.0
# 서울역        55481511.0
# 사당         54818151.0
# 신림         52797959.0
# 구로디지털단지    46290426.0
# 신도림        45882099.0
# 고속터미널      42586946.0
# 삼성         41763727.0
# 서울대입구      38218481.0
# 신촌         37935702.0
# 교대         37904055.0
# 을지로입구      37522895.0
# 시청         37344074.0
# dtype: float64

# %%
df_tmdgkck = pd.DataFrame(tmdgkck)

# %%
df_tmdgkck.columns = ['총 승하차']
df_tmdgkck
# Out:
#               총 승하차
# 역명
# 강남       72989920.0
# 잠실       59959378.0
# 홍대입구     57959028.0
# 서울역      55481511.0
# 사당       54818151.0
# 신림       52797959.0
# 구로디지털단지  46290426.0
# 신도림      45882099.0
# 고속터미널    42586946.0
# 삼성       41763727.0
# 서울대입구    38218481.0
# 신촌       37935702.0
# 교대       37904055.0
# 을지로입구    37522895.0
# 시청       37344074.0

# %%
df_tmdgkck.index.values
# Out:
# array(['강남', '잠실', '홍대입구', '서울역', '사당', '신림', '구로디지털단지', '신도림', '고속터미널',
#        '삼성', '서울대입구', '신촌', '교대', '을지로입구', '시청'], dtype=object)

# %%
df_tmdgkck.values
# Out:
# array([[72989920.],
#        [59959378.],
#        [57959028.],
#        [55481511.],
#        [54818151.],
#        [52797959.],
#        [46290426.],
#        [45882099.],
#        [42586946.],
#        [41763727.],
#        [38218481.],
#        [37935702.],
#        [37904055.],
#        [37522895.],
#        [37344074.]])

# %% [markdown]
# ## 8번 start

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# %%
font_path = "./data/malgun.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# %%
plt.plot(df_tmdgkck)

# %%
df_tmdgkck_ri = df_tmdgkck.reset_index()
df_tmdgkck_ri
# Out:
#          역명       총 승하차
# 0        강남  72989920.0
# 1        잠실  59959378.0
# 2      홍대입구  57959028.0
# 3       서울역  55481511.0
# 4        사당  54818151.0
# 5        신림  52797959.0
# 6   구로디지털단지  46290426.0
# 7       신도림  45882099.0
# 8     고속터미널  42586946.0
# 9        삼성  41763727.0
# 10    서울대입구  38218481.0
# 11       신촌  37935702.0
# 12       교대  37904055.0
# 13    을지로입구  37522895.0
# 14       시청  37344074.0

# %%
df_tmdgkck_ri.plot.bar(x='역명', y='총 승하차')
# Out:
# <AxesSubplot:xlabel='역명'>

# %% [markdown]
# ## 8번 답

# %%
df_tmdgkck_ri.plot.barh(x='역명', y='총 승하차', rot=0, figsize=(12, 5))
plt.show()
