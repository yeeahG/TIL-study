# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://finance.naver.com/item/sise_day.naver?code=005930&page=1"

# %%
head = { "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36"}

# %%
r = requests.get(url, headers=head)

# %%
bs = BeautifulSoup(r.text, 'lxml')

# %% [markdown]
# ### 데이터 파싱하기
# * 일 데이터를 하나의 list 담고 그 데이터를 전체 리스터 담는 구조
# * [[],[], [], []]

# %%
for idx, x in enumerate(bs.find("table").findAll("tr")[2:]):
    print(idx+2, x)
    print ("----------------------")
# Out:
# 2 <tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# <td align="center"><span class="tah p10 gray03">2022.04.08</span></td>
# <td class="num"><span class="tah p11">68,000</span></td>
# <td class="num">
# <span class="tah p11">0</span>
# </td>
# <td class="num"><span class="tah p11">68,100</span></td>
# <td class="num"><span class="tah p11">68,300</span></td>
# <td class="num"><span class="tah p11">68,000</span></td>
# <td class="num"><span class="tah p11">3,242,250</span></td>
# </tr>
# ----------------------
# 3 <tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# <td align="center"><span class="tah p10 gray03">2022.04.07</span></td>
# <td class="num"><span class="tah p11">68,000</span></td>
# <td class="num">
# <img alt="하락" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_down.gif" style="margin-right:4px;" width="7"/><span class="tah p11 nv01">
# 				500
# 				</span>
# </td>
# <td class="num"><span class="tah p11">68,500</span></td>
# <td class="num"><span class="tah p11">68,500</span></td>
# <td class="num"><span class="tah p11">68,000</span></td>
# <td class="num"><span class="tah p11">20,683,327</span></td>
# </tr>
# ----------------------
# 4 <tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# <td align="center"><span class="tah p10 gray03">2022.04.06</span></td>
# <td class="num"><span class="tah p11">68,500</span></td>
# <td class="num">
# <img alt="하락" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_down.gif" style="margin-right:4px;" width="7"/><span class="tah p11 nv01">
# 				700
# 				</span>
# </td>
# <td class="num"><span class="tah p11">68,600</span></td>
# <td class="num"><span class="tah p11">68,800</span></td>
# <td class="num"><span class="tah p11">68,500</span></td>
# <td class="num"><span class="tah p11">15,517,308</span></td>
# </tr>
# ----------------------
# 5 <tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# <td align="center"><span class="tah p10 gray03">2022.04.05</span></td>
# <td class="num"><span class="tah p11">69,200</span></td>
# <td class="num">
# <img alt="하락" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_down.gif" style="margin-right:4px;" width="7"/><span class="tah p11 nv01">
# 				100
# 				</span>
# </td>
# <td class="num"><span class="tah p11">69,400</span></td>
# <td class="num"><span class="tah p11">69,600</span></td>
# <td class="num"><span class="tah p11">69,100</span></td>
# <td class="num"><span class="tah p11">8,467,248</span></td>
# </tr>
# ----------------------
# 6 <tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# <td align="center"><span class="tah p10 gray03">2022.04.04</span></td>
# <td class="num"><span class="tah p11">69,300</span></td>
# <td class="num">
# <img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
# 				200
# 				</span>
# </td>
# <td class="num"><span class="tah p11">68,900</span></td>
# <td class="num"><span class="tah p11">69,300</span></td>
# <td class="num"><span class="tah p11">68,600</span></td>
# <td class="num"><span class="tah p11">11,107,905</span></td>
# </tr>
# ----------------------
# 7 <tr>
# <td colspan="7" height="8"></td>
# </tr>
# ----------------------
# 8 <tr>
# <td bgcolor="#e1e1e1" colspan="7" height="1"></td>
# </tr>
# ----------------------
# 9 <tr>
# <td colspan="7" height="8"></td>
# </tr>
# ----------------------
# 10 <tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# <td align="center"><span class="tah p10 gray03">2022.04.01</span></td>
# <td class="num"><span class="tah p11">69,100</span></td>
# <td class="num">
# <img alt="하락" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_down.gif" style="margin-right:4px;" width="7"/><span class="tah p11 nv01">
# 				500
# 				</span>
# </td>
# <td class="num"><span class="tah p11">69,500</span></td>
# <td class="num"><span class="tah p11">69,500</span></td>
# <td class="num"><span class="tah p11">69,000</span></td>
# <td class="num"><span class="tah p11">15,916,846</span></td>
# </tr>
# ----------------------
# 11 <tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# <td align="center"><span class="tah p10 gray03">2022.03.31</span></td>
# <td class="num"><span class="tah p11">69,600</span></td>
# <td class="num">
# <img alt="하락" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_down.gif" style="margin-right:4px;" width="7"/><span class="tah p11 nv01">
# 				300
# 				</span>
# </td>
# <td class="num"><span class="tah p11">69,900</span></td>
# <td class="num"><span class="tah p11">70,200</span></td>
# <td class="num"><span class="tah p11">69,600</span></td>
# <td class="num"><span class="tah p11">12,510,366</span></td>
# </tr>
# ----------------------
# 12 <tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# <td align="center"><span class="tah p10 gray03">2022.03.30</span></td>
# <td class="num"><span class="tah p11">69,900</span></td>
# <td class="num">
# <img alt="하락" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_down.gif" style="margin-right:4px;" width="7"/><span class="tah p11 nv01">
# 				300
# 				</span>
# </td>
# <td class="num"><span class="tah p11">70,300</span></td>
# <td class="num"><span class="tah p11">70,500</span></td>
# <td class="num"><span class="tah p11">69,800</span></td>
# <td class="num"><span class="tah p11">12,670,187</span></td>
# </tr>
# ----------------------
# 13 <tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# <td align="center"><span class="tah p10 gray03">2022.03.29</span></td>
# <td class="num"><span class="tah p11">70,200</span></td>
# <td class="num">
# <img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
# 				500
# 				</span>
# </td>
# <td class="num"><span class="tah p11">70,000</span></td>
# <td class="num"><span class="tah p11">70,300</span></td>
# <td class="num"><span class="tah p11">69,800</span></td>
# <td class="num"><span class="tah p11">13,686,208</span></td>
# </tr>
# ----------------------
# 14 <tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# <td align="center"><span class="tah p10 gray03">2022.03.28</span></td>
# <td class="num"><span class="tah p11">69,700</span></td>
# <td class="num">
# <img alt="하락" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_down.gif" style="margin-right:4px;" width="7"/><span class="tah p11 nv01">
# 				100
# 				</span>
# </td>
# <td class="num"><span class="tah p11">69,500</span></td>
# <td class="num"><span class="tah p11">69,900</span></td>
# <td class="num"><span class="tah p11">69,200</span></td>
# <td class="num"><span class="tah p11">12,619,289</span></td>
# </tr>
# ----------------------
# 15 <tr>
# <td colspan="7" height="8"></td>
# </tr>
# ----------------------

# %%
[x.text.strip() for x in bs.find("table").findAll("tr")[2].findAll("td")]
# Out:
# ['2022.04.08', '68,000', '0', '68,100', '68,300', '68,000', '3,242,250']

# %%
len(bs.find("table").findAll("tr")[7].findAll("td"))
# Out:
# 1

# %%
for idx, x in enumerate(bs.find("table").findAll("tr")[2:]):
    if len(x.findAll("td")) > 1:
        print ([x.text.strip() for x in x.findAll("td")])
# Out:
# ['2022.04.08', '68,000', '0', '68,100', '68,300', '68,000', '3,242,250']
# ['2022.04.07', '68,000', '500', '68,500', '68,500', '68,000', '20,683,327']
# ['2022.04.06', '68,500', '700', '68,600', '68,800', '68,500', '15,517,308']
# ['2022.04.05', '69,200', '100', '69,400', '69,600', '69,100', '8,467,248']
# ['2022.04.04', '69,300', '200', '68,900', '69,300', '68,600', '11,107,905']
# ['2022.04.01', '69,100', '500', '69,500', '69,500', '69,000', '15,916,846']
# ['2022.03.31', '69,600', '300', '69,900', '70,200', '69,600', '12,510,366']
# ['2022.03.30', '69,900', '300', '70,300', '70,500', '69,800', '12,670,187']
# ['2022.03.29', '70,200', '500', '70,000', '70,300', '69,800', '13,686,208']
# ['2022.03.28', '69,700', '100', '69,500', '69,900', '69,200', '12,619,289']

# %%
tmp = []
for idx, x in enumerate(bs.find("table").findAll("tr")[2:]):
    if len(x.findAll("td")) > 1:
        tmp.append ([x.text.strip() for x in x.findAll("td")])

# %%
tmp
# Out:
# [['2022.04.08', '68,000', '0', '68,100', '68,300', '68,000', '3,242,250'],
#  ['2022.04.07', '68,000', '500', '68,500', '68,500', '68,000', '20,683,327'],
#  ['2022.04.06', '68,500', '700', '68,600', '68,800', '68,500', '15,517,308'],
#  ['2022.04.05', '69,200', '100', '69,400', '69,600', '69,100', '8,467,248'],
#  ['2022.04.04', '69,300', '200', '68,900', '69,300', '68,600', '11,107,905'],
#  ['2022.04.01', '69,100', '500', '69,500', '69,500', '69,000', '15,916,846'],
#  ['2022.03.31', '69,600', '300', '69,900', '70,200', '69,600', '12,510,366'],
#  ['2022.03.30', '69,900', '300', '70,300', '70,500', '69,800', '12,670,187'],
#  ['2022.03.29', '70,200', '500', '70,000', '70,300', '69,800', '13,686,208'],
#  ['2022.03.28', '69,700', '100', '69,500', '69,900', '69,200', '12,619,289']]

# %% [markdown]
# * tmp를 list comprehension 버전

# %%
tmp2 = [[x.text.strip() for x in x.findAll("td")] for idx, x in enumerate(bs.find("table").findAll("tr")[2:]) if len(x.findAll("td")) > 1]

# %%
tmp2
# Out:
# [['2022.04.08', '68,000', '0', '68,100', '68,300', '68,000', '3,242,250'],
#  ['2022.04.07', '68,000', '500', '68,500', '68,500', '68,000', '20,683,327'],
#  ['2022.04.06', '68,500', '700', '68,600', '68,800', '68,500', '15,517,308'],
#  ['2022.04.05', '69,200', '100', '69,400', '69,600', '69,100', '8,467,248'],
#  ['2022.04.04', '69,300', '200', '68,900', '69,300', '68,600', '11,107,905'],
#  ['2022.04.01', '69,100', '500', '69,500', '69,500', '69,000', '15,916,846'],
#  ['2022.03.31', '69,600', '300', '69,900', '70,200', '69,600', '12,510,366'],
#  ['2022.03.30', '69,900', '300', '70,300', '70,500', '69,800', '12,670,187'],
#  ['2022.03.29', '70,200', '500', '70,000', '70,300', '69,800', '13,686,208'],
#  ['2022.03.28', '69,700', '100', '69,500', '69,900', '69,200', '12,619,289']]

# %%
url = "https://finance.naver.com/item/sise_day.naver?code={}&page={}"
# 005930

# %% [markdown]
# ### 사용자 함수 만들기
# * 사용자한테 종목 코드와 페이지 번호를 받으면 데이터를 파싱해서 리스트 형태로 리턴한다.

# %%
def get_stock_day(code, page):
    url = "https://finance.naver.com/item/sise_day.naver?code={}&page={}"
    r = requests.get(url.format(code, page), headers=head)
    bs = BeautifulSoup(r.text, 'lxml')
    return [[x.text.strip() for x in x.findAll("td")] for idx, x in enumerate(bs.find("table").findAll("tr")[2:]) if len(x.findAll("td")) > 1]

# %% [markdown]
# * 10 page 데이터 받기 (하나의 리스트 담기)

# %%
total = []
for x in range(1, 11):
    total.extend(get_stock_day("005930", x))

# %%
len(total)
# Out:
# 100

# %%
a = [1,2,3]

# %%
b = [4,5]

# %%
a.append(b)

# %%
a
# Out:
# [1, 2, 3, [4, 5]]

# %%
a[-1]
# Out:
# [4, 5]

# %%
a.extend(b)

# %%
a
# Out:
# [1, 2, 3, [4, 5], 4, 5]

# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql

# %%
con =pymysql.connect(host="127.0.0.1", user='root', port=3306, password='1q2w3e', db='stock' ,
                charset='utf8')

# %%
cur = con.cursor()

# %%
cur.execute("show tables")
# Out:
# 0

# %%
cur.fetchall()
# Out:
# ()

# %%
sql = """create table stock (
	code char(16) not null,
	date date,
	closing_price int,
	diff_price int,
	open_price int,
	high_price int,
	low_price int,
	volume int,
	primary key(code, date)
)"""

# %%
cur.execute(sql)
# Out:
# 0

# %%
con.commit()

# %%
x = total[0].copy()

# %%
x.insert(0, '005930')

# %%
[y.replace(",", "") for y in x]
# Out:
# ['005930', '2022.04.08', '68000', '0', '68100', '68300', '68000', '5676414']

# %%
sql_insert = "INSERT INTO stock VALUES (%s, %s, %s, %s,%s, %s, %s, %s)"

# %%
cur.execute(sql_insert, [y.replace(",", "") for y in x] )
# Out:
# 1

# %%
con.commit()

# %%
cur.execute("select * from stock")
# Out:
# 1

# %%
tmp = cur.fetchall()

# %%
tmp
# Out:
# (('005930',
#   datetime.date(2022, 4, 8),
#   68000,
#   0,
#   68100,
#   68300,
#   68000,
#   5676414),)

# %%
cur.execute("truncate table stock")
# Out:
# 0

# %%
con.commit()

# %%
cur.execute("select * from stock")
# Out:
# 0

# %%
cur.fetchall()
# Out:
# ()

# %% [markdown]
# # DB 데이터 넣기

# %%
for x in total:
    x.insert(0, '005930')
    cur.execute(sql_insert, [y.replace(",", "") for y in x] )
con.commit()

# %%
cur.execute("select * from stock")
# Out:
# 100

# %%
rt = cur.fetchall()

# %%
rt
# Out:
# (('005930',
#   datetime.date(2021, 11, 12),
#   70600,
#   700,
#   70200,
#   70900,
#   69900,
#   10087450),
#  ('005930',
#   datetime.date(2021, 11, 15),
#   71400,
#   800,
#   71700,
#   71900,
#   70900,
#   12420710),
#  ('005930',
#   datetime.date(2021, 11, 16),
#   71300,
#   100,
#   71500,
#   72000,
#   71300,
#   10919239),
#  ('005930',
#   datetime.date(2021, 11, 17),
#   70700,
#   600,
#   71300,
#   71600,
#   70600,
#   11027606),
#  ('005930',
#   datetime.date(2021, 11, 18),
#   70200,
#   500,
#   70700,
#   71000,
#   70200,
#   10144957),
#  ('005930',
#   datetime.date(2021, 11, 19),
#   71200,
#   1000,
#   70400,
#   71400,
#   70100,
#   11954728),
#  ('005930',
#   datetime.date(2021, 11, 22),
#   74900,
#   3700,
#   73300,
#   75200,
#   73000,
#   27506623),
#  ('005930',
#   datetime.date(2021, 11, 23),
#   75300,
#   400,
#   76000,
#   76000,
#   74500,
#   22029195),
#  ('005930',
#   datetime.date(2021, 11, 24),
#   74800,
#   500,
#   76000,
#   76200,
#   74100,
#   15652305),
#  ('005930',
#   datetime.date(2021, 11, 25),
#   73700,
#   1100,
#   75100,
#   75100,
#   73600,
#   12559258),
#  ('005930',
#   datetime.date(2021, 11, 26),
#   72300,
#   1400,
#   73500,
#   74100,
#   72000,
#   13002242),
#  ('005930',
#   datetime.date(2021, 11, 29),
#   72300,
#   0,
#   71700,
#   73000,
#   71400,
#   16682559),
#  ('005930',
#   datetime.date(2021, 11, 30),
#   71300,
#   1000,
#   73200,
#   73900,
#   70500,
#   30364841),
#  ('005930',
#   datetime.date(2021, 12, 1),
#   74400,
#   3100,
#   72000,
#   74800,
#   71600,
#   21954856),
#  ('005930',
#   datetime.date(2021, 12, 2),
#   75800,
#   1400,
#   73900,
#   75800,
#   73800,
#   23652940),
#  ('005930',
#   datetime.date(2021, 12, 3),
#   75600,
#   200,
#   75600,
#   76000,
#   74100,
#   18330240),
#  ('005930',
#   datetime.date(2021, 12, 6),
#   76300,
#   700,
#   75100,
#   76700,
#   74900,
#   16391250),
#  ('005930',
#   datetime.date(2021, 12, 7),
#   77400,
#   1100,
#   76100,
#   77700,
#   75600,
#   19232453),
#  ('005930',
#   datetime.date(2021, 12, 8),
#   77400,
#   0,
#   78300,
#   78600,
#   77100,
#   21558340),
#  ('005930',
#   datetime.date(2021, 12, 9),
#   78200,
#   800,
#   77400,
#   78200,
#   77000,
#   21604528),
#  ('005930',
#   datetime.date(2021, 12, 10),
#   76900,
#   1300,
#   77400,
#   77600,
#   76800,
#   9155219),
#  ('005930',
#   datetime.date(2021, 12, 13),
#   76800,
#   100,
#   77200,
#   78300,
#   76500,
#   15038750),
#  ('005930',
#   datetime.date(2021, 12, 14),
#   77000,
#   200,
#   76500,
#   77200,
#   76200,
#   10976660),
#  ('005930',
#   datetime.date(2021, 12, 15),
#   77600,
#   600,
#   76400,
#   77600,
#   76300,
#   9584939),
#  ('005930',
#   datetime.date(2021, 12, 16),
#   77800,
#   200,
#   78500,
#   78500,
#   77400,
#   11996128),
#  ('005930',
#   datetime.date(2021, 12, 17),
#   78000,
#   200,
#   76800,
#   78000,
#   76800,
#   13108479),
#  ('005930',
#   datetime.date(2021, 12, 20),
#   77100,
#   900,
#   77600,
#   77800,
#   76800,
#   11264375),
#  ('005930',
#   datetime.date(2021, 12, 21),
#   78100,
#   1000,
#   77900,
#   78300,
#   77500,
#   14245298),
#  ('005930',
#   datetime.date(2021, 12, 22),
#   79400,
#   1300,
#   78900,
#   79400,
#   78800,
#   17105892),
#  ('005930',
#   datetime.date(2021, 12, 23),
#   79900,
#   500,
#   79800,
#   80000,
#   79300,
#   13577498),
#  ('005930',
#   datetime.date(2021, 12, 24),
#   80500,
#   600,
#   80200,
#   80800,
#   80200,
#   12086380),
#  ('005930',
#   datetime.date(2021, 12, 27),
#   80200,
#   300,
#   80600,
#   80600,
#   79800,
#   10783368),
#  ('005930',
#   datetime.date(2021, 12, 28),
#   80300,
#   100,
#   80200,
#   80400,
#   79700,
#   18226325),
#  ('005930',
#   datetime.date(2021, 12, 29),
#   78800,
#   1500,
#   80200,
#   80200,
#   78500,
#   19794795),
#  ('005930',
#   datetime.date(2021, 12, 30),
#   78300,
#   500,
#   78900,
#   79500,
#   78100,
#   14236700),
#  ('005930',
#   datetime.date(2022, 1, 3),
#   78600,
#   300,
#   79400,
#   79800,
#   78200,
#   13502112),
#  ('005930',
#   datetime.date(2022, 1, 4),
#   78700,
#   100,
#   78800,
#   79200,
#   78300,
#   12427416),
#  ('005930',
#   datetime.date(2022, 1, 5),
#   77400,
#   1300,
#   78800,
#   79000,
#   76400,
#   25470640),
#  ('005930',
#   datetime.date(2022, 1, 6),
#   76900,
#   500,
#   76700,
#   77600,
#   76600,
#   12931954),
#  ('005930',
#   datetime.date(2022, 1, 7),
#   78300,
#   1400,
#   78100,
#   78400,
#   77400,
#   15163757),
#  ('005930',
#   datetime.date(2022, 1, 10),
#   78000,
#   300,
#   78100,
#   78100,
#   77100,
#   9947422),
#  ('005930',
#   datetime.date(2022, 1, 11),
#   78900,
#   900,
#   78400,
#   79000,
#   78000,
#   13221123),
#  ('005930',
#   datetime.date(2022, 1, 12),
#   78900,
#   0,
#   79500,
#   79600,
#   78600,
#   11000502),
#  ('005930',
#   datetime.date(2022, 1, 13),
#   77900,
#   1000,
#   79300,
#   79300,
#   77900,
#   13889401),
#  ('005930',
#   datetime.date(2022, 1, 14),
#   77300,
#   600,
#   77700,
#   78100,
#   77100,
#   10096725),
#  ('005930',
#   datetime.date(2022, 1, 17),
#   77500,
#   200,
#   77600,
#   77800,
#   76900,
#   8785122),
#  ('005930',
#   datetime.date(2022, 1, 18),
#   77000,
#   500,
#   77600,
#   77800,
#   76600,
#   9592788),
#  ('005930',
#   datetime.date(2022, 1, 19),
#   76300,
#   700,
#   76500,
#   76900,
#   76100,
#   10598290),
#  ('005930',
#   datetime.date(2022, 1, 20),
#   76500,
#   200,
#   76200,
#   76700,
#   75900,
#   9708168),
#  ('005930',
#   datetime.date(2022, 1, 21),
#   75600,
#   900,
#   75800,
#   75800,
#   74700,
#   15774888),
#  ('005930',
#   datetime.date(2022, 1, 24),
#   75100,
#   500,
#   75400,
#   75800,
#   74700,
#   13691134),
#  ('005930',
#   datetime.date(2022, 1, 25),
#   74000,
#   1100,
#   74800,
#   75000,
#   73200,
#   17766704),
#  ('005930',
#   datetime.date(2022, 1, 26),
#   73300,
#   700,
#   73900,
#   74400,
#   73100,
#   12976730),
#  ('005930',
#   datetime.date(2022, 1, 27),
#   71300,
#   2000,
#   73800,
#   74000,
#   71300,
#   22274777),
#  ('005930',
#   datetime.date(2022, 1, 28),
#   73300,
#   2000,
#   71300,
#   73700,
#   71200,
#   21367447),
#  ('005930',
#   datetime.date(2022, 2, 3),
#   73300,
#   0,
#   74900,
#   74900,
#   73300,
#   17744721),
#  ('005930',
#   datetime.date(2022, 2, 4),
#   74000,
#   700,
#   74300,
#   74600,
#   73400,
#   12730034),
#  ('005930',
#   datetime.date(2022, 2, 7),
#   73000,
#   1000,
#   73500,
#   73600,
#   72400,
#   14240838),
#  ('005930',
#   datetime.date(2022, 2, 8),
#   73500,
#   500,
#   73800,
#   74200,
#   73000,
#   11736666),
#  ('005930',
#   datetime.date(2022, 2, 9),
#   74700,
#   1200,
#   74300,
#   74700,
#   74000,
#   9699122),
#  ('005930',
#   datetime.date(2022, 2, 10),
#   75400,
#   700,
#   75600,
#   75800,
#   74700,
#   17746033),
#  ('005930',
#   datetime.date(2022, 2, 11),
#   74900,
#   500,
#   75000,
#   75500,
#   74600,
#   12205407),
#  ('005930',
#   datetime.date(2022, 2, 14),
#   73700,
#   1200,
#   74400,
#   74500,
#   73100,
#   13993255),
#  ('005930',
#   datetime.date(2022, 2, 15),
#   73700,
#   0,
#   74100,
#   74200,
#   73100,
#   9320365),
#  ('005930',
#   datetime.date(2022, 2, 16),
#   74800,
#   1100,
#   74600,
#   74900,
#   74200,
#   10767386),
#  ('005930',
#   datetime.date(2022, 2, 17),
#   75000,
#   200,
#   75000,
#   75600,
#   74500,
#   13605382),
#  ('005930',
#   datetime.date(2022, 2, 18),
#   74300,
#   700,
#   74600,
#   74800,
#   73700,
#   10122226),
#  ('005930',
#   datetime.date(2022, 2, 21),
#   74200,
#   100,
#   73200,
#   74300,
#   72600,
#   10489717),
#  ('005930',
#   datetime.date(2022, 2, 22),
#   73400,
#   800,
#   73000,
#   73400,
#   72800,
#   11692469),
#  ('005930',
#   datetime.date(2022, 2, 23),
#   73000,
#   400,
#   73800,
#   73800,
#   72800,
#   10397964),
#  ('005930',
#   datetime.date(2022, 2, 24),
#   71500,
#   1500,
#   72300,
#   72300,
#   71300,
#   15759283),
#  ('005930',
#   datetime.date(2022, 2, 25),
#   71900,
#   400,
#   72100,
#   72600,
#   71900,
#   13168484),
#  ('005930',
#   datetime.date(2022, 2, 28),
#   72100,
#   200,
#   71100,
#   72100,
#   71000,
#   17781783),
#  ('005930',
#   datetime.date(2022, 3, 2),
#   71700,
#   400,
#   72300,
#   72400,
#   71500,
#   12481430),
#  ('005930',
#   datetime.date(2022, 3, 3),
#   72900,
#   1200,
#   72300,
#   73100,
#   72200,
#   13232638),
#  ('005930',
#   datetime.date(2022, 3, 4),
#   71500,
#   1400,
#   72700,
#   72700,
#   71200,
#   13409634),
#  ('005930',
#   datetime.date(2022, 3, 7),
#   70100,
#   1400,
#   70000,
#   70600,
#   69900,
#   18617138),
#  ('005930',
#   datetime.date(2022, 3, 8),
#   69500,
#   600,
#   68800,
#   70000,
#   68700,
#   15828269),
#  ('005930',
#   datetime.date(2022, 3, 10),
#   71200,
#   1700,
#   70800,
#   71200,
#   70500,
#   21159248),
#  ('005930',
#   datetime.date(2022, 3, 11),
#   70000,
#   1200,
#   70500,
#   70700,
#   69700,
#   15787655),
#  ('005930',
#   datetime.date(2022, 3, 14),
#   70200,
#   200,
#   70000,
#   70200,
#   69600,
#   9040993),
#  ('005930',
#   datetime.date(2022, 3, 15),
#   69500,
#   700,
#   69800,
#   70100,
#   69500,
#   10258562),
#  ('005930',
#   datetime.date(2022, 3, 16),
#   70400,
#   900,
#   70200,
#   70500,
#   69700,
#   10175750),
#  ('005930',
#   datetime.date(2022, 3, 17),
#   71200,
#   800,
#   71200,
#   71800,
#   70900,
#   17646315),
#  ('005930',
#   datetime.date(2022, 3, 18),
#   70700,
#   500,
#   70600,
#   70900,
#   70200,
#   14410038),
#  ('005930',
#   datetime.date(2022, 3, 21),
#   69900,
#   800,
#   70900,
#   71000,
#   69900,
#   11169002),
#  ('005930',
#   datetime.date(2022, 3, 22),
#   70300,
#   400,
#   69900,
#   70500,
#   69900,
#   9402666),
#  ('005930',
#   datetime.date(2022, 3, 23),
#   70500,
#   200,
#   70600,
#   71200,
#   70300,
#   12398025),
#  ('005930',
#   datetime.date(2022, 3, 24),
#   69800,
#   700,
#   69600,
#   70300,
#   69600,
#   37943357),
#  ('005930',
#   datetime.date(2022, 3, 25),
#   69800,
#   0,
#   70100,
#   70200,
#   69600,
#   12986010),
#  ('005930',
#   datetime.date(2022, 3, 28),
#   69700,
#   100,
#   69500,
#   69900,
#   69200,
#   12619289),
#  ('005930',
#   datetime.date(2022, 3, 29),
#   70200,
#   500,
#   70000,
#   70300,
#   69800,
#   13686208),
#  ('005930',
#   datetime.date(2022, 3, 30),
#   69900,
#   300,
#   70300,
#   70500,
#   69800,
#   12670187),
#  ('005930',
#   datetime.date(2022, 3, 31),
#   69600,
#   300,
#   69900,
#   70200,
#   69600,
#   12510366),
#  ('005930',
#   datetime.date(2022, 4, 1),
#   69100,
#   500,
#   69500,
#   69500,
#   69000,
#   15916846),
#  ('005930',
#   datetime.date(2022, 4, 4),
#   69300,
#   200,
#   68900,
#   69300,
#   68600,
#   11107905),
#  ('005930',
#   datetime.date(2022, 4, 5),
#   69200,
#   100,
#   69400,
#   69600,
#   69100,
#   8467248),
#  ('005930',
#   datetime.date(2022, 4, 6),
#   68500,
#   700,
#   68600,
#   68800,
#   68500,
#   15517308),
#  ('005930',
#   datetime.date(2022, 4, 7),
#   68000,
#   500,
#   68500,
#   68500,
#   68000,
#   20683327),
#  ('005930', datetime.date(2022, 4, 8), 68000, 0, 68100, 68300, 68000, 5676414))

# %%
krx = "http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd"
payload= {"bld" : "dbms/MDC/STAT/standard/MDCSTAT01901",
"locale" : "ko_KR",
"mktId" : "ALL",
"share" : "1",
"csvxls_isNo" : "false",}

# %%
krx_r = requests.post(krx, data=payload)

# %%
len(krx_r.json()['OutBlock_1'])
# Out:
# 2625

# %%
for x in krx_r.json()['OutBlock_1']:
    print(x)
    break
# Out:
# {'ISU_CD': 'KR7098120009', 'ISU_SRT_CD': '098120', 'ISU_NM': '(주)마이크로컨텍솔루션', 'ISU_ABBRV': '마이크로컨텍솔', 'ISU_ENG_NM': 'Micro Contact Solution Co.,Ltd.', 'LIST_DD': '2008/09/23', 'MKT_TP_NM': 'KOSDAQ', 'SECUGRP_NM': '주권', 'SECT_TP_NM': '벤처기업부', 'KIND_STKCERT_TP_NM': '보통주', 'PARVAL': '500', 'LIST_SHRS': '8,312,766'}

# %%
krx_sql = """create table master (
	{} varchar(50), 
	{} varchar(50),
    {} varchar(50),
    {} varchar(50),
    {} varchar(50),
    {} varchar(50),
    {} varchar(50),
    {} varchar(50),
    {} varchar(50),
    {} varchar(50),
    {} varchar(50),
    {} varchar(50),
    primary key(ISU_CD)
)"""

# %%
len(x.keys())
# Out:
# 12

# %%
x
# Out:
# {'ISU_CD': 'KR7238490007',
#  'ISU_SRT_CD': '238490',
#  'ISU_NM': '힘스',
#  'ISU_ABBRV': '힘스',
#  'ISU_ENG_NM': 'HIMS CO., LTD.',
#  'LIST_DD': '2017/07/20',
#  'MKT_TP_NM': 'KOSDAQ',
#  'SECUGRP_NM': '주권',
#  'SECT_TP_NM': '우량기업부',
#  'KIND_STKCERT_TP_NM': '보통주',
#  'PARVAL': '500',
#  'LIST_SHRS': '11,312,236'}

# %%
print(krx_sql.format('ISU_CD', 'ISU_SRT_CD', 'ISU_NM', 'ISU_ABBRV', 'ISU_ENG_NM', 'LIST_DD', 'MKT_TP_NM', 'SECUGRP_NM', 'SECT_TP_NM', 'KIND_STKCERT_TP_NM', 'PARVAL', 'LIST_SHRS'))
# Out:
# create table master (
# 	ISU_CD varchar(50),
# 	ISU_SRT_CD varchar(50),
#     ISU_NM varchar(50),
#     ISU_ABBRV varchar(50),
#     ISU_ENG_NM varchar(50),
#     LIST_DD varchar(50),
#     MKT_TP_NM varchar(50),
#     SECUGRP_NM varchar(50),
#     SECT_TP_NM varchar(50),
#     KIND_STKCERT_TP_NM varchar(50),
#     PARVAL varchar(50),
#     LIST_SHRS varchar(50),
#     primary key(ISU_CD)
# )

# %%
cur.execute(krx_sql.format('ISU_CD', 'ISU_SRT_CD', 'ISU_NM', 'ISU_ABBRV', 'ISU_ENG_NM', 'LIST_DD', 'MKT_TP_NM', 'SECUGRP_NM', 'SECT_TP_NM', 'KIND_STKCERT_TP_NM', 'PARVAL', 'LIST_SHRS'))
# Out:
# 0

# %%
con.commit()

# %%
master_sql = "INSERT INTO master VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"

# %%
cur.execute(master_sql,list(x.values()))
# Out:
# 1

# %%
con.commit()

# %%
cur.execute("select * from master")
# Out:
# 1

# %%
cur.fetchall()
# Out:
# (('KR7098120009',
#   '098120',
#   '(주)마이크로컨텍솔루션',
#   '마이크로컨텍솔',
#   'Micro Contact Solution Co.,Ltd.',
#   '2008/09/23',
#   'KOSDAQ',
#   '주권',
#   '벤처기업부',
#   '보통주',
#   '500',
#   '8,312,766'),)

# %%
for x in krx_r.json()['OutBlock_1']:
    try:
        cur.execute(master_sql, list(x.values()))
    except Exception as e:
        print(e)
        print(x['ISU_ENG_NM'])
# Out:
# (1062, "Duplicate entry 'KR7098120009' for key 'PRIMARY'")
# Micro Contact Solution Co.,Ltd.
# (1062, "Duplicate entry 'KR7131100000' for key 'PRIMARY'")
# SKY E&M Co., Ltd.
# (1062, "Duplicate entry 'KR7009520008' for key 'PRIMARY'")
# POSCO M-TECH CO.,LTD.
# (1062, "Duplicate entry 'KR7095570008' for key 'PRIMARY'")
# AJ Networks Co.,Ltd.
# (1062, "Duplicate entry 'KR7006840003' for key 'PRIMARY'")
# AK Holdings, Inc.
# (1062, "Duplicate entry 'KR7282330000' for key 'PRIMARY'")
# BGF Retail
# (1062, "Duplicate entry 'KR7027410000' for key 'PRIMARY'")
# BGF
# (1062, "Duplicate entry 'KR7138930003' for key 'PRIMARY'")
# BNK Financial Group Inc.
# (1062, "Duplicate entry 'KR7001461003' for key 'PRIMARY'")
# BYC(1P)
# (1062, "Duplicate entry 'KR7001460005' for key 'PRIMARY'")
# BYC
# (1062, "Duplicate entry 'KR7001041003' for key 'PRIMARY'")
# CJ(1P)
# (1062, "Duplicate entry 'KR700104K010' for key 'PRIMARY'")
# CJ(4PC)
# (1062, "Duplicate entry 'KR7001040005' for key 'PRIMARY'")
# CJ Corp.
# (1062, "Duplicate entry 'KR7011151008' for key 'PRIMARY'")
# CJSEAFOODCORPORATION(1P)
# (1062, "Duplicate entry 'KR7011150000' for key 'PRIMARY'")
# CJSEAFOODCORPORATION
# (1062, "Duplicate entry 'KR7058820002' for key 'PRIMARY'")
# CMG Pharmaceutical Co., Ltd.
# (1062, "Duplicate entry 'KR7000590000' for key 'PRIMARY'")
# CSHOLDINGS
# (1062, "Duplicate entry 'KR7012030003' for key 'PRIMARY'")
# DB Inc.
# (1062, "Duplicate entry 'KR7016610008' for key 'PRIMARY'")
# DB Financial Investment Co., LTD.
# (1062, "Duplicate entry 'KR7005830005' for key 'PRIMARY'")
# DB INSURANCE
# (1062, "Duplicate entry 'KR7000991000' for key 'PRIMARY'")
# DB HiTek Co.,LTD(1P)
# (1062, "Duplicate entry 'KR7000990002' for key 'PRIMARY'")
# DB HiTek Co.,LTD
# (1062, "Duplicate entry 'KR7139130009' for key 'PRIMARY'")
# DGB Financial Group
# (1062, "Duplicate entry 'KR7001530005' for key 'PRIMARY'")
# DI DONGIL
# (1062, "Duplicate entry 'KR7000211003' for key 'PRIMARY'")
# DL(1P)
# (1062, "Duplicate entry 'KR7001880004' for key 'PRIMARY'")
# DLConstruction
# (1062, "Duplicate entry 'KR7000210005' for key 'PRIMARY'")
# DL
# (1062, "Duplicate entry 'KR737550K011' for key 'PRIMARY'")
# DL E&C CO., LTD.(1P)
# (1062, "Duplicate entry 'KR7375500006' for key 'PRIMARY'")
# DL E&C CO., LTD.
# (1062, "Duplicate entry 'KR7155660004' for key 'PRIMARY'")
# DSR CORP
# (1062, "Duplicate entry 'KR7069730000' for key 'PRIMARY'")
# DSRWIRECORP
# (1062, "Duplicate entry 'KR7017940008' for key 'PRIMARY'")
# E1Corporation
# (1062, "Duplicate entry 'KR7365550003' for key 'PRIMARY'")
# ESR KENDALL SQUARE REIT
# (1062, "Duplicate entry 'KR7050120005' for key 'PRIMARY'")
# ES CUBE
# (1062, "Duplicate entry 'KR7383220001' for key 'PRIMARY'")
# F&F
# (1062, "Duplicate entry 'KR7007700008' for key 'PRIMARY'")
# F&F Holdings
# (1062, "Duplicate entry 'KR7078931003' for key 'PRIMARY'")
# GS Holdings(1P)
# (1062, "Duplicate entry 'KR7006360002' for key 'PRIMARY'")
# GS Engineering & Construction Corp
# (1062, "Duplicate entry 'KR7078930005' for key 'PRIMARY'")
# GS Holdings
# (1062, "Duplicate entry 'KR7012630000' for key 'PRIMARY'")
# HDC HOLDINGS CO.,Ltd
# (1062, "Duplicate entry 'KR7294870001' for key 'PRIMARY'")
# HYUNDAI DEVELOPMENT COMPANY
# (1062, "Duplicate entry 'KR7097230007' for key 'PRIMARY'")
# HJ SHIPBUILDING & CONSTRUCTION
# (1062, "Duplicate entry 'KR7003560000' for key 'PRIMARY'")
# IHQ
# (1062, "Duplicate entry 'KR7175330000' for key 'PRIMARY'")
# JB Financial Group Co., Ltd.
# (1062, "Duplicate entry 'KR7234080000' for key 'PRIMARY'")
# JW LIFESCIENCE
# (1062, "Duplicate entry 'KR7001061001' for key 'PRIMARY'")
# JWPHARMACEUTICAL(1P)
# (1062, "Duplicate entry 'KR7001062009' for key 'PRIMARY'")
# JWPHARMACEUTICAL(2PB)
# (1062, "Duplicate entry 'KR7001060003' for key 'PRIMARY'")
# JWPHARMACEUTICAL
# (1062, "Duplicate entry 'KR7096760004' for key 'PRIMARY'")
# JW HOLDINGS CORPORATION
# (1062, "Duplicate entry 'KR7105560007' for key 'PRIMARY'")
# KB Financial Group
# (1062, "Duplicate entry 'KR7024120008' for key 'PRIMARY'")
# KB Autosys Co.,Ltd
# (1062, "Duplicate entry 'KR7009070004' for key 'PRIMARY'")
# KCTC
# (1062, "Duplicate entry 'KR7044180008' for key 'PRIMARY'")
# KD Corporation
# (1062, "Duplicate entry 'KR7016381006' for key 'PRIMARY'")
# KG DONGBUSTEEL(1P)
# (1062, "Duplicate entry 'KR7016380008' for key 'PRIMARY'")
# KG DONGBUSTEEL
# (1062, "Duplicate entry 'KR7001390004' for key 'PRIMARY'")
# KG Chemical
# (1062, "Duplicate entry 'KR7033180001' for key 'PRIMARY'")
# KH FEELUX Co.,Ltd.
# (1062, "Duplicate entry 'KR7001940006' for key 'PRIMARY'")
# KISCO Holdings
# (1062, "Duplicate entry 'KR7025000001' for key 'PRIMARY'")
# KPXCHEMICAL
# (1062, "Duplicate entry 'KR7092230002' for key 'PRIMARY'")
# KPXHOLDINGS
# (1062, "Duplicate entry 'KR7000040006' for key 'PRIMARY'")
# KR MOTORS
# (1062, "Duplicate entry 'KR7093050003' for key 'PRIMARY'")
# LF
# (1062, "Duplicate entry 'KR7003551009' for key 'PRIMARY'")
# LG Corp.(1P)
# (1062, "Duplicate entry 'KR7034220004' for key 'PRIMARY'")
# LG Display
# (1062, "Duplicate entry 'KR7003550001' for key 'PRIMARY'")
# LG Corp.
# (1062, "Duplicate entry 'KR7051901007' for key 'PRIMARY'")
# LGHOUSEHOLD&HEALTHCARE,LTD(1P)
# (1062, "Duplicate entry 'KR7051900009' for key 'PRIMARY'")
# LGHOUSEHOLD&HEALTHCARE,LTD
# (1062, "Duplicate entry 'KR7373220003' for key 'PRIMARY'")
# LG Energy Solution
# (1062, "Duplicate entry 'KR7032640005' for key 'PRIMARY'")
# LG Uplus
# (1062, "Duplicate entry 'KR7011070000' for key 'PRIMARY'")
# LG Innotek
# (1062, "Duplicate entry 'KR7066571001' for key 'PRIMARY'")
# LGELECTRONICS(1P)
# (1062, "Duplicate entry 'KR7066570003' for key 'PRIMARY'")
# LGELECTRONICS
# (1062, "Duplicate entry 'KR7051911006' for key 'PRIMARY'")
# LGCHEM,LTD(1P)
# (1062, "Duplicate entry 'KR7051910008' for key 'PRIMARY'")
# LGCHEM,LTD
# (1062, "Duplicate entry 'KR7079550000' for key 'PRIMARY'")
# LIG Nex1 Co., Ltd.
# (1062, "Duplicate entry 'KR7010120004' for key 'PRIMARY'")
# LS ELECTRIC
# (1062, "Duplicate entry 'KR7000680009' for key 'PRIMARY'")
# LSNetworks
# (1062, "Duplicate entry 'KR7006260004' for key 'PRIMARY'")
# LS
# (1062, "Duplicate entry 'KR7001120005' for key 'PRIMARY'")
# LX INTERNATIONAL CORP.
# (1062, "Duplicate entry 'KR7023150006' for key 'PRIMARY'")
# MHETHANOL
# (1062, "Duplicate entry 'KR7035420009' for key 'PRIMARY'")
# NAVER
# (1062, "Duplicate entry 'KR7181710005' for key 'PRIMARY'")
# NHN
# (1062, "Duplicate entry 'KR7338100001' for key 'PRIMARY'")
# NH Prime REIT
# (1062, "Duplicate entry 'KR7034310003' for key 'PRIMARY'")
# NICEHoldings
# (1062, "Duplicate entry 'KR7008260002' for key 'PRIMARY'")
# NI STEEL
# (1062, "Duplicate entry 'KR7004251005' for key 'PRIMARY'")
# NPC(1P)
# (1062, "Duplicate entry 'KR7004250007' for key 'PRIMARY'")
# NPC
# (1062, "Duplicate entry 'KR7010060002' for key 'PRIMARY'")
# OCI
# (1062, "Duplicate entry 'KR7010951002' for key 'PRIMARY'")
# S-Oil(1P)
# (1062, "Duplicate entry 'KR7010950004' for key 'PRIMARY'")
# S-OilCorporation
# (1062, "Duplicate entry 'KR8392070007' for key 'PRIMARY'")
# SBI FinTech Solutions Co., Ltd.
# (1062, "Duplicate entry 'KR7005090006' for key 'PRIMARY'")
# SGC Energy
# (1062, "Duplicate entry 'KR7001380005' for key 'PRIMARY'")
# SG GLOBAL
# (1062, "Duplicate entry 'KR7001770007' for key 'PRIMARY'")
# SHIN HWA DYNAMICS
# (1062, "Duplicate entry 'KR7002360006' for key 'PRIMARY'")
# SH ENERGY & CHEMICAL
# (1062, "Duplicate entry 'KR7009160003' for key 'PRIMARY'")
# SIMPACInc
# (1062, "Duplicate entry 'KR7123700007' for key 'PRIMARY'")
# SJM CO.,LTD
# (1062, "Duplicate entry 'KR7025530007' for key 'PRIMARY'")
# SJM HOLDINGS
# (1062, "Duplicate entry 'KR703473K016' for key 'PRIMARY'")
# SK(1P)
# (1062, "Duplicate entry 'KR7011790003' for key 'PRIMARY'")
# SKC
# (1062, "Duplicate entry 'KR7018670000' for key 'PRIMARY'")
# SKGas
# (1062, "Duplicate entry 'KR7001741008' for key 'PRIMARY'")
# SKNetworksCo.,Ltd(1P)
# (1062, "Duplicate entry 'KR7001740000' for key 'PRIMARY'")
# SKNetworksCo.,Ltd
# (1062, "Duplicate entry 'KR7210980009' for key 'PRIMARY'")
# SK D&D Co., Ltd
# (1062, "Duplicate entry 'KR7395400005' for key 'PRIMARY'")
# SK REIT
# (1062, "Duplicate entry 'KR7034730002' for key 'PRIMARY'")
# SK
# (1062, "Duplicate entry 'KR7402340004' for key 'PRIMARY'")
# SKSQUARE
# (1062, "Duplicate entry 'KR7361610009' for key 'PRIMARY'")
# SK ie technology
# (1062, "Duplicate entry 'KR7096771001' for key 'PRIMARY'")
# SK Innovation(1P)
# (1062, "Duplicate entry 'KR7096770003' for key 'PRIMARY'")
# SK Innovation
# (1062, "Duplicate entry 'KR7001511005' for key 'PRIMARY'")
# SKSecurities(1P)
# (1062, "Duplicate entry 'KR7001510007' for key 'PRIMARY'")
# SKSecurities
# (1062, "Duplicate entry 'KR728513K010' for key 'PRIMARY'")
# SKCHEMICALS(1P)
# (1062, "Duplicate entry 'KR7285130001' for key 'PRIMARY'")
# SKCHEMICALS
# (1062, "Duplicate entry 'KR7017670001' for key 'PRIMARY'")
# SKTelecom
# (1062, "Duplicate entry 'KR7064960008' for key 'PRIMARY'")
# SNT MOTIV
# (1062, "Duplicate entry 'KR7100840008' for key 'PRIMARY'")
# SNTEnergy Co.,Ltd.
# (1062, "Duplicate entry 'KR7003570009' for key 'PRIMARY'")
# SNT DYNAMICS
# (1062, "Duplicate entry 'KR7036530004' for key 'PRIMARY'")
# SNT Holdings
# (1062, "Duplicate entry 'KR7005610001' for key 'PRIMARY'")
# SPC SAMLIP
# (1062, "Duplicate entry 'KR7011810009' for key 'PRIMARY'")
# STX
# (1062, "Duplicate entry 'KR7077970002' for key 'PRIMARY'")
# STXEngineCo.,Ltd
# (1062, "Duplicate entry 'KR7071970008' for key 'PRIMARY'")
# STX Heavy Industries
# (1062, "Duplicate entry 'KR7084870005' for key 'PRIMARY'")
# TBH GLOBAL
# (1062, "Duplicate entry 'KR7002710002' for key 'PRIMARY'")
# TCC STEEL
# (1062, "Duplicate entry 'KR7024070005' for key 'PRIMARY'")
# WISCOM
# (1062, "Duplicate entry 'KR7079940003' for key 'PRIMARY'")
# GABIA, Inc.
# (1062, "Duplicate entry 'KR7078890001' for key 'PRIMARY'")
# KAON Media Co., Ltd.
# (1062, "Duplicate entry 'KR7000500009' for key 'PRIMARY'")
# GAONCABLE
# (1062, "Duplicate entry 'KR7036620003' for key 'PRIMARY'")
# GAMSUNG Corporation
# (1062, "Duplicate entry 'KR7000860007' for key 'PRIMARY'")
# KANGNAM JEVISCO
# (1062, "Duplicate entry 'KR7217730001' for key 'PRIMARY'")
# KANGSTEM BIOTECH CO., LTD.
# (1062, "Duplicate entry 'KR7035250000' for key 'PRIMARY'")
# Kangwon Land, Inc.
# (1062, "Duplicate entry 'KR7114190002' for key 'PRIMARY'")
# KANGWON ENERGY
# (1062, "Duplicate entry 'KR7094480001' for key 'PRIMARY'")
# GalaxiaMoneytree Co.,Ltd.
# (1062, "Duplicate entry 'KR7011420007' for key 'PRIMARY'")
# GALAXIA SM
# (1062, "Duplicate entry 'KR7039240007' for key 'PRIMARY'")
# Kyeong Nam Steel Co., LTD
# (1062, "Duplicate entry 'KR7053950002' for key 'PRIMARY'")
# KYUNG NAM PHARM.CO.,LTD.
# (1062, "Duplicate entry 'KR7002100006' for key 'PRIMARY'")
# Kyungnong
# (1062, "Duplicate entry 'KR7009450008' for key 'PRIMARY'")
# KYUNGDONGNAVIEN
# (1062, "Duplicate entry 'KR7267290005' for key 'PRIMARY'")
# KYUNGDONG CITY GAS
# (1062, "Duplicate entry 'KR7012320008' for key 'PRIMARY'")
# KYUNGDONG INVEST
# (1062, "Duplicate entry 'KR7011040003' for key 'PRIMARY'")
# KyungdongPharm
# (1062, "Duplicate entry 'KR7000050005' for key 'PRIMARY'")
# Kyungbang
# (1062, "Duplicate entry 'KR7214390007' for key 'PRIMARY'")
# KYONGBO PHARMACEUTICAL CO., LTD.
# (1062, "Duplicate entry 'KR7012610002' for key 'PRIMARY'")
# KyunginSynthetic
# (1062, "Duplicate entry 'KR7009140005' for key 'PRIMARY'")
# KyunginElectronics
# (1062, "Duplicate entry 'KR7024910002' for key 'PRIMARY'")
# KyungchangIndustrial
# (1062, "Duplicate entry 'KR7013580006' for key 'PRIMARY'")
# KyeryongConstructionIndustrial
# (1062, "Duplicate entry 'KR7012201000' for key 'PRIMARY'")
# KeyangElectricMachinery(1P)
# (1062, "Duplicate entry 'KR7012200002' for key 'PRIMARY'")
# KeyangElectricMachinery
# (1062, "Duplicate entry 'KR7002140002' for key 'PRIMARY'")
# KoreaIndustrial
# (1062, "Duplicate entry 'KR7198440000' for key 'PRIMARY'")
# KOREA CEMENT co., Ltd.
# (1062, "Duplicate entry 'KR7049720006' for key 'PRIMARY'")
# KORYO CREDIT INFORMATION CO., LTD.
# (1062, "Duplicate entry 'KR7010130003' for key 'PRIMARY'")
# KoreaZinc
# (1062, "Duplicate entry 'KR7002240000' for key 'PRIMARY'")
# KISWire
# (1062, "Duplicate entry 'KR7014570006' for key 'PRIMARY'")
# KOREAN DRUG CO., LTD.
# (1062, "Duplicate entry 'KR7348150004' for key 'PRIMARY'")
# KoBioLabs, Inc
# (1062, "Duplicate entry 'KR7098460009' for key 'PRIMARY'")
# Koh Young Technology Inc.
# (1062, "Duplicate entry 'KR7035290006' for key 'PRIMARY'")
# Gold&S
# (1062, "Duplicate entry 'KR7038530002' for key 'PRIMARY'")
# Gold Pacific Co.,Ltd
# (1062, "Duplicate entry 'KR7215000001' for key 'PRIMARY'")
# GOLFZON Co., Ltd.
# (1062, "Duplicate entry 'KR7121440002' for key 'PRIMARY'")
# GOLFZON NEWDIN HOLDINGS Co., Ltd.
# (1062, "Duplicate entry 'KR7183410000' for key 'PRIMARY'")
# GolfzonDeca
# (1062, "Duplicate entry 'KR7366030005' for key 'PRIMARY'")
# 09women Co., Ltd.
# (1062, "Duplicate entry 'KR7076340009' for key 'PRIMARY'")
# GWANAK CONSTRUCTION AND EQUIPMENT SERVICE
# (1062, "Duplicate entry 'KR7009290008' for key 'PRIMARY'")
# KwangdongPharmaceutical
# (1062, "Duplicate entry 'KR7014200000' for key 'PRIMARY'")
# KANGLIM Co., LTD.
# (1062, "Duplicate entry 'KR7017040007' for key 'PRIMARY'")
# KWANG MYUNG ELECTRIC
# (1062, "Duplicate entry 'KR7029480001' for key 'PRIMARY'")
# Kwangmu
# (1062, "Duplicate entry 'KR7017900002' for key 'PRIMARY'")
# AUK
# (1062, "Duplicate entry 'KR7037710001' for key 'PRIMARY'")
# GwangjuShinsegae
# (1062, "Duplicate entry 'KR7026910000' for key 'PRIMARY'")
# KwangjinInd
# (1062, "Duplicate entry 'KR7355150004' for key 'PRIMARY'")
# Kyobo 10 Special Purpose Acquisition Company
# (1062, "Duplicate entry 'KR7397880006' for key 'PRIMARY'")
# Kyobo 11 Special Purpose Acquisition Company
# (1062, "Duplicate entry 'KR7331520007' for key 'PRIMARY'")
# Kyobo 9 Special Purpose Acquisition Company
# (1062, "Duplicate entry 'KR7030610000' for key 'PRIMARY'")
# KYOBOSECURITIESCO.,LTD.
# (1062, "Duplicate entry 'KR7339770000' for key 'PRIMARY'")
# KYOCHON FOOD&BEVERAGE
# (1062, "Duplicate entry 'KR7053270005' for key 'PRIMARY'")
# GUYOUNGTECHNOLOGY COMPANY LIMITED
# (1062, "Duplicate entry 'KR7007690001' for key 'PRIMARY'")
# KukdoChemical
# (1062, "Duplicate entry 'KR7005320007' for key 'PRIMARY'")
# Kukdong
# (1062, "Duplicate entry 'KR7066620006' for key 'PRIMARY'")
# KUKBO DESIGN
# (1062, "Duplicate entry 'KR7001140003' for key 'PRIMARY'")
# KUKBO
# (1062, "Duplicate entry 'KR7043650001' for key 'PRIMARY'")
# KOOK SOON DANG CO., LTD.
# (1062, "Duplicate entry 'KR7006050009' for key 'PRIMARY'")
# KUK YOUNG G&M
# (1062, "Duplicate entry 'KR7060480001' for key 'PRIMARY'")
# KUKIL METAL CO., LTD
# (1062, "Duplicate entry 'KR7078130002' for key 'PRIMARY'")
# KUK-IL PAPER MFG CO.,LTD
# (1062, "Duplicate entry 'KR7307750000' for key 'PRIMARY'")
# KUKJEON PHARMACEUTICAL Co.,Ltd
# (1062, "Duplicate entry 'KR7002720001' for key 'PRIMARY'")
# Kukje Pharma
# (1062, "Duplicate entry 'KR7243870003' for key 'PRIMARY'")
# Goodcen
# (1062, "Duplicate entry 'KR7114090004' for key 'PRIMARY'")
# Grand Korea Leisure
# (1062, "Duplicate entry 'HK0000307485' for key 'PRIMARY'")
# Great Rich Technologies Limited
# (1062, "Duplicate entry 'KR7204020002' for key 'PRIMARY'")
# GRITEE, Inc.
# (1062, "Duplicate entry 'KR7083420000' for key 'PRIMARY'")
# GREEN CHEMICAL
# (1062, "Duplicate entry 'KR7186230009' for key 'PRIMARY'")
# GREEN PLUS Co., Ltd
# (1062, "Duplicate entry 'KR7014530000' for key 'PRIMARY'")
# KukdongOil&Chem.
# (1062, "Duplicate entry 'KR7083450007' for key 'PRIMARY'")
# Global Standard Technology Co., Ltd.
# (1062, "Duplicate entry 'KYG3931T1076' for key 'PRIMARY'")
# Global SM Tech Limited
# (1062, "Duplicate entry 'KR7204620009' for key 'PRIMARY'")
# Global Tax Free Co., Ltd.
# (1062, "Duplicate entry 'KR7019660000' for key 'PRIMARY'")
# GLOBON CO., LTD.
# (1062, "Duplicate entry 'KR7014281000' for key 'PRIMARY'")
# KUMKANG KIND(1P)
# (1062, "Duplicate entry 'KR7014280002' for key 'PRIMARY'")
# KUMKANG KIND
# (1062, "Duplicate entry 'KR7053260006' for key 'PRIMARY'")
# KEUM KANG STEEL CO., LTD
# (1062, "Duplicate entry 'KR7008870008' for key 'PRIMARY'")
# Kumbi
# (1062, "Duplicate entry 'KR7001570001' for key 'PRIMARY'")
# Kumyang
# (1062, "Duplicate entry 'KR7002991008' for key 'PRIMARY'")
# KUMHOE&C(1P)
# (1062, "Duplicate entry 'KR7002990000' for key 'PRIMARY'")
# KUMHOE&C
# (1062, "Duplicate entry 'KR7011781002' for key 'PRIMARY'")
# KumhoPetrochemical(1P)
# (1062, "Duplicate entry 'KR7011780004' for key 'PRIMARY'")
# KumhoPetrochemical
# (1062, "Duplicate entry 'KR7214330003' for key 'PRIMARY'")
# Kumho HT, Inc.
# (1062, "Duplicate entry 'KR7001210004' for key 'PRIMARY'")
# KumhoElectric
# (1062, "Duplicate entry 'KR7073240004' for key 'PRIMARY'")
# KUMHOTIRECO.,INC
# (1062, "Duplicate entry 'KR7036190007' for key 'PRIMARY'")
# GEUMHWA PSC CO.,LTD.
# (1062, "Duplicate entry 'KR7049080005' for key 'PRIMARY'")
# GIGALANE Co., Ltd.
# (1062, "Duplicate entry 'KR7035460005' for key 'PRIMARY'")
# Kisan Telecom CO.,Ltd
# (1062, "Duplicate entry 'KR7092440007' for key 'PRIMARY'")
# KISHIN CORPORATION
# (1062, "Duplicate entry 'KR7000270009' for key 'PRIMARY'")
# KIA CORPORATION
# (1062, "Duplicate entry 'KR7013700000' for key 'PRIMARY'")
# CAMUS ENGINEERING & CONSTRUCTION Inc.
# (1062, "Duplicate entry 'KR7308100007' for key 'PRIMARY'")
# Castelbajac Co., Ltd.
# (1062, "Duplicate entry 'KR7004541009' for key 'PRIMARY'")
# KleanNara(1P)
# (1062, "Duplicate entry 'KR7004540001' for key 'PRIMARY'")
# KleanNara
# (1062, "Duplicate entry 'KR7187790001' for key 'PRIMARY'")
# NANO. Co., Ltd.
# (1062, "Duplicate entry 'KR7286750005' for key 'PRIMARY'")
# NANOBRICK Co., Ltd.
# (1062, "Duplicate entry 'KR7151910007' for key 'PRIMARY'")
# NANOS Co.,Ltd.
# (1062, "Duplicate entry 'KR7121600001' for key 'PRIMARY'")
# Advanced Nano Products Co.,Ltd
# (1062, "Duplicate entry 'KR7247660004' for key 'PRIMARY'")
# NANOCMS CO.,LTD
# (1062, "Duplicate entry 'KR7039860002' for key 'PRIMARY'")
# NanoenTek,Inc.
# (1062, "Duplicate entry 'KR7091970004' for key 'PRIMARY'")
# Nano Chem Tech Inc.
# (1062, "Duplicate entry 'KR7244880001' for key 'PRIMARY'")
# NANOOM
# (1062, "Duplicate entry 'KR7288490006' for key 'PRIMARY'")
# NARASOFT
# (1062, "Duplicate entry 'KR7051490001' for key 'PRIMARY'")
# NARA MOLD & DIE CO., LTD.
# (1062, "Duplicate entry 'KR7137080008' for key 'PRIMARY'")
# NARAE NANOTECH CORPORATION
# (1062, "Duplicate entry 'KR7190510008' for key 'PRIMARY'")
# Namuga Co.,Ltd
# (1062, "Duplicate entry 'KR7242040004' for key 'PRIMARY'")
# NAMU TECH CO.,LTD.
# (1062, "Duplicate entry 'KR7089600001' for key 'PRIMARY'")
# Nasmedia Co., Ltd.
# (1062, "Duplicate entry 'KR7293580007' for key 'PRIMARY'")
# NAU IB Capital
# (1062, "Duplicate entry 'KR7257990002' for key 'PRIMARY'")
# NOWCOS
# (1062, "Duplicate entry 'KR7138610001' for key 'PRIMARY'")
# NIBEC CO., LTD.
# (1062, "Duplicate entry 'KR7130580004' for key 'PRIMARY'")
# NICE D&B CO., LTD.
# (1062, "Duplicate entry 'KR7036800001' for key 'PRIMARY'")
# NICE INFORMATION&TELECOMMUNICATION INC.
# (1062, "Duplicate entry 'KR7030190003' for key 'PRIMARY'")
# NICE Information Service Co., Ltd.
# (1062, "Duplicate entry 'KR7267320000' for key 'PRIMARY'")
# Naintech. CO.,LTD.
# (1062, "Duplicate entry 'KR7001260009' for key 'PRIMARY'")
# NamkwangEngineering&Construction
# (1062, "Duplicate entry 'KR7008351009' for key 'PRIMARY'")
# NamsunAluminium(1P)
# (1062, "Duplicate entry 'KR7008350001' for key 'PRIMARY'")
# NamsunAluminium
# (1062, "Duplicate entry 'KR7004270005' for key 'PRIMARY'")
# Namsung
# (1062, "Duplicate entry 'KR7003921004' for key 'PRIMARY'")
# NamyangDairyProducts(1P)
# (1062, "Duplicate entry 'KR7003920006' for key 'PRIMARY'")
# NamyangDairyProducts
# (1062, "Duplicate entry 'KR7025860008' for key 'PRIMARY'")
# NamhaeChemical
# (1062, "Duplicate entry 'KR7111710000' for key 'PRIMARY'")
# Namhwa Industrial Co.,Ltd
# (1062, "Duplicate entry 'KR7091590000' for key 'PRIMARY'")
# Nam Hwa Construction Company, Limited
# (1062, "Duplicate entry 'KR7168330009' for key 'PRIMARY'")
# Naturalendo Tech Co., Ltd
# (1062, "Duplicate entry 'KR7094860004' for key 'PRIMARY'")
# NEORIGIN
# (1062, "Duplicate entry 'KR7253590004' for key 'PRIMARY'")
# Neosem Inc.
# (1062, "Duplicate entry 'KR7212560007' for key 'PRIMARY'")
# NEOOTO Co., Ltd.
# (1062, "Duplicate entry 'KR7095660007' for key 'PRIMARY'")
# NEOWIZ
# (1062, "Duplicate entry 'KR7042420000' for key 'PRIMARY'")
# NEOWIZ HOLDINDS Corporation
# (1062, "Duplicate entry 'KR8840140006' for key 'PRIMARY'")
# NeoImmuneTech, Inc.
# (1062, "Duplicate entry 'KR7311390009' for key 'PRIMARY'")
# Neo Cremar Co., Ltd.
# (1062, "Duplicate entry 'KR7085910008' for key 'PRIMARY'")
# NEO TECHNICAL SYSTEM CO., LTD
# (1062, "Duplicate entry 'KR7092730001' for key 'PRIMARY'")
# Neopharm CO., LTD.
# (1062, "Duplicate entry 'KR7290660000' for key 'PRIMARY'")
# NEOFECT Co.,Ltd
# (1062, "Duplicate entry 'KR7306620006' for key 'PRIMARY'")
# Neontech Co., Ltd.
# (1062, "Duplicate entry 'KR7153460001' for key 'PRIMARY'")
# Nable Communications, Inc.
# (1062, "Duplicate entry 'KR7007390008' for key 'PRIMARY'")
# NATURECELL CO.,LTD.
# (1062, "Duplicate entry 'KR7086220001' for key 'PRIMARY'")
# Natural F&P
# (1062, "Duplicate entry 'KR7033640004' for key 'PRIMARY'")
# NEPES Corporation
# (1062, "Duplicate entry 'KR7330860008' for key 'PRIMARY'")
# Nepes Ark Corporation
# (1062, "Duplicate entry 'KR7005721006' for key 'PRIMARY'")
# NEXEN(1P)
# (1062, "Duplicate entry 'KR7005720008' for key 'PRIMARY'")
# NEXEN
# (1062, "Duplicate entry 'KR7002351005' for key 'PRIMARY'")
# NEXENTIRE(1PB)
# (1062, "Duplicate entry 'KR7002350007' for key 'PRIMARY'")
# NEXENTIRE
# (1062, "Duplicate entry 'KR7089140008' for key 'PRIMARY'")
# NEXTURNBIOSCIENCE
# (1062, "Duplicate entry 'KR7065170003' for key 'PRIMARY'")
# NEXT BT Co., LTD.
# (1062, "Duplicate entry 'KR7003580008' for key 'PRIMARY'")
# NEXT SCIENCE
# (1062, "Duplicate entry 'KR7137940003' for key 'PRIMARY'")
# NextEye Co., Ltd.
# (1062, "Duplicate entry 'KR7160550000' for key 'PRIMARY'")
# Next Entertainment World Co., Ltd.
# (1062, "Duplicate entry 'KR7348210006' for key 'PRIMARY'")
# NEXTIN Inc.
# (1062, "Duplicate entry 'KR7041140005' for key 'PRIMARY'")
# Nexon GT Co., Ltd.
# (1062, "Duplicate entry 'KR7217270008' for key 'PRIMARY'")
# Neptune Company
# (1062, "Duplicate entry 'KR7225570001' for key 'PRIMARY'")
# NAT GAMES Co., Ltd.
# (1062, "Duplicate entry 'KR7251270005' for key 'PRIMARY'")
# Netmarble Corporation
# (1062, "Duplicate entry 'KR7317860005' for key 'PRIMARY'")
# Nordmason
# (1062, "Duplicate entry 'KR7104620000' for key 'PRIMARY'")
# Yellow Balloon Tour Co., Ltd.
# (1062, "Duplicate entry 'KR7090351008' for key 'PRIMARY'")
# NOROO PAINT(1P)
# (1062, "Duplicate entry 'KR7090350000' for key 'PRIMARY'")
# NOROO PAINT
# (1062, "Duplicate entry 'KR7000321000' for key 'PRIMARY'")
# NorooHoldings(1P)
# (1062, "Duplicate entry 'KR7000320002' for key 'PRIMARY'")
# NorooHoldings
# (1062, "Duplicate entry 'KR7194700001' for key 'PRIMARY'")
# NOVAREX Co., Ltd.
# (1062, "Duplicate entry 'KR7285490009' for key 'PRIMARY'")
# NOVATECH
# (1062, "Duplicate entry 'KR7229500004' for key 'PRIMARY'")
# NOVMETAPHARMA
# (1062, "Duplicate entry 'KR7106520000' for key 'PRIMARY'")
# Noble M&B
# (1062, "Duplicate entry 'KR7376930004' for key 'PRIMARY'")
# Noul Co., Ltd.
# (1062, "Duplicate entry 'KR7278650007' for key 'PRIMARY'")
# KNOTUS Co.,Ltd.
# (1062, "Duplicate entry 'KR7006280002' for key 'PRIMARY'")
# Green Cross Corporation
# (1062, "Duplicate entry 'KR7142280007' for key 'PRIMARY'")
# Green Cross Medical Science Corporation
# (1062, "Duplicate entry 'KR7234690006' for key 'PRIMARY'")
# GREEN CROSS WellBeing Corporation
# (1062, "Duplicate entry 'KR7005252002' for key 'PRIMARY'")
# Green Cross Holdings Corporation(2PB)
# (1062, "Duplicate entry 'KR7005250006' for key 'PRIMARY'")
# Green Cross Holdings Corporation
# (1062, "Duplicate entry 'KR7065560005' for key 'PRIMARY'")
# Nokwon Commercials & Industries, Inc.
# (1062, "Duplicate entry 'KR7004370003' for key 'PRIMARY'")
# Nongshim
# (1062, "Duplicate entry 'KR7072710007' for key 'PRIMARY'")
# NongshimHoldings
# (1062, "Duplicate entry 'KR7154030001' for key 'PRIMARY'")
# ASIA SEED Co.,Ltd.
# (1062, "Duplicate entry 'KR7054050000' for key 'PRIMARY'")
# NONG WOO BIO CO.,LTD.
# (1062, "Duplicate entry 'KR7069140002' for key 'PRIMARY'")
# Nuriplan Co., Ltd
# (1062, "Duplicate entry 'KR7040160004' for key 'PRIMARY'")
# NuriFlex
# (1062, "Duplicate entry 'KR7332290006' for key 'PRIMARY'")
# NOUSBO
# (1062, "Duplicate entry 'KR7126870005' for key 'PRIMARY'")
# NEUROS Co., Ltd.
# (1062, "Duplicate entry 'KR7060260007' for key 'PRIMARY'")
# NUVOTEC Co., Ltd
# (1062, "Duplicate entry 'KR7012340006' for key 'PRIMARY'")
# NUIN TEK CO., LTD
# (1062, "Duplicate entry 'KR7214870008' for key 'PRIMARY'")
# NewGLAB Pharma
# (1062, "Duplicate entry 'KR7270870009' for key 'PRIMARY'")
# Newtree Co., Ltd.
# (1062, "Duplicate entry 'KR7144960002' for key 'PRIMARY'")
# New Power Plasma Co.,Ltd
# (1062, "Duplicate entry 'KR7085670008' for key 'PRIMARY'")
# NEWFLEX TECHNOLOGY Co., LTD.
# (1062, "Duplicate entry 'KR7119860005' for key 'PRIMARY'")
# DANAWA Co., Ltd
# (1062, "Duplicate entry 'KR7064260003' for key 'PRIMARY'")
# DANAL CO., LTD.
# (1062, "Duplicate entry 'KR7093640001' for key 'PRIMARY'")
# Tamul Multimedia, Co., Ltd.
# (1062, "Duplicate entry 'KR7340360007' for key 'PRIMARY'")
# DAVOLINK
# (1062, "Duplicate entry 'KR7039560008' for key 'PRIMARY'")
# DASAN Networks, Inc.
# (1062, "Duplicate entry 'KR7058730003' for key 'PRIMARY'")
# Development Advance Solution
# (1062, "Duplicate entry 'KR7298870007' for key 'PRIMARY'")
# Daol Investment
# (1062, "Duplicate entry 'KR7030210009' for key 'PRIMARY'")
# Daol Investment & Securities
# (1062, "Duplicate entry 'KR7023590003' for key 'PRIMARY'")
# DaouTechnology
# (1062, "Duplicate entry 'KR7032190001' for key 'PRIMARY'")
# DAOU DATA CORP.
# (1062, "Duplicate entry 'KR7323350009' for key 'PRIMARY'")
# DAWON NEXVIEW
# (1062, "Duplicate entry 'KR7068240001' for key 'PRIMARY'")
# DAWONSYS Co., LTD
# (1062, "Duplicate entry 'KR7145210001' for key 'PRIMARY'")
# Dynamic Design
# (1062, "Duplicate entry 'KR7271850000' for key 'PRIMARY'")
# DIOGENE
# (1062, "Duplicate entry 'KR7343090007' for key 'PRIMARY'")
# DanDiBio
# (1062, "Duplicate entry 'KR7019680008' for key 'PRIMARY'")
# DAEKYO
# (1062, "Duplicate entry 'KR7019681006' for key 'PRIMARY'")
# DAEKYO(1PB)
# (1062, "Duplicate entry 'KR7006370001' for key 'PRIMARY'")
# DaeguDepartmentStore
# (1062, "Duplicate entry 'KR700806K010' for key 'PRIMARY'")
# DAEDUCK Co.,LTD(1P)
# (1062, "Duplicate entry 'KR7008060006' for key 'PRIMARY'")
# DAEDUCK Co.,LTD
# (1062, "Duplicate entry 'KR7353200009' for key 'PRIMARY'")
# DaeduckElectronics
# (1062, "Duplicate entry 'KR735320K011' for key 'PRIMARY'")
# DaeduckElectronics(1P)
# (1062, "Duplicate entry 'KR7178600003' for key 'PRIMARY'")
# DAEDONG KOREA GINSENG CO.,LTD.
# (1062, "Duplicate entry 'KR7020400008' for key 'PRIMARY'")
# DaedongMetal
# (1062, "Duplicate entry 'KR7008830002' for key 'PRIMARY'")
# DaedongGear
# (1062, "Duplicate entry 'KR7000490003' for key 'PRIMARY'")
# DAEDONG CORPORATION
# (1062, "Duplicate entry 'KR7048470009' for key 'PRIMARY'")
# DAE DONG STEEL CO., LTD.
# (1062, "Duplicate entry 'KR7008110009' for key 'PRIMARY'")
# DAIDONGElECTRONICS
# (1062, "Duplicate entry 'KR7004780003' for key 'PRIMARY'")
# DaeryukCan
# (1062, "Duplicate entry 'KR7005750005' for key 'PRIMARY'")
# DAELIM B&Co
# (1062, "Duplicate entry 'KR7017650003' for key 'PRIMARY'")
# DaelimPaper
# (1062, "Duplicate entry 'KR7006570006' for key 'PRIMARY'")
# DaelimTrading
# (1062, "Duplicate entry 'KR7007720006' for key 'PRIMARY'")
# DAEMYUNG SONOSEASON CO.,LTD.
# (1062, "Duplicate entry 'KR7317850006' for key 'PRIMARY'")
# DAEMO Engineering Co.,Ltd.
# (1062, "Duplicate entry 'KR7290670009' for key 'PRIMARY'")
# DAEBO MAGNETIC CO.,LTD.
# (1062, "Duplicate entry 'KR7078140001' for key 'PRIMARY'")
# Daebongls co., Ltd
# (1062, "Duplicate entry 'KR7001681006' for key 'PRIMARY'")
# Daesang(1P)
# (1062, "Duplicate entry 'KR7001680008' for key 'PRIMARY'")
# Daesang
# (1062, "Duplicate entry 'KR7084691005' for key 'PRIMARY'")
# Daesang Holdings(1P)
# (1062, "Duplicate entry 'KR7084690007' for key 'PRIMARY'")
# Daesang Holdings
# (1062, "Duplicate entry 'KR7036480002' for key 'PRIMARY'")
# Daesung Microbiological Labs. Co., Ltd.
# (1062, "Duplicate entry 'KR7128820008' for key 'PRIMARY'")
# DAESUNG INDUSTRIAL
# (1062, "Duplicate entry 'KR7117580001' for key 'PRIMARY'")
# DAESUNG ENERGY
# (1062, "Duplicate entry 'KR7025440009' for key 'PRIMARY'")
# DAESUNG ELTEC CO., LTD.
# (1062, "Duplicate entry 'KR7027830009' for key 'PRIMARY'")
# Daesung Private Equity, Inc.
# (1062, "Duplicate entry 'KR7104040001' for key 'PRIMARY'")
# Daesung Fine Tech. Co., Ltd
# (1062, "Duplicate entry 'KR7016710006' for key 'PRIMARY'")
# DAESUNG HOLDINGS
# (1406, "Data too long for column 'ISU_ENG_NM' at row 1")
# Daishin Balance No.10 Special Purpose Acquisition Company
# (1406, "Data too long for column 'ISU_ENG_NM' at row 1")
# Daishin Balance No.11 Special Purpose Acquisition Company
# (1406, "Data too long for column 'ISU_ENG_NM' at row 1")
# Daishin Balance No.8 Special Purpose Acquisition Company
# (1062, "Duplicate entry 'KR7020180006' for key 'PRIMARY'")
# DaishinInformation
# (1062, "Duplicate entry 'KR7003541000' for key 'PRIMARY'")
# DaishinSecurities(1P)
# (1062, "Duplicate entry 'KR7003542008' for key 'PRIMARY'")
# DAISHINSECURITIES(2PB)
# (1062, "Duplicate entry 'KR7003540002' for key 'PRIMARY'")
# DaishinSecurities
# (1062, "Duplicate entry 'KR7045390002' for key 'PRIMARY'")
# DAEA TI CO., LTD.
# (1062, "Duplicate entry 'KR7009190000' for key 'PRIMARY'")
# DaiyangMetal
# (1062, "Duplicate entry 'KR7108380007' for key 'PRIMARY'")
# DAYANG ELECTRIC CO.,LTD
# (1062, "Duplicate entry 'KR7006580005' for key 'PRIMARY'")
# DaeyangPaperMfg
# (1062, "Duplicate entry 'KR7014160006' for key 'PRIMARY'")
# DaeyoungPackaging
# (1062, "Duplicate entry 'KR7047040001' for key 'PRIMARY'")
# DaewooEngineering&Construction
# (1062, "Duplicate entry 'KR7009320003' for key 'PRIMARY'")
# DAEWOO ELECTRONIC COMPONENTS
# (1062, "Duplicate entry 'KR7042660001' for key 'PRIMARY'")
# DAEWOOSHIPBUILDING&MARINEENGINEERING
# (1062, "Duplicate entry 'KR7003090008' for key 'PRIMARY'")
# Daewoong
# (1062, "Duplicate entry 'KR7069620003' for key 'PRIMARY'")
# DAEWOONGPHARMACEUTICAL
# (1062, "Duplicate entry 'KR7007680002' for key 'PRIMARY'")
# DAEWON CO., LTD.
# (1062, "Duplicate entry 'KR7000430009' for key 'PRIMARY'")
# DaewonKangup
# (1062, "Duplicate entry 'KR7048910004' for key 'PRIMARY'")
# DAEWON MEDIA CO.,LTD.
# (1062, "Duplicate entry 'KR7005710009' for key 'PRIMARY'")
# Daewonsanup
# (1062, "Duplicate entry 'KR7006341002' for key 'PRIMARY'")
# DaewonCable(1P)
# (1062, "Duplicate entry 'KR7006340004' for key 'PRIMARY'")
# DaewonCable
# (1062, "Duplicate entry 'KR7003220001' for key 'PRIMARY'")
# DaewonPharmaceutical
# (1062, "Duplicate entry 'KR7024890006' for key 'PRIMARY'")
# DaewonChemical
# (1062, "Duplicate entry 'KR7290380005' for key 'PRIMARY'")
# Dae Yu Co., Ltd.
# (1062, "Duplicate entry 'KR7002880003' for key 'PRIMARY'")
# DAYOU AUTOMOTIVE SEAT TECHNOLOGY CO.,LTD
# (1062, "Duplicate entry 'KR7290120005' for key 'PRIMARY'")
# Dayou AP Co.,Ltd.
# (1062, "Duplicate entry 'KR7000300004' for key 'PRIMARY'")
# DAYOUPLUS
# (1062, "Duplicate entry 'KR7120240007' for key 'PRIMARY'")
# Daejung Chemicals & Metals Co., Ltd.
# (1062, "Duplicate entry 'KR7003310000' for key 'PRIMARY'")
# Daejoo Inc.
# (1062, "Duplicate entry 'KR7114920002' for key 'PRIMARY'")
# Daejoo Energy INnovation Technology Co.,Ltd
# (1062, "Duplicate entry 'KR7078600004' for key 'PRIMARY'")
# Daejoo Electronic Materials Co., Ltd.
# (1062, "Duplicate entry 'KR7015230006' for key 'PRIMARY'")
# DaechangForging
# (1062, "Duplicate entry 'KR7012800009' for key 'PRIMARY'")
# DAECHANG
# (1062, "Duplicate entry 'KR7096350004' for key 'PRIMARY'")
# DAECHANG SOLUTION CO.,LTD.
# (1062, "Duplicate entry 'KR7140520008' for key 'PRIMARY'")
# DaeChang Steel CO., LTD.
# (1062, "Duplicate entry 'KR7131220006' for key 'PRIMARY'")
# DAIHAN SCIENTIFIC CO., Ltd
# (1062, "Duplicate entry 'KR7010170009' for key 'PRIMARY'")
# TAIHAN Fiberoptics Co.,LTD
# (1062, "Duplicate entry 'KR7060900008' for key 'PRIMARY'")
# Daehan Green Power Corporation
# (1062, "Duplicate entry 'KR7054670005' for key 'PRIMARY'")
# DAEHAN NEW PHARM CO., LTD.
# (1062, "Duplicate entry 'KR7001070002' for key 'PRIMARY'")
# TaihanTextile
# (1062, "Duplicate entry 'KR7023910003' for key 'PRIMARY'")
# DaihanPharmaceutical
# (1062, "Duplicate entry 'KR7006650006' for key 'PRIMARY'")
# KOREA PETRO CHEMICAL IND
# (1062, "Duplicate entry 'KR7001440007' for key 'PRIMARY'")
# TaihanElectricWire
# (1062, "Duplicate entry 'KR7084010008' for key 'PRIMARY'")
# Daehan Steel Co. Ltd.
# (1062, "Duplicate entry 'KR7001791003' for key 'PRIMARY'")
# TS(1P)
# (1062, "Duplicate entry 'KR7001790005' for key 'PRIMARY'")
# TS
# (1062, "Duplicate entry 'KR7001130004' for key 'PRIMARY'")
# DaehanFlourMill
# (1062, "Duplicate entry 'KR7003491008' for key 'PRIMARY'")
# KoreanAirLines(1P)
# (1062, "Duplicate entry 'KR7003490000' for key 'PRIMARY'")
# KoreanAirLines
# (1062, "Duplicate entry 'KR7005880000' for key 'PRIMARY'")
# KoreaLine
# (1062, "Duplicate entry 'KR7003830007' for key 'PRIMARY'")
# DaehanSyntheticFibrer
# (1062, "Duplicate entry 'KR7016090003' for key 'PRIMARY'")
# Daehyun
# (1062, "Duplicate entry 'KR7069460004' for key 'PRIMARY'")
# DAEHOAL
# (1062, "Duplicate entry 'KR7021040001' for key 'PRIMARY'")
# dhSteel
# (1062, "Duplicate entry 'KR7021041009' for key 'PRIMARY'")
# dhSteel(1P)
# (1062, "Duplicate entry 'KR7067080002' for key 'PRIMARY'")
# DAE HWA PHARM CO., LTD
# (1062, "Duplicate entry 'KR7161570007' for key 'PRIMARY'")
# THE MIDONG Co,. Ltd
# (1062, "Duplicate entry 'KR7298540006' for key 'PRIMARY'")
# THE NATURE HOLDINGS CO., LTD
# (1062, "Duplicate entry 'KR7192080000' for key 'PRIMARY'")
# DoubleUGames
# (1062, "Duplicate entry 'KR7073570004' for key 'PRIMARY'")
# WI Co.,Ltd.
# (1062, "Duplicate entry 'KR7299170001' for key 'PRIMARY'")
# WSI Co., Ltd.
# (1062, "Duplicate entry 'KR7192410009' for key 'PRIMARY'")
# The HQ
# (1062, "Duplicate entry 'KR7089230007' for key 'PRIMARY'")
# THE E&M Co., Ltd.
# (1062, "Duplicate entry 'KR7012510004' for key 'PRIMARY'")
# DOUZONE BIZON
# (1062, "Duplicate entry 'KR7302920004' for key 'PRIMARY'")
# TCO
# (1062, "Duplicate entry 'KR7213420003' for key 'PRIMARY'")
# DUK SAN NEOLUX CO.,LTD
# (1062, "Duplicate entry 'KR7317330009' for key 'PRIMARY'")
# Duksan Techopia Co., Ltd.
# (1062, "Duplicate entry 'KR7077360006' for key 'PRIMARY'")
# DUK SAN HI METAL CO.,LTD.
# (1062, "Duplicate entry 'KR7004831004' for key 'PRIMARY'")
# Duksung(1P)
# (1062, "Duplicate entry 'KR7004830006' for key 'PRIMARY'")
# Duksung
# (1062, "Duplicate entry 'KR7090410002' for key 'PRIMARY'")
# DUCKSHIN HOUSING CO., LTD.
# (1062, "Duplicate entry 'KR7024900003' for key 'PRIMARY'")
# DuckYangIndustry
# (1062, "Duplicate entry 'KR7263600009' for key 'PRIMARY'")
# DERKWOO ELECTRONICS CO.,LTD.
# (1062, "Duplicate entry 'KR7194480000' for key 'PRIMARY'")
# Devsisters corporation
# (1062, "Duplicate entry 'KR7348840000' for key 'PRIMARY'")
# Daydream
# (1062, "Duplicate entry 'KR7263800005' for key 'PRIMARY'")
# Datasolution, Inc.
# (1062, "Duplicate entry 'KR7199150004' for key 'PRIMARY'")
# Data Streams Corp.
# (1062, "Duplicate entry 'KR7206560005' for key 'PRIMARY'")
# Dexter studios Co., Ltd.
# (1062, "Duplicate entry 'KR7261200000' for key 'PRIMARY'")
# DENTIS CO.,LTD
# (1062, "Duplicate entry 'KR7145720009' for key 'PRIMARY'")
# DENTIUM
# (1062, "Duplicate entry 'KR7227420007' for key 'PRIMARY'")
# DOBU MASK
# (1062, "Duplicate entry 'KR7067990002' for key 'PRIMARY'")
# DEUTSCH MOTORS INC.
# (1062, "Duplicate entry 'KR7002150001' for key 'PRIMARY'")
# DOHWA ENGINEERING
# (1062, "Duplicate entry 'KR7006620009' for key 'PRIMARY'")
# DongKoo Bio & Pharma Co., Ltd.
# (1062, "Duplicate entry 'KR7005160007' for key 'PRIMARY'")
# DONGKUK INDUSTRIES COMPANY
# (1062, "Duplicate entry 'KR7075970004' for key 'PRIMARY'")
# DONGKUK REFRACTORIES & STEEL CO., LTD.
# (1062, "Duplicate entry 'KR7100130004' for key 'PRIMARY'")
# DONGKUK STRUCTURES & CONSTRUCTION COMPANY LIMITED
# (1062, "Duplicate entry 'KR7001230002' for key 'PRIMARY'")
# DongkukSteelMill
# (1062, "Duplicate entry 'KR7086450004' for key 'PRIMARY'")
# DongKook Pharmaceutical Co.,Ltd.
# (1062, "Duplicate entry 'KR7004140000' for key 'PRIMARY'")
# DongbangTransport&Logistics
# (1062, "Duplicate entry 'KR7099410003' for key 'PRIMARY'")
# Dongbang Ship Machinery Co., Ltd
# (1062, "Duplicate entry 'KR7007590003' for key 'PRIMARY'")
# DongbangAgro
# (1062, "Duplicate entry 'KR7005961008' for key 'PRIMARY'")
# Dongbu(1P)
# (1062, "Duplicate entry 'KR7005960000' for key 'PRIMARY'")
# Dongbu Corporation
# (1062, "Duplicate entry 'KR7026960005' for key 'PRIMARY'")
# DONGSUH
# (1062, "Duplicate entry 'KR7002210003' for key 'PRIMARY'")
# DongsungPharmaceutical
# (1062, "Duplicate entry 'KR7102260007' for key 'PRIMARY'")
# DONGSUNG CHEMICAL Co., Ltd.
# (1062, "Duplicate entry 'KR7033500000' for key 'PRIMARY'")
# DONGSUNG FINETEC CO., Ltd
# (1062, "Duplicate entry 'KR7025950007' for key 'PRIMARY'")
# DongshinEngineering&Construction
# (1062, "Duplicate entry 'KR7000640003' for key 'PRIMARY'")
# Dong-A Socio Holdings
# (1062, "Duplicate entry 'KR7170900005' for key 'PRIMARY'")
# Donga ST
# (1062, "Duplicate entry 'KR7088130000' for key 'PRIMARY'")
# DONG A ELTEK Co., Ltd
# (1062, "Duplicate entry 'KR7028100006' for key 'PRIMARY'")
# Dong-Ah Geological Engineering Company
# (1062, "Duplicate entry 'KR7282690007' for key 'PRIMARY'")
# DONG AH TIRE
# (1062, "Duplicate entry 'KR7041930009' for key 'PRIMARY'")
# DONG-A HWA SUNG CO.,LTD
# (1062, "Duplicate entry 'KR7001521004' for key 'PRIMARY'")
# TONGYANG(1P)
# (1062, "Duplicate entry 'KR7001522002' for key 'PRIMARY'")
# TONGYANG(2PB)
# (1062, "Duplicate entry 'KR7001523000' for key 'PRIMARY'")
# TONGYANG(3PB)
# (1062, "Duplicate entry 'KR7084670009' for key 'PRIMARY'")
# DONGYANG EXPRESS CORP.
# (1062, "Duplicate entry 'KR7001520006' for key 'PRIMARY'")
# TONGYANG
# (1062, "Duplicate entry 'KR7082640004' for key 'PRIMARY'")
# TONGYANG LIFE INSURANCE
# (1062, "Duplicate entry 'KR7060380003' for key 'PRIMARY'")
# Dongyang S·TEC Co., Ltd.
# (1062, "Duplicate entry 'KR7079960001' for key 'PRIMARY'")
# DONGYANG E&P INC.
# (1062, "Duplicate entry 'KR7008970006' for key 'PRIMARY'")
# DongyangSteelPipe
# (1062, "Duplicate entry 'KR7228340006' for key 'PRIMARY'")
# TONGYANG PILE, Inc.
# (1062, "Duplicate entry 'KR7092780006' for key 'PRIMARY'")
# DONGYANG PISTON
# (1062, "Duplicate entry 'KR7088910005' for key 'PRIMARY'")
# DONGWOO FARM TO TABLE CO., LTD
# (1062, "Duplicate entry 'KR7094170008' for key 'PRIMARY'")
# DONGWOON ANATECH CO.,LTD.
# (1062, "Duplicate entry 'KR7049770001' for key 'PRIMARY'")
# DongwonF&B Co.,Ltd.
# (1062, "Duplicate entry 'KR7013120001' for key 'PRIMARY'")
# DongwonDevelopment
# (1062, "Duplicate entry 'KR7018500009' for key 'PRIMARY'")
# DONGWON METAL
# (1062, "Duplicate entry 'KR7006040000' for key 'PRIMARY'")
# DongwonIndustries
# (1062, "Duplicate entry 'KR7030720007' for key 'PRIMARY'")
# DongwonFisheries
# (1062, "Duplicate entry 'KR7014821003' for key 'PRIMARY'")
# Dongwon Systems Corporation(1P)
# (1062, "Duplicate entry 'KR7014820005' for key 'PRIMARY'")
# Dongwon Systems Corporation
# (1062, "Duplicate entry 'KR7163560006' for key 'PRIMARY'")
# DRB Industrial
# (1062, "Duplicate entry 'KR7109860007' for key 'PRIMARY'")
# DONGIL METAL CO., LTD.
# (1062, "Duplicate entry 'KR7032960007' for key 'PRIMARY'")
# DongilTechnology
# (1062, "Duplicate entry 'KR7004890000' for key 'PRIMARY'")
# DONGILINDUSTRIESCO.,LTD
# (1062, "Duplicate entry 'KR7002690006' for key 'PRIMARY'")
# DONG IL STEEL MFG CO., LTD
# (1062, "Duplicate entry 'KR7023790009' for key 'PRIMARY'")
# DongilSteel
# (1062, "Duplicate entry 'KR7005290002' for key 'PRIMARY'")
# DONGJIN SEMICHEM CO., LTD.
# (1062, "Duplicate entry 'KR7025900002' for key 'PRIMARY'")
# DONGWHA ENTERPRISE CO., LTD.
# (1062, "Duplicate entry 'KR7000020008' for key 'PRIMARY'")
# DongwhaPharm
# (1062, "Duplicate entry 'KR7000151001' for key 'PRIMARY'")
# DOOSAN(1P)
# (1062, "Duplicate entry 'KR7000152009' for key 'PRIMARY'")
# DOOSAN(2PB)
# (1062, "Duplicate entry 'KR7241560002' for key 'PRIMARY'")
# Doosan Bobcat
# (1062, "Duplicate entry 'KR7000150003' for key 'PRIMARY'")
# DOOSAN
# (1062, "Duplicate entry 'KR7034020008' for key 'PRIMARY'")
# DoosanHeavyIndustriesandConstruction
# (1062, "Duplicate entry 'KR733626K013' for key 'PRIMARY'")
# Doosan Fuel Cell(1P)
# (1062, "Duplicate entry 'KR733626K021' for key 'PRIMARY'")
# Doosan Fuel Cell(2PB)
# (1062, "Duplicate entry 'KR7336260005' for key 'PRIMARY'")
# Doosan Fuel Cell
# (1062, "Duplicate entry 'KR7016740003' for key 'PRIMARY'")
# DUAL
# (1062, "Duplicate entry 'KR7073190001' for key 'PRIMARY'")
# DUOBACK CO., LTD.
# (1062, "Duplicate entry 'KR7176750008' for key 'PRIMARY'")
# DuChemBio Co.,LTD.
# (1062, "Duplicate entry 'KR7030350003' for key 'PRIMARY'")
# Dragonfly GF Co., Ltd.
# (1062, "Duplicate entry 'KR7203650007' for key 'PRIMARY'")
# Dream Security Co.,Ltd.
# (1062, "Duplicate entry 'KR7223250002' for key 'PRIMARY'")
# DreamCIS INC.
# (1062, "Duplicate entry 'KR7060570009' for key 'PRIMARY'")
# Dreamus Company
# (1062, "Duplicate entry 'KR7192650000' for key 'PRIMARY'")
# DREAMTECH
# (1062, "Duplicate entry 'KR7217620004' for key 'PRIMARY'")
# Didim Inc.
# (1062, "Duplicate entry 'KR7187870001' for key 'PRIMARY'")
# Device ENG CO.,Ltd
# (1406, "Data too long for column 'ISU_ENG_NM' at row 1")
# DB Finance No.10 Special Purpose Acquisition Co., Ltd.
# (1406, "Data too long for column 'ISU_ENG_NM' at row 1")
# DB Finance No.8 Special Purpose Acquisition Co., Ltd.
# (1406, "Data too long for column 'ISU_ENG_NM' at row 1")
# DB Finance No.9 Special Purpose Acquisition Co., Ltd.
# (1062, "Duplicate entry 'KR7066670001' for key 'PRIMARY'")
# Display Tech Co.,Ltd
# (1062, "Duplicate entry 'KR7024090003' for key 'PRIMARY'")
# DCMCorp.
# (1062, "Duplicate entry 'KR7003160009' for key 'PRIMARY'")
# DI
# (1062, "Duplicate entry 'KR7092200005' for key 'PRIMARY'")
# DAE-IL Corporation
# (1062, "Duplicate entry 'KR7110990009' for key 'PRIMARY'")
# Digital Imaging Technology, Inc.
# (1062, "Duplicate entry 'KR7078590007' for key 'PRIMARY'")
# DIAC
# (1062, "Duplicate entry 'KR7004840005' for key 'PRIMARY'")
# DRB Holding Co.,Ltd
# (1062, "Duplicate entry 'KR7263690000' for key 'PRIMARY'")
# DRGEM CORPORATION
# (1062, "Duplicate entry 'KR7214680001' for key 'PRIMARY'")
# DRTECH Corporation
# (1062, "Duplicate entry 'KR7377190004' for key 'PRIMARY'")
# D&D platform REIT
# (1062, "Duplicate entry 'KR7263720005' for key 'PRIMARY'")
# D&C MEDIA CO.,LTD.
# (1062, "Duplicate entry 'KR7376300000' for key 'PRIMARY'")
# DEAR U Co.,Ltd.
# (1062, "Duplicate entry 'KR7241520006' for key 'PRIMARY'")
# DSC Investment Inc.
# (1062, "Duplicate entry 'KR7109740001' for key 'PRIMARY'")
# DSK Co.,Ltd.
# (1062, "Duplicate entry 'KR7131030009' for key 'PRIMARY'")
# DHP KOREA.CO., Ltd
# (1062, "Duplicate entry 'KR7196490007' for key 'PRIMARY'")
# DA Technology Co.,Ltd.
# (1062, "Duplicate entry 'KR7066900002' for key 'PRIMARY'")
# DAP Co., Ltd
# (1062, "Duplicate entry 'KR7180400004' for key 'PRIMARY'")
# Dx & Vx
# (1062, "Duplicate entry 'KR7127120004' for key 'PRIMARY'")
# DNA Link, Inc
# (1062, "Duplicate entry 'KR7092070002' for key 'PRIMARY'")
# DNF Co., Ltd.
# (1062, "Duplicate entry 'KR7068790005' for key 'PRIMARY'")
# DMS Co.,Ltd.
# (1062, "Duplicate entry 'KR7039840004' for key 'PRIMARY'")
# DIO Corporation
# (1062, "Duplicate entry 'KR7219550001' for key 'PRIMARY'")
# DYD
# (1062, "Duplicate entry 'KR7013570007' for key 'PRIMARY'")
# DY Corporation
# (1062, "Duplicate entry 'KR7310870001' for key 'PRIMARY'")
# DYC
# (1062, "Duplicate entry 'KR7210540001' for key 'PRIMARY'")
# DY POWER Corporation
# (1062, "Duplicate entry 'KR7104460001' for key 'PRIMARY'")
# DYPNF CO.,LTD
# (1062, "Duplicate entry 'KR7079810008' for key 'PRIMARY'")
# DE&T Co., Ltd.
# (1062, "Duplicate entry 'KR7113810006' for key 'PRIMARY'")
# Dgenx Co., Ltd.
# (1062, "Duplicate entry 'KR7043360007' for key 'PRIMARY'")
# Digital Graphics Incorporation
# (1062, "Duplicate entry 'KR7197140007' for key 'PRIMARY'")
# DigiCAP
# (1062, "Duplicate entry 'KR7068930007' for key 'PRIMARY'")
# Digital Daesung Co., Ltd.
# (1062, "Duplicate entry 'KR7033130006' for key 'PRIMARY'")
# DigitalChosun
# (1062, "Duplicate entry 'KR7105740005' for key 'PRIMARY'")
# DK-Lok Corporation
# (1062, "Duplicate entry 'KR7263020000' for key 'PRIMARY'")
# DK&D
# (1062, "Duplicate entry 'KR7290550003' for key 'PRIMARY'")
# DK Tech Co., Ltd.
# (1062, "Duplicate entry 'KR7007340003' for key 'PRIMARY'")
# DTR AUTOMOTIVE CORPORATION
# (1062, "Duplicate entry 'KR7187220009' for key 'PRIMARY'")
# DT&C.co.,ltd.
# (1062, "Duplicate entry 'KR7163430002' for key 'PRIMARY'")
# DPECO
# (1062, "Duplicate entry 'KR7131180002' for key 'PRIMARY'")
# DILLI ILLUSTRATE INC.,
# (1062, "Duplicate entry 'KR7315640003' for key 'PRIMARY'")
# DEEPNOID Inc.
# (1062, "Duplicate entry 'KR7317120004' for key 'PRIMARY'")
# RANIX INC.
# (1062, "Duplicate entry 'KR7042510008' for key 'PRIMARY'")
# RaonSecure Co., Ltd.
# (1062, "Duplicate entry 'KR7232680009' for key 'PRIMARY'")
# RAONTEC Inc.
# (1062, "Duplicate entry 'KR7300120003' for key 'PRIMARY'")
# LaonPeople Inc.
# (1062, "Duplicate entry 'KR7171120009' for key 'PRIMARY'")
# LION CHEMTECH CO., Ltd.
# (1062, "Duplicate entry 'KR7069540003' for key 'PRIMARY'")
# LIGHTRON INC.
# (1062, "Duplicate entry 'KR7285770004' for key 'PRIMARY'")
# Life Science Technology
# (1062, "Duplicate entry 'KR7347700007' for key 'PRIMARY'")
# Life Semantics Corp.
# (1062, "Duplicate entry 'KR7214260002' for key 'PRIMARY'")
# Raphas Co., Ltd.
# (1062, "Duplicate entry 'KR7115390007' for key 'PRIMARY'")
# LOCK&LOCK CO.,LTD.
# (1062, "Duplicate entry 'KR7200350007' for key 'PRIMARY'")
# RaemongRaein.Co.,Ltd
# (1062, "Duplicate entry 'KR7171010002' for key 'PRIMARY'")
# RAM TECHNOLOGY CO., LTD.
# (1062, "Duplicate entry 'KR7084650001' for key 'PRIMARY'")
# LabGenomics. Co., Ltd.
# (1062, "Duplicate entry 'KR7217500008' for key 'PRIMARY'")
# RUSSELL CO., LTD.
# (1062, "Duplicate entry 'KR7092590009' for key 'PRIMARY'")
# Luxpia
# (1062, "Duplicate entry 'KR7141080002' for key 'PRIMARY'")
# LegoChem Biosciences Inc.
# (1062, "Duplicate entry 'KR7060300001' for key 'PRIMARY'")
# REDROVER CO.,LTD
# (1062, "Duplicate entry 'KR7038390001' for key 'PRIMARY'")
# RedcapTour Co., Ltd.
# (1062, "Duplicate entry 'KR7294140009' for key 'PRIMARY'")
# LEMON COMPANY LIMITED
# (1062, "Duplicate entry 'KR7228670006' for key 'PRIMARY'")
# Ray Co., Ltd.
# (1062, "Duplicate entry 'KR7228850004' for key 'PRIMARY'")
# RAYENCE CO., LTD.
# (1062, "Duplicate entry 'KR7281740001' for key 'PRIMARY'")
# Lake Materials Co., Ltd.
# (1062, "Duplicate entry 'KR7277810008' for key 'PRIMARY'")
# Rainbow Robotics
# (1062, "Duplicate entry 'KR7179720008' for key 'PRIMARY'")
# LendingMachine Co., Ltd.
# (1062, "Duplicate entry 'KR7215100009' for key 'PRIMARY'")
# RoboRobo Co., Ltd.
# (1062, "Duplicate entry 'KR7090360009' for key 'PRIMARY'")
# Robostar Co.,Ltd.
# (1062, "Duplicate entry 'KR7238500003' for key 'PRIMARY'")
# Robo3
# (1062, "Duplicate entry 'KR7108490004' for key 'PRIMARY'")
# ROBOTIS
# (1062, "Duplicate entry 'HK0000295359' for key 'PRIMARY'")
# Rothwell International Co., Limited
# (1062, "Duplicate entry 'KR7223220005' for key 'PRIMARY'")
# Logis Mon
# (1062, "Duplicate entry 'KR7067730002' for key 'PRIMARY'")
# LOGISYS INC.
# (1062, "Duplicate entry 'KR7071280002' for key 'PRIMARY'")
# RORZE SYSTEMS CORPORATION
# (1062, "Duplicate entry 'KR7032350001' for key 'PRIMARY'")
# LOTTE TOUR DEVELOPMENT CO., LTD
# (1062, "Duplicate entry 'KR7089860001' for key 'PRIMARY'")
# LOTTE rental
# (1062, "Duplicate entry 'KR7330590001' for key 'PRIMARY'")
# LOTTE REIT
# (1062, "Duplicate entry 'KR7000400002' for key 'PRIMARY'")
# LotteNon-LifeInsurance
# (1062, "Duplicate entry 'KR7023530009' for key 'PRIMARY'")
# LOTTE SHOPPING CO., LTD.
# (1062, "Duplicate entry 'KR7004000006' for key 'PRIMARY'")
# LOTTE Fine Chemical
# (1062, "Duplicate entry 'KR7286940002' for key 'PRIMARY'")
# LOTTE DATA COMMUNICATION COMPANY
# (1062, "Duplicate entry 'KR7280360009' for key 'PRIMARY'")
# LOTTE CONF
# (1062, "Duplicate entry 'KR700499K014' for key 'PRIMARY'")
# Lotte Corporation(1P)
# (1062, "Duplicate entry 'KR7004990008' for key 'PRIMARY'")
# Lotte Corporation
# (1062, "Duplicate entry 'KR7005301007' for key 'PRIMARY'")
# LotteChilsungBeverage(1P)
# (1062, "Duplicate entry 'KR7005300009' for key 'PRIMARY'")
# LotteChilsungBeverage
# (1062, "Duplicate entry 'KR7011170008' for key 'PRIMARY'")
# LOTTE CHEMICAL CORPORATION
# (1062, "Duplicate entry 'KR7002270007' for key 'PRIMARY'")
# LotteFood
# (1062, "Duplicate entry 'KR7071840003' for key 'PRIMARY'")
# LOTTE Himart
# (1062, "Duplicate entry 'KR7038060000' for key 'PRIMARY'")
# LUMENS CO., LTD.
# (1062, "Duplicate entry 'KR7162120000' for key 'PRIMARY'")
# LUKEN Technologies
# (1062, "Duplicate entry 'KR7253610000' for key 'PRIMARY'")
# Rootloc
# (1062, "Duplicate entry 'KR7085370005' for key 'PRIMARY'")
# Lutronic Corporation
# (1062, "Duplicate entry 'KR708537K039' for key 'PRIMARY'")
# Lutronic(3PC)
# (1062, "Duplicate entry 'KR7060240009' for key 'PRIMARY'")
# LONGTU KOREA Inc.
# (1062, "Duplicate entry 'KR7058470006' for key 'PRIMARY'")
# LEENO Industrial Inc
# (1062, "Duplicate entry 'KR7039980008' for key 'PRIMARY'")
# LEENOS CORP.
# (1062, "Duplicate entry 'KR7019570001' for key 'PRIMARY'")
# Leaders Technology Investment Co.,Ltd
# (1062, "Duplicate entry 'KR7016100000' for key 'PRIMARY'")
# LEADERS COSMETICS CO.,LTD.
# (1062, "Duplicate entry 'KR7012700001' for key 'PRIMARY'")
# The LEADCORP, Inc.
# (1062, "Duplicate entry 'KR7302550009' for key 'PRIMARY'")
# REMED CO.,LTD.
# (1062, "Duplicate entry 'KR7377450002' for key 'PRIMARY'")
# REFINE Co., Ltd
# ...
# CUBIC KOREA INC.
# (1062, "Duplicate entry 'KR7161390000' for key 'PRIMARY'")
# HANKOOK TIRE & TECHNOLOGY
# (1062, "Duplicate entry 'KR7053590006' for key 'PRIMARY'")
# HANKOOK Technology Inc.
# (1062, "Duplicate entry 'KR7034830000' for key 'PRIMARY'")
# KOREIT
# (1406, "Data too long for column 'ISU_ENG_NM' at row 1")
# KIM ANKOR Oilfield Overseas Resources Development Fund[1]
# (1406, "Data too long for column 'ISU_ENG_NM' at row 1")
# KIM Parallel Oilfield Overseas Resources Development Fund[1]
# (1062, "Duplicate entry 'KR7071051007' for key 'PRIMARY'")
# KOREA INVESTMENT HOLDINGS(1P)
# (1062, "Duplicate entry 'KR7071050009' for key 'PRIMARY'")
# KOREA INVESTMENT HOLDINGS
# (1062, "Duplicate entry 'KR7007280001' for key 'PRIMARY'")
# KOREA STEEL
# (1062, "Duplicate entry 'KR7032300006' for key 'PRIMARY'")
# KOREA PHARMA Co., Ltd.
# (1062, "Duplicate entry 'KR7037230000' for key 'PRIMARY'")
# HANKUK PACKAGE CO., LTD.
# (1062, "Duplicate entry 'KR7010100006' for key 'PRIMARY'")
# KoreaFlange
# (1062, "Duplicate entry 'KR7047810007' for key 'PRIMARY'")
# KOREA AEROSPACE INDUSTRIES
# (1062, "Duplicate entry 'KR7123690000' for key 'PRIMARY'")
# HANKOOKCOSMETICS
# (1062, "Duplicate entry 'KR7003350006' for key 'PRIMARY'")
# HankookCosmeticsManufacturing
# (1062, "Duplicate entry 'KR7030520001' for key 'PRIMARY'")
# HANCOM INC.
# (1062, "Duplicate entry 'KR7052600004' for key 'PRIMARY'")
# HANNET CO., LTD.
# (1062, "Duplicate entry 'KR7011500006' for key 'PRIMARY'")
# HANNONGCHEMICALSINC.
# (1062, "Duplicate entry 'KR7002390003' for key 'PRIMARY'")
# HANDOK Inc.
# (1062, "Duplicate entry 'KR7256150004' for key 'PRIMARY'")
# Handok Clean Tech Co., Ltd.
# (1062, "Duplicate entry 'KR7014790000' for key 'PRIMARY'")
# Halla Corporation
# (1062, "Duplicate entry 'KR7092460005' for key 'PRIMARY'")
# HANLA IMS Co., LTD
# (1062, "Duplicate entry 'KR7060980000' for key 'PRIMARY'")
# Halla Holdings Corporation
# (1062, "Duplicate entry 'KR7053690004' for key 'PRIMARY'")
# HanmiGlobal Co., Ltd
# (1062, "Duplicate entry 'KR7042700005' for key 'PRIMARY'")
# HANMISemiconductorCO.,Ltd.
# (1062, "Duplicate entry 'KR7008930000' for key 'PRIMARY'")
# Hanmi Science
# (1062, "Duplicate entry 'KR7128940004' for key 'PRIMARY'")
# HanmiPharm
# (1062, "Duplicate entry 'KR7047080007' for key 'PRIMARY'")
# HANBIT SOFT Inc.
# (1062, "Duplicate entry 'KR7009240003' for key 'PRIMARY'")
# HANSSEM CO.,LTD.
# (1062, "Duplicate entry 'KR7020000006' for key 'PRIMARY'")
# HandsomeCorporation
# (1062, "Duplicate entry 'KR7003680006' for key 'PRIMARY'")
# HansungEnterprise
# (1062, "Duplicate entry 'KR7105630008' for key 'PRIMARY'")
# HANSAE
# (1062, "Duplicate entry 'KR7069640001' for key 'PRIMARY'")
# HANSAEMK
# (1062, "Duplicate entry 'KR7016450009' for key 'PRIMARY'")
# HansaeYes24Holdings
# (1062, "Duplicate entry 'KR7010420008' for key 'PRIMARY'")
# HANSOLPNS
# (1062, "Duplicate entry 'KR7009180001' for key 'PRIMARY'")
# Hansol Logistics
# (1062, "Duplicate entry 'KR7070590005' for key 'PRIMARY'")
# Hansol Inticube Co., Ltd.
# (1062, "Duplicate entry 'KR7213500002' for key 'PRIMARY'")
# Hansol Paper Co., Ltd.
# (1062, "Duplicate entry 'KR7014680003' for key 'PRIMARY'")
# HansolChemical
# (1062, "Duplicate entry 'KR7004710000' for key 'PRIMARY'")
# HansolTechnics
# (1062, "Duplicate entry 'KR7004150009' for key 'PRIMARY'")
# Hansol Holdings
# (1062, "Duplicate entry 'KR7025750001' for key 'PRIMARY'")
# HansolHomeDeco
# (1062, "Duplicate entry 'KR7226440006' for key 'PRIMARY'")
# HANSONGNEOTECH CO.,LTD.
# (1062, "Duplicate entry 'KR7042520007' for key 'PRIMARY'")
# HANS BIOMED CORPORATION
# (1062, "Duplicate entry 'KR7004960001' for key 'PRIMARY'")
# HanshinConstruction
# (1062, "Duplicate entry 'KR7011700002' for key 'PRIMARY'")
# HanshinMachinery
# (1062, "Duplicate entry 'KR7078350006' for key 'PRIMARY'")
# HANYANG DIGITECH CO.,LTD.
# (1062, "Duplicate entry 'KR7045100005' for key 'PRIMARY'")
# HANYANG ENG CO.,LTD.
# (1062, "Duplicate entry 'KR7001751007' for key 'PRIMARY'")
# HanyangSecurities(1P)
# (1062, "Duplicate entry 'KR7001750009' for key 'PRIMARY'")
# HanyangSecurities
# (1062, "Duplicate entry 'KR7018880005' for key 'PRIMARY'")
# Hanon Systems
# (1062, "Duplicate entry 'KR7009420001' for key 'PRIMARY'")
# HANALL BIOPHARMA CO.,LTD
# (1062, "Duplicate entry 'KR7014130009' for key 'PRIMARY'")
# HanExpress
# (1062, "Duplicate entry 'KR7046110003' for key 'PRIMARY'")
# HANIL NETWORKS CO., LTD.
# (1062, "Duplicate entry 'KR7024740003' for key 'PRIMARY'")
# HanilForgingIndustrial
# (1062, "Duplicate entry 'KR7005860002' for key 'PRIMARY'")
# HANIL FEED Co.Ltd
# (1062, "Duplicate entry 'KR7300720000' for key 'PRIMARY'")
# HANILCEMENT
# (1062, "Duplicate entry 'KR7123840001' for key 'PRIMARY'")
# HANIL VACUUM CO., LTD.
# (1062, "Duplicate entry 'KR7002220002' for key 'PRIMARY'")
# HanilIron&Steel
# (1062, "Duplicate entry 'KR7006390009' for key 'PRIMARY'")
# HANIL HYUNDAI CEMENT
# (1062, "Duplicate entry 'KR7003300001' for key 'PRIMARY'")
# HANILHOLDINGS
# (1062, "Duplicate entry 'KR7007770001' for key 'PRIMARY'")
# HANIL CHEMICAL IND. CO., LTD
# (1062, "Duplicate entry 'KR7051600005' for key 'PRIMARY'")
# KEPCO Plant Service & Engineering
# (1062, "Duplicate entry 'KR7130660004' for key 'PRIMARY'")
# Korea Electric Power Industrial Development
# (1062, "Duplicate entry 'KR7107640005' for key 'PRIMARY'")
# HanJung Natural Connectivity System.co.,Ltd
# (1062, "Duplicate entry 'KR7002320000' for key 'PRIMARY'")
# HanjinTransportation
# (1062, "Duplicate entry 'KR7003480001' for key 'PRIMARY'")
# HanjinHeavyInd&ConstHoldings
# (1062, "Duplicate entry 'KR718064K016' for key 'PRIMARY'")
# HANJINKAL(1P)
# (1062, "Duplicate entry 'KR7180640005' for key 'PRIMARY'")
# HANJINKAL
# (1062, "Duplicate entry 'KR7043090000' for key 'PRIMARY'")
# HanChang Biotech
# (1062, "Duplicate entry 'KR7005110002' for key 'PRIMARY'")
# Hanchang
# (1062, "Duplicate entry 'KR7079170007' for key 'PRIMARY'")
# Hanchang Industry Co., Ltd.
# (1062, "Duplicate entry 'KR7009460007' for key 'PRIMARY'")
# HanchangPaper
# (1062, "Duplicate entry 'KR7086960002' for key 'PRIMARY'")
# Hancom MDS Inc.
# (1062, "Duplicate entry 'KR7372910000' for key 'PRIMARY'")
# Hancom Lifecare
# (1062, "Duplicate entry 'KR7054920004' for key 'PRIMARY'")
# Hancom WITH
# (1062, "Duplicate entry 'KR7002680007' for key 'PRIMARY'")
# Hantop Inc.
# (1062, "Duplicate entry 'KR7000881003' for key 'PRIMARY'")
# Hanwha(1P)
# (1062, "Duplicate entry 'KR700088K015' for key 'PRIMARY'")
# HANWHA(3PB)
# (1062, "Duplicate entry 'KR7000880005' for key 'PRIMARY'")
# Hanwha
# (1062, "Duplicate entry 'KR7088350004' for key 'PRIMARY'")
# HANWHA LIFE INSURANCE
# (1062, "Duplicate entry 'KR7000370007' for key 'PRIMARY'")
# Hanwha General Insurance Co.,Ltd.
# (1062, "Duplicate entry 'KR7009831009' for key 'PRIMARY'")
# HANWHA SOLUTIONS(1P)
# (1062, "Duplicate entry 'KR7009830001' for key 'PRIMARY'")
# HANWHA SOLUTIONS
# (1062, "Duplicate entry 'KR7272210006' for key 'PRIMARY'")
# HANWHA SYSTEMS
# (1062, "Duplicate entry 'KR7012450003' for key 'PRIMARY'")
# HANWHA AEROSPACE
# (1062, "Duplicate entry 'KR7003531001' for key 'PRIMARY'")
# HANWHA INVESTMENT & SECURITIES(1P)
# (1062, "Duplicate entry 'KR7003530003' for key 'PRIMARY'")
# HANWHA INVESTMENT & SECURITIES
# (1406, "Data too long for column 'ISU_ENG_NM' at row 1")
# Hanwha Plus No 2 Special Purpose Acquisition Company
# (1062, "Duplicate entry 'KR7195870001' for key 'PRIMARY'")
# HAESUNG DS
# (1062, "Duplicate entry 'KR7034810002' for key 'PRIMARY'")
# Haesung Industrial Co., Ltd.
# (1062, "Duplicate entry 'KR703481K019' for key 'PRIMARY'")
# Haesung Industrial Co., Ltd.(1P)
# (1062, "Duplicate entry 'KR7076610005' for key 'PRIMARY'")
# Haesung Optics Co.,Ltd
# (1062, "Duplicate entry 'KR7059270009' for key 'PRIMARY'")
# Haisung TPC Co., Ltd.
# (1062, "Duplicate entry 'KR7101530004' for key 'PRIMARY'")
# Haitai Confectionery and Foods Co., Ltd.
# (1062, "Duplicate entry 'KR7220180004' for key 'PRIMARY'")
# HANDYSOFT, Inc.
# (1062, "Duplicate entry 'KR7143210003' for key 'PRIMARY'")
# HANDS CORPORATION
# (1062, "Duplicate entry 'HK0000214814' for key 'PRIMARY'")
# HENG SHENG GROUP COMPANY LIMITED
# (1062, "Duplicate entry 'KR7084990001' for key 'PRIMARY'")
# Helixmith Co., Ltd
# (1062, "Duplicate entry 'KR7000721001' for key 'PRIMARY'")
# HyundaiEngineering&Construction(1P)
# (1062, "Duplicate entry 'KR7267270007' for key 'PRIMARY'")
# HYUNDAI CE
# (1062, "Duplicate entry 'KR7000720003' for key 'PRIMARY'")
# HyundaiEngineering&Construction
# (1062, "Duplicate entry 'KR7170030001' for key 'PRIMARY'")
# HYUNDAI INDUSTRIAL CO.,LTD
# (1062, "Duplicate entry 'KR7005440003' for key 'PRIMARY'")
# HYUNDAIGREENFOOD
# (1062, "Duplicate entry 'KR7086280005' for key 'PRIMARY'")
# HYUNDAIGLOVIS Co.,LTD
# (1062, "Duplicate entry 'KR7042670000' for key 'PRIMARY'")
# Hyundai Doosan Infracore
# (1062, "Duplicate entry 'KR7064350002' for key 'PRIMARY'")
# HYUNDAI ROTEM
# (1062, "Duplicate entry 'KR7079430005' for key 'PRIMARY'")
# HYUNDAILIVART
# (1062, "Duplicate entry 'KR7012330007' for key 'PRIMARY'")
# HyundaiMobis
# (1062, "Duplicate entry 'KR7319400008' for key 'PRIMARY'")
# HYUNDAI MOVEX
# (1062, "Duplicate entry 'KR7010620003' for key 'PRIMARY'")
# HyundaiMipoDockyard
# (1062, "Duplicate entry 'KR7052260007' for key 'PRIMARY'")
# HYUNDAI BIOLAND Co.,Ltd.
# (1062, "Duplicate entry 'KR7048410005' for key 'PRIMARY'")
# HYUNDAI BIOSCIENCE CO., LTD.
# (1062, "Duplicate entry 'KR7069960003' for key 'PRIMARY'")
# HYUNDAIDEPARTMENTSTORECO.,LTD
# (1062, "Duplicate entry 'KR7004561007' for key 'PRIMARY'")
# HYUNDAI BNG STEEL(1P)
# (1062, "Duplicate entry 'KR7004560009' for key 'PRIMARY'")
# HYUNDAI BNG STEEL
# (1062, "Duplicate entry 'KR7016790008' for key 'PRIMARY'")
# HYUNDAI FEED Inc.
# (1062, "Duplicate entry 'KR7004310009' for key 'PRIMARY'")
# Hyundai pharm
# (1062, "Duplicate entry 'KR7322000001' for key 'PRIMARY'")
# HYUNDAI ENERGY SOLUTIONS
# (1062, "Duplicate entry 'KR7041440009' for key 'PRIMARY'")
# HYUNDAI EVERDIGM
# (1062, "Duplicate entry 'KR7039010004' for key 'PRIMARY'")
# HYUNDAI HT
# (1062, "Duplicate entry 'KR7017800004' for key 'PRIMARY'")
# HyundaiElevator
# (1062, "Duplicate entry 'KR7307950006' for key 'PRIMARY'")
# HyundaiAutoever
# (1062, "Duplicate entry 'KR7011210002' for key 'PRIMARY'")
# HYUNDAI WIA
# (1062, "Duplicate entry 'KR7090850009' for key 'PRIMARY'")
# HYUNDAI EZWEL
# (1062, "Duplicate entry 'KR7267260008' for key 'PRIMARY'")
# HYUNDAI ELECTRIC
# (1062, "Duplicate entry 'KR7005381009' for key 'PRIMARY'")
# HyundaiMotor(1P)
# (1062, "Duplicate entry 'KR7005382007' for key 'PRIMARY'")
# HyundaiMotor(2PB)
# (1062, "Duplicate entry 'KR7005383005' for key 'PRIMARY'")
# HyundaiMotor(3PB)
# (1062, "Duplicate entry 'KR7005380001' for key 'PRIMARY'")
# HyundaiMotor
# (1062, "Duplicate entry 'KR7004020004' for key 'PRIMARY'")
# HYUNDAI STEEL
# (1062, "Duplicate entry 'KR7329180004' for key 'PRIMARY'")
# HYUNDAI HEAVY INDUSTRIES
# (1062, "Duplicate entry 'KR7267250009' for key 'PRIMARY'")
# HYUNDAI HEAVY INDUSTRIES HOLDINGS
# (1062, "Duplicate entry 'KR7001500008' for key 'PRIMARY'")
# HYUNDAI MOTOR SECURITIES
# (1062, "Duplicate entry 'KR7011760006' for key 'PRIMARY'")
# HYUNDAI CORPORATION
# (1062, "Duplicate entry 'KR7227840006' for key 'PRIMARY'")
# HYUNDAI CORPORATION HOLDINGS
# (1062, "Duplicate entry 'KR7126560002' for key 'PRIMARY'")
# Hyundai Futurenet
# (1062, "Duplicate entry 'KR7001450006' for key 'PRIMARY'")
# Hyundai MARINE & FIRE INSURANCE CO.,LTD
# (1062, "Duplicate entry 'KR7057050007' for key 'PRIMARY'")
# HYUNDAI HOME SHOPPING NETWORK CORPORATION
# (1062, "Duplicate entry 'KR7092300003' for key 'PRIMARY'")
# HYUNWOO INDUSTRIAL CO.,LTD
# (1062, "Duplicate entry 'KR7053660007' for key 'PRIMARY'")
# HYUNJIN MATERIALS CO., LTD.
# (1062, "Duplicate entry 'KR7138360003' for key 'PRIMARY'")
# Hyupjin
# (1062, "Duplicate entry 'KR7011080009' for key 'PRIMARY'")
# HYUNGJI Innovation and Creative Company Limited
# (1062, "Duplicate entry 'KR7093240000' for key 'PRIMARY'")
# HYUNGJI ELITE
# (1062, "Duplicate entry 'KR7003010006' for key 'PRIMARY'")
# HaeinCorporation
# (1062, "Duplicate entry 'KR7111110003' for key 'PRIMARY'")
# Hojeon
# (1062, "Duplicate entry 'KR7008771008' for key 'PRIMARY'")
# HotelShilla(1P)
# (1062, "Duplicate entry 'KR7008770000' for key 'PRIMARY'")
# HotelShilla
# (1062, "Duplicate entry 'KR7060560000' for key 'PRIMARY'")
# Home Center Holdings Co.,Ltd
# (1062, "Duplicate entry 'KR7064240005' for key 'PRIMARY'")
# homecast CO., LTD.
# (1062, "Duplicate entry 'KR7039610001' for key 'PRIMARY'")
# HS VALVE CO., LTD
# (1062, "Duplicate entry 'KR7002460004' for key 'PRIMARY'")
# HwasungIndustrial
# (1062, "Duplicate entry 'KR7378850002' for key 'PRIMARY'")
# HWASEUNG R&A CO., LTD.
# (1062, "Duplicate entry 'KR7241590009' for key 'PRIMARY'")
# HWASEUNG ENTERPRISE
# (1062, "Duplicate entry 'KR7006060008' for key 'PRIMARY'")
# HSIndustries
# (1062, "Duplicate entry 'KR7013520002' for key 'PRIMARY'")
# Hwaseung Corporation
# (1062, "Duplicate entry 'KR7010690006' for key 'PRIMARY'")
# Hwashin
# (1062, "Duplicate entry 'KR7126640002' for key 'PRIMARY'")
# HWASHIN PRECISION CO., LTD.
# (1062, "Duplicate entry 'KR7133820001' for key 'PRIMARY'")
# FINEBESTEEL
# (1062, "Duplicate entry 'KR7061250007' for key 'PRIMARY'")
# HWAIL PHARM. CO., LTD
# (1062, "Duplicate entry 'KR7010660009' for key 'PRIMARY'")
# HWACHEON MACHINERY
# (1062, "Duplicate entry 'KR7000850008' for key 'PRIMARY'")
# HwacheonMachineTool
# (1062, "Duplicate entry 'KR7016580003' for key 'PRIMARY'")
# WhaninPharm
# (1062, "Duplicate entry 'KR7032560005' for key 'PRIMARY'")
# Hwang Kum Steel & Technology
# (1062, "Duplicate entry 'KR7004800009' for key 'PRIMARY'")
# Hyosung
# (1062, "Duplicate entry 'KR7094280005' for key 'PRIMARY'")
# HYOSUNG ITX Co., Ltd.
# (1062, "Duplicate entry 'KR7097870000' for key 'PRIMARY'")
# Hyosung ONB Co., Ltd
# (1062, "Duplicate entry 'KR7298040007' for key 'PRIMARY'")
# HYOSUNG HEAVY INDUSTRIES
# (1062, "Duplicate entry 'KR7298050006' for key 'PRIMARY'")
# HYOSUNG ADVANCED MATERIALS
# (1062, "Duplicate entry 'KR7298020009' for key 'PRIMARY'")
# HYOSUNG TNC
# (1062, "Duplicate entry 'KR7298000001' for key 'PRIMARY'")
# HYOSUNG CHEMICAL
# (1062, "Duplicate entry 'KR7093370005' for key 'PRIMARY'")
# FOOSUNG CO.,LTD
# (1062, "Duplicate entry 'KR7050090000' for key 'PRIMARY'")
# PHOENIX MATERIALS CO., LTD.
# (1062, "Duplicate entry 'KR7081660003' for key 'PRIMARY'")
# Fila Holdings
# (1062, "Duplicate entry 'KR7290270008' for key 'PRIMARY'")
# Hunesion co.,ltd
# (1062, "Duplicate entry 'KR7005870001' for key 'PRIMARY'")
# HuneedTechnologies
# (1062, "Duplicate entry 'KR7353190002' for key 'PRIMARY'")
# Hurum Co., Ltd.
# (1062, "Duplicate entry 'KR7090710005' for key 'PRIMARY'")
# Hyulim ROBOT Co.,Ltd.
# (1062, "Duplicate entry 'KR7205470008' for key 'PRIMARY'")
# HUMASIS CO., LTD.
# (1062, "Duplicate entry 'KR7115160004' for key 'PRIMARY'")
# HUMAX CO., LTD.
# (1062, "Duplicate entry 'KR7028080000' for key 'PRIMARY'")
# Humax Holdings Co., Ltd
# (1062, "Duplicate entry 'KR7032860009' for key 'PRIMARY'")
# Human N
# (1062, "Duplicate entry 'KR7200670008' for key 'PRIMARY'")
# Humedix Co., Ltd.
# (1062, "Duplicate entry 'KR7212310007' for key 'PRIMARY'")
# HUVEXEL
# (1062, "Duplicate entry 'KR7079980009' for key 'PRIMARY'")
# HUVIS
# (1062, "Duplicate entry 'KR7065510000' for key 'PRIMARY'")
# Huvitz Co., Ltd.
# (1062, "Duplicate entry 'KR7215090002' for key 'PRIMARY'")
# Hucentech
# (1062, "Duplicate entry 'KR7005010004' for key 'PRIMARY'")
# HUSTEEL
# (1062, "Duplicate entry 'KR7243070000' for key 'PRIMARY'")
# Huons Co., Ltd.
# (1062, "Duplicate entry 'KR7084110006' for key 'PRIMARY'")
# Huons Global Co., Ltd.
# (1062, "Duplicate entry 'KR7263920001' for key 'PRIMARY'")
# Huons Blossom
# (1062, "Duplicate entry 'KR7145020004' for key 'PRIMARY'")
# Hugel, Inc.
# (1062, "Duplicate entry 'KR7069260008' for key 'PRIMARY'")
# HuchemsFineChemicalCorporation
# (1062, "Duplicate entry 'KR7024060006' for key 'PRIMARY'")
# HeunguOil
# (1062, "Duplicate entry 'KR7010240000' for key 'PRIMARY'")
# HEUNGKUK METALTECH CO.,LTD.
# (1062, "Duplicate entry 'KR7189980006' for key 'PRIMARY'")
# HYUNGKUK F&B Co., Ltd
# (1062, "Duplicate entry 'KR7000541003' for key 'PRIMARY'")
# HeungkukFire&MarineIns(1P)
# (1062, "Duplicate entry 'KR7000542001' for key 'PRIMARY'")
# HeungkukFire&MarineIns(2PB)
# (1062, "Duplicate entry 'KR7000540005' for key 'PRIMARY'")
# HeungkukFire&MarineInsurance
# (1062, "Duplicate entry 'KR7003280005' for key 'PRIMARY'")
# HeungaShipping
# (1062, "Duplicate entry 'KR7037440005' for key 'PRIMARY'")
# Heerim Architects & Planners
# (1062, "Duplicate entry 'KR7238490007' for key 'PRIMARY'")
# HIMS CO., LTD.

# %%
con.commit()

# %%
cur.execute("select * from master")
# Out:
# 2602

# %%
rt= cur.fetchall()

# %%
rt
# Out:
# (('HK0000057197',
#   '900110',
#   '이스트아시아홀딩스인베스트먼트리미티드',
#   '이스트아시아홀딩스',
#   'East Asia Holdings Investment Limited',
#   '2010/04/23',
#   'KOSDAQ',
#   '외국주권',
#   '외국기업(소속부없음)',
#   '보통주',
#   '무액면',
#   '201,982,155'),
#  ('HK0000214814',
#   '900270',
#   '헝셩그룹유한회사',
#   '헝셩그룹',
#   'HENG SHENG GROUP COMPANY LIMITED',
#   '2016/08/18',
#   'KOSDAQ',
#   '외국주권',
#   '외국기업(소속부없음)',
#   '보통주',
#   '무액면',
#   '82,824,858'),
#  ('HK0000295359',
#   '900260',
#   '로스웰인터내셔널',
#   '로스웰',
#   'Rothwell International Co., Limited',
#   '2016/06/30',
#   'KOSDAQ',
#   '외국주권',
#   '외국기업(소속부없음)',
#   '보통주',
#   '무액면',
#   '180,156,443'),
#  ('HK0000307485',
#   '900290',
#   '그레이트리치과기유한공사',
#   'GRT',
#   'Great Rich Technologies Limited',
#   '2016/10/25',
#   'KOSDAQ',
#   '외국주권',
#   '외국기업(소속부없음)',
#   '보통주',
#   '무액면',
#   '67,375,000'),
#  ('HK0000312568',
#   '900300',
#   '오가닉티코스메틱스홀딩스컴퍼니리미티드',
#   '오가닉티코스메틱',
#   'ORGANIC TEA COSMETICS HOLDINGS COMPANY LIMITED',
#   '2016/11/04',
#   'KOSDAQ',
#   '외국주권',
#   '외국기업(소속부없음)',
#   '보통주',
#   '무액면',
#   '120,337,029'),
#  ('HK0000341732',
#   '900310',
#   '컬러레이홀딩스',
#   '컬러레이',
#   'Coloray International Investment Co., Limited',
#   '2017/08/10',
#   'KOSDAQ',
#   '외국주권',
#   '외국기업(소속부없음)',
#   '보통주',
#   '무액면',
#   '54,000,000'),
#  ('HK0000449303',
#   '900340',
#   '윙입푸드홀딩스',
#   '윙입푸드',
#   'WING YIP FOOD (CHINA) HOLDINGS GROUP LIMITED',
#   '2018/11/30',
#   'KOSDAQ',
#   '외국주권',
#   '외국기업(소속부없음)',
#   '보통주',
#   '무액면',
#   '47,973,428'),
#  ('KR7000020008',
#   '000020',
#   '동화약품보통주',
#   '동화약품',
#   'DongwhaPharm',
#   '1976/03/24',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '27,931,470'),
#  ('KR7000040006',
#   '000040',
#   'KR모터스보통주',
#   'KR모터스',
#   'KR MOTORS',
#   '1976/05/25',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '96,137,368'),
#  ('KR7000050005',
#   '000050',
#   '경방보통주',
#   '경방',
#   'Kyungbang',
#   '1956/03/03',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '27,415,270'),
#  ('KR7000060004',
#   '000060',
#   '메리츠화재해상보험보통주',
#   '메리츠화재',
#   'Meritz Fire & Marine Insurance',
#   '1956/07/02',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '120,625,000'),
#  ('KR7000070003',
#   '000070',
#   '삼양홀딩스보통주',
#   '삼양홀딩스',
#   'SAMYANGHOLDINGS',
#   '1968/12/27',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '8,564,271'),
#  ('KR7000071001',
#   '000075',
#   '삼양홀딩스1우선주',
#   '삼양홀딩스우',
#   'SAMYANGHOLDINGS(1P)',
#   '1992/02/21',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '304,058'),
#  ('KR7000080002',
#   '000080',
#   '하이트진로보통주',
#   '하이트진로',
#   'HITEJINRO',
#   '2009/10/19',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '70,133,611'),
#  ('KR7000082008',
#   '000087',
#   '하이트진로2우선주(신형)',
#   '하이트진로2우B',
#   'HITEJINRO(2PB)',
#   '2011/09/26',
#   'KOSPI',
#   '주권',
#   '',
#   '신형우선주',
#   '5,000',
#   '1,130,138'),
#  ('KR7000100008',
#   '000100',
#   '유한양행보통주',
#   '유한양행',
#   'Yuhan',
#   '1962/11/01',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '73,231,476'),
#  ('KR7000101006',
#   '000105',
#   '유한양행1우선주',
#   '유한양행우',
#   'Yuhan(1P)',
#   '1995/02/21',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '1,000',
#   '1,180,940'),
#  ('KR7000120006',
#   '000120',
#   '씨제이대한통운보통주',
#   'CJ대한통운',
#   'CJ LOGISTICS',
#   '1956/07/02',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '22,812,344'),
#  ('KR7000140004',
#   '000140',
#   '하이트진로홀딩스보통주',
#   '하이트진로홀딩스',
#   'HITEJINROHOLDINGS',
#   '1973/09/19',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '23,206,765'),
#  ('KR7000141002',
#   '000145',
#   '하이트진로홀딩스1우선주',
#   '하이트진로홀딩스우',
#   'HITEJINROHOLDINGS(1P)',
#   '1987/09/29',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '470,810'),
#  ('KR7000150003',
#   '000150',
#   '두산보통주',
#   '두산',
#   'DOOSAN',
#   '1973/06/29',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '16,523,835'),
#  ('KR7000151001',
#   '000155',
#   '두산1우선주',
#   '두산우',
#   'DOOSAN(1P)',
#   '1986/07/31',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '3,996,462'),
#  ('KR7000152009',
#   '000157',
#   '두산2우선주(신형)',
#   '두산2우B',
#   'DOOSAN(2PB)',
#   '1999/12/03',
#   'KOSPI',
#   '주권',
#   '',
#   '신형우선주',
#   '5,000',
#   '893,038'),
#  ('KR7000180000',
#   '000180',
#   '성창기업지주보통주',
#   '성창기업지주',
#   'SungchangEnterpriseHoldings',
#   '1976/06/02',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '69,751,600'),
#  ('KR7000210005',
#   '000210',
#   'DL보통주',
#   'DL',
#   'DL',
#   '1976/02/02',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '20,955,884'),
#  ('KR7000211003',
#   '000215',
#   'DL1우선주',
#   'DL우',
#   'DL(1P)',
#   '1989/08/21',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '1,686,115'),
#  ('KR7000220004',
#   '000220',
#   '유유제약보통주',
#   '유유제약',
#   'YuyuPharma',
#   '1975/11/18',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '17,232,351'),
#  ('KR7000221002',
#   '000225',
#   '유유제약1우선주',
#   '유유제약1우',
#   'YuyuPharma(1P)',
#   '1990/01/05',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '1,000',
#   '2,266,930'),
#  ('KR7000222000',
#   '000227',
#   '유유제약2우선주(신형)',
#   '유유제약2우B',
#   'YuyuPharma(2PB)',
#   '2000/06/20',
#   'KOSPI',
#   '주권',
#   '',
#   '신형우선주',
#   '1,000',
#   '325,560'),
#  ('KR7000230003',
#   '000230',
#   '일동홀딩스보통주',
#   '일동홀딩스',
#   'ILDONG HOLDINGS',
#   '1975/06/28',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '11,540,400'),
#  ('KR7000240002',
#   '000240',
#   '한국앤컴퍼니보통주',
#   '한국앤컴퍼니',
#   'HANKOOK & COMPANY',
#   '1968/12/27',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '94,935,240'),
#  ('KR7000250001',
#   '000250',
#   '삼천당제약',
#   '삼천당제약',
#   'SAM CHUN DANG PHARM CO. LTD',
#   '2000/10/04',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '22,768,041'),
#  ('KR7000270009',
#   '000270',
#   '기아보통주',
#   '기아',
#   'KIA CORPORATION',
#   '1973/07/21',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '405,363,347'),
#  ('KR7000300004',
#   '000300',
#   '대유플러스보통주',
#   '대유플러스',
#   'DAYOUPLUS',
#   '1975/06/09',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '120,998,774'),
#  ('KR7000320002',
#   '000320',
#   '노루홀딩스보통주',
#   '노루홀딩스',
#   'NorooHoldings',
#   '1973/08/10',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '13,291,151'),
#  ('KR7000321000',
#   '000325',
#   '노루홀딩스1우선주',
#   '노루홀딩스우',
#   'NorooHoldings(1P)',
#   '1989/01/21',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '500',
#   '185,250'),
#  ('KR7000370007',
#   '000370',
#   '한화손해보험보통주',
#   '한화손해보험',
#   'Hanwha General Insurance Co.,Ltd.',
#   '1975/06/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '116,738,915'),
#  ('KR7000390005',
#   '000390',
#   '삼화페인트공업보통주',
#   '삼화페인트',
#   'SamhwaPaintIndustrial',
#   '1993/09/10',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '27,203,469'),
#  ('KR7000400002',
#   '000400',
#   '롯데손해보험보통주',
#   '롯데손해보험',
#   'LotteNon-LifeInsurance',
#   '1971/04/16',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '310,336,320'),
#  ('KR7000430009',
#   '000430',
#   '대원강업보통주',
#   '대원강업',
#   'DaewonKangup',
#   '1977/06/22',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '62,000,000'),
#  ('KR7000440008',
#   '000440',
#   '중앙에너비스',
#   '중앙에너비스',
#   'Joong Ang Enervis Co.,Ltd.',
#   '1993/03/24',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '6,227,130'),
#  ('KR7000480004',
#   '000480',
#   '조선내화보통주',
#   '조선내화',
#   'ChosunRefractories',
#   '1978/06/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '4,000,000'),
#  ('KR7000490003',
#   '000490',
#   '대동보통주',
#   '대동',
#   'DAEDONG CORPORATION',
#   '1975/06/27',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '23,728,210'),
#  ('KR7000500009',
#   '000500',
#   '가온전선보통주',
#   '가온전선',
#   'GAONCABLE',
#   '1987/06/08',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '4,160,347'),
#  ('KR7000520007',
#   '000520',
#   '삼일제약보통주',
#   '삼일제약',
#   'SamilPharmaceutical',
#   '1985/05/29',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '13,537,283'),
#  ('KR7000540005',
#   '000540',
#   '흥국화재해상보험보통주',
#   '흥국화재',
#   'HeungkukFire&MarineInsurance',
#   '1974/12/05',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '64,242,645'),
#  ('KR7000541003',
#   '000545',
#   '흥국화재해상보험1우선주',
#   '흥국화재우',
#   'HeungkukFire&MarineIns(1P)',
#   '1990/03/20',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '768,000'),
#  ('KR7000542001',
#   '000547',
#   '흥국화재해상보험2우선주(신형)',
#   '흥국화재2우B',
#   'HeungkukFire&MarineIns(2PB)',
#   '1999/08/09',
#   'KOSPI',
#   '주권',
#   '',
#   '신형우선주',
#   '5,000',
#   '153,600'),
#  ('KR7000590000',
#   '000590',
#   'CS홀딩스보통주',
#   'CS홀딩스',
#   'CSHOLDINGS',
#   '1975/12/22',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '1,154,482'),
#  ('KR7000640003',
#   '000640',
#   '동아쏘시오홀딩스보통주',
#   '동아쏘시오홀딩스',
#   'Dong-A Socio Holdings',
#   '1970/02/10',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '6,348,913'),
#  ('KR7000650002',
#   '000650',
#   '천일고속보통주',
#   '천일고속',
#   'ChunilExpress',
#   '1977/06/23',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '1,429,220'),
#  ('KR7000660001',
#   '000660',
#   '에스케이하이닉스보통주',
#   'SK하이닉스',
#   'SK hynix',
#   '1996/12/26',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '728,002,365'),
#  ('KR7000670000',
#   '000670',
#   '영풍보통주',
#   '영풍',
#   'Youngpoong',
#   '1976/06/12',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '1,842,040'),
#  ('KR7000680009',
#   '000680',
#   'LS네트웍스보통주',
#   'LS네트웍스',
#   'LSNetworks',
#   '1973/11/15',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '78,803,016'),
#  ('KR7000700005',
#   '000700',
#   '유수홀딩스보통주',
#   '유수홀딩스',
#   'EUSU HOLDINGS',
#   '1956/03/03',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '2,500',
#   '26,041,812'),
#  ('KR7000720003',
#   '000720',
#   '현대건설보통주',
#   '현대건설',
#   'HyundaiEngineering&Construction',
#   '1984/12/22',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '111,355,765'),
#  ('KR7000721001',
#   '000725',
#   '현대건설1우선주',
#   '현대건설우',
#   'HyundaiEngineering&Construction(1P)',
#   '1989/09/21',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '1,054,693'),
#  ('KR7000760009',
#   '000760',
#   '이화산업보통주',
#   '이화산업',
#   'RIFA',
#   '1994/04/29',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '2,800,000'),
#  ('KR7000810002',
#   '000810',
#   '삼성화재해상보험보통주',
#   '삼성화재',
#   'SamsungFire&MarineInsurance',
#   '1975/06/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '47,374,837'),
#  ('KR7000811000',
#   '000815',
#   '삼성화재해상보험1우선주',
#   '삼성화재우',
#   'SamsungFire&MarineInsurance(1P)',
#   '1990/04/10',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '500',
#   '3,192,000'),
#  ('KR7000850008',
#   '000850',
#   '화천기공보통주',
#   '화천기공',
#   'HwacheonMachineTool',
#   '1999/11/18',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '2,200,000'),
#  ('KR7000860007',
#   '000860',
#   '강남제비스코보통주',
#   '강남제비스코',
#   'KANGNAM JEVISCO',
#   '1975/11/12',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '6,500,000'),
#  ('KR7000880005',
#   '000880',
#   '한화보통주',
#   '한화',
#   'Hanwha',
#   '1976/06/24',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '74,958,735'),
#  ('KR7000881003',
#   '000885',
#   '한화1우선주',
#   '한화우',
#   'Hanwha(1P)',
#   '1990/01/22',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '479,294'),
#  ('KR700088K015',
#   '00088K',
#   '한화3우선주(신형)',
#   '한화3우B',
#   'HANWHA(3PB)',
#   '2016/10/19',
#   'KOSPI',
#   '주권',
#   '',
#   '신형우선주',
#   '5,000',
#   '22,472,000'),
#  ('KR7000890004',
#   '000890',
#   '보해양조보통주',
#   '보해양조',
#   'BohaeBrewery',
#   '1988/09/23',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '138,751,579'),
#  ('KR7000910000',
#   '000910',
#   '유니온보통주',
#   '유니온',
#   'Union',
#   '1996/07/03',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '15,611,619'),
#  ('KR7000950006',
#   '000950',
#   '전방보통주',
#   '전방',
#   'Chonbang',
#   '1968/10/21',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '1,680,000'),
#  ('KR7000970004',
#   '000970',
#   '한국주철관공업보통주',
#   '한국주철관',
#   'KoreaCastIronPipeInd',
#   '1969/12/12',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '22,800,500'),
#  ('KR7000990002',
#   '000990',
#   'DB하이텍보통주',
#   'DB하이텍',
#   'DB HiTek Co.,LTD',
#   '1975/12/12',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '44,398,588'),
#  ('KR7000991000',
#   '000995',
#   'DB하이텍1우선주',
#   'DB하이텍1우',
#   'DB HiTek Co.,LTD(1P)',
#   '2007/05/21',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '112,316'),
#  ('KR7001000009',
#   '001000',
#   '신라섬유',
#   '신라섬유',
#   'SillaTextile',
#   '1994/06/28',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '100',
#   '24,277,540'),
#  ('KR7001020007',
#   '001020',
#   '페이퍼코리아보통주',
#   '페이퍼코리아',
#   'PaperCorea Inc.',
#   '1976/06/26',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '43,647,068'),
#  ('KR7001040005',
#   '001040',
#   'CJ보통주',
#   'CJ',
#   'CJ Corp.',
#   '1973/06/29',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '29,176,998'),
#  ('KR7001041003',
#   '001045',
#   'CJ1우선주',
#   'CJ우',
#   'CJ(1P)',
#   '1989/08/18',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '2,260,223'),
#  ('KR700104K010',
#   '00104K',
#   'CJ4우선주(전환)',
#   'CJ4우(전환)',
#   'CJ(4PC)',
#   '2019/08/09',
#   'KOSPI',
#   '주권',
#   '',
#   '신형우선주',
#   '5,000',
#   '4,226,512'),
#  ('KR7001060003',
#   '001060',
#   'JW중외제약보통주',
#   'JW중외제약',
#   'JWPHARMACEUTICAL',
#   '1976/06/14',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '2,500',
#   '22,178,081'),
#  ('KR7001061001',
#   '001065',
#   'JW중외제약1우선주',
#   'JW중외제약우',
#   'JWPHARMACEUTICAL(1P)',
#   '1994/10/21',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '2,500',
#   '182,735'),
#  ('KR7001062009',
#   '001067',
#   'JW중외제약2우선주(신형)',
#   'JW중외제약2우B',
#   'JWPHARMACEUTICAL(2PB)',
#   '1998/04/13',
#   'KOSPI',
#   '주권',
#   '',
#   '신형우선주',
#   '2,500',
#   '102,927'),
#  ('KR7001070002',
#   '001070',
#   '대한방직보통주',
#   '대한방직',
#   'TaihanTextile',
#   '1973/12/28',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '5,300,000'),
#  ('KR7001080001',
#   '001080',
#   '만호제강보통주',
#   '만호제강',
#   'ManhoRope&Wire',
#   '1977/06/18',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '4,150,000'),
#  ('KR7001120005',
#   '001120',
#   'LX인터내셔널보통주',
#   'LX인터내셔널',
#   'LX INTERNATIONAL CORP.',
#   '1976/01/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '38,760,000'),
#  ('KR7001130004',
#   '001130',
#   '대한제분보통주',
#   '대한제분',
#   'DaehanFlourMill',
#   '1970/11/25',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '1,690,000'),
#  ('KR7001140003',
#   '001140',
#   '국보보통주',
#   '국보',
#   'KUKBO',
#   '1989/12/02',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '69,660,070'),
#  ('KR7001200005',
#   '001200',
#   '유진투자증권보통주',
#   '유진투자증권',
#   'EUGENE INVESTMENT & SECURITIES',
#   '1987/08/24',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '96,866,418'),
#  ('KR7001210004',
#   '001210',
#   '금호전기보통주',
#   '금호전기',
#   'KumhoElectric',
#   '1973/11/15',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '20,861,019'),
#  ('KR7001230002',
#   '001230',
#   '동국제강보통주',
#   '동국제강',
#   'DongkukSteelMill',
#   '1988/05/09',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '95,432,737'),
#  ('KR7001250000',
#   '001250',
#   '지에스글로벌보통주',
#   'GS글로벌',
#   'GS Global Corp.',
#   '1976/06/26',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '2,500',
#   '82,533,764'),
#  ('KR7001260009',
#   '001260',
#   '남광토건보통주',
#   '남광토건',
#   'NamkwangEngineering&Construction',
#   '1976/12/28',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '9,829,014'),
#  ('KR7001270008',
#   '001270',
#   '부국증권보통주',
#   '부국증권',
#   'BookookSecurities',
#   '1988/07/19',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '10,369,886'),
#  ('KR7001271006',
#   '001275',
#   '부국증권1우선주',
#   '부국증권우',
#   'BookookSecurities(1P)',
#   '1989/11/10',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '3,000,000'),
#  ('KR7001290006',
#   '001290',
#   '상상인증권보통주',
#   '상상인증권',
#   'SANGSANGININVESTMENT&SECURITIES',
#   '1988/09/23',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '107,456,063'),
#  ('KR7001340009',
#   '001340',
#   '백광산업보통주',
#   '백광산업',
#   'PaikkwangIndustrial',
#   '1976/06/10',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '44,918,407'),
#  ('KR7001360007',
#   '001360',
#   '삼성제약',
#   '삼성제약',
#   'SAMSUNG PHARMACEUTICAL',
#   '1975/07/04',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '67,162,079'),
#  ('KR7001380005',
#   '001380',
#   'SG글로벌보통주',
#   'SG글로벌',
#   'SG GLOBAL',
#   '1976/06/29',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '44,964,143'),
#  ('KR7001390004',
#   '001390',
#   'KG케미칼보통주',
#   'KG케미칼',
#   'KG Chemical',
#   '1989/08/25',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '13,866,096'),
#  ('KR7001420009',
#   '001420',
#   '태원물산보통주',
#   '태원물산',
#   'TaewonMulsan',
#   '1975/06/24',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '7,600,000'),
#  ('KR7001430008',
#   '001430',
#   '세아베스틸보통주',
#   '세아베스틸',
#   'SEAH BESTEEL',
#   '1991/03/12',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '35,862,119'),
#  ('KR7001440007',
#   '001440',
#   '대한전선보통주',
#   '대한전선',
#   'TaihanElectricWire',
#   '1968/12/27',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '100',
#   '1,244,473,009'),
#  ('KR7001450006',
#   '001450',
#   '현대해상화재보험보통주',
#   '현대해상',
#   'Hyundai MARINE & FIRE INSURANCE CO.,LTD',
#   '1989/08/25',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '89,400,000'),
#  ('KR7001460005',
#   '001460',
#   'BYC보통주',
#   'BYC',
#   'BYC',
#   '1975/06/02',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '624,615'),
#  ('KR7001461003',
#   '001465',
#   'BYC1우선주',
#   'BYC우',
#   'BYC(1P)',
#   '1989/09/05',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '215,385'),
#  ('KR7001470004',
#   '001470',
#   '삼부토건보통주',
#   '삼부토건',
#   'SambuEngineering&Construction',
#   '1976/06/26',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '172,556,269'),
#  ('KR7001500008',
#   '001500',
#   '현대차증권보통주',
#   '현대차증권',
#   'HYUNDAI MOTOR SECURITIES',
#   '1990/06/09',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '31,712,562'),
#  ('KR7001510007',
#   '001510',
#   'SK증권보통주',
#   'SK증권',
#   'SKSecurities',
#   '1986/09/20',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '472,590,171'),
#  ('KR7001511005',
#   '001515',
#   'SK증권1우선주',
#   'SK증권우',
#   'SKSecurities(1P)',
#   '1989/08/29',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '500',
#   '3,912,514'),
#  ('KR7001520006',
#   '001520',
#   '동양보통주',
#   '동양',
#   'TONGYANG',
#   '1976/06/25',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '238,684,063'),
#  ('KR7001521004',
#   '001525',
#   '동양1우선주',
#   '동양우',
#   'TONGYANG(1P)',
#   '1989/09/30',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '500',
#   '617,731'),
#  ('KR7001522002',
#   '001527',
#   '동양2우선주(신형)',
#   '동양2우B',
#   'TONGYANG(2PB)',
#   '1999/01/28',
#   'KOSPI',
#   '주권',
#   '',
#   '신형우선주',
#   '500',
#   '308,569'),
#  ('KR7001523000',
#   '001529',
#   '동양3우선주(신형)',
#   '동양3우B',
#   'TONGYANG(3PB)',
#   '2007/08/03',
#   'KOSPI',
#   '주권',
#   '',
#   '신형우선주',
#   '500',
#   '89,722'),
#  ('KR7001530005',
#   '001530',
#   'DI동일보통주',
#   'DI동일',
#   'DI DONGIL',
#   '1964/01/04',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '2,510,655'),
#  ('KR7001540004',
#   '001540',
#   '안국약품',
#   '안국약품',
#   'AHN-GOOK PHARMACEUTICAL Co., Ltd.',
#   '2000/06/15',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '13,042,420'),
#  ('KR7001550003',
#   '001550',
#   '조비보통주',
#   '조비',
#   'Chobi',
#   '1976/12/28',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '5,192,239'),
#  ('KR7001560002',
#   '001560',
#   '제일연마공업보통주',
#   '제일연마',
#   'CHEILGRINDINGWHEELIND.CO.,LTD',
#   '2005/12/09',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '10,000,000'),
#  ('KR7001570001',
#   '001570',
#   '금양보통주',
#   '금양',
#   'Kumyang',
#   '1976/12/17',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '49,710,590'),
#  ('KR7001620004',
#   '001620',
#   '케이비아이동국실업보통주',
#   '케이비아이동국실업',
#   'KBI DONGKOOK IND',
#   '1990/09/15',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '87,286,004'),
#  ('KR7001630003',
#   '001630',
#   '종근당홀딩스보통주',
#   '종근당홀딩스',
#   'CHONGKUNDANG HOLDINGS CORP.',
#   '1976/06/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '2,500',
#   '5,009,861'),
#  ('KR7001680008',
#   '001680',
#   '대상보통주',
#   '대상',
#   'Daesang',
#   '1970/04/01',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '34,648,025'),
#  ('KR7001681006',
#   '001685',
#   '대상1우선주',
#   '대상우',
#   'Daesang(1P)',
#   '1989/11/21',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '1,000',
#   '1,370,223'),
#  ('KR7001720002',
#   '001720',
#   '신영증권보통주',
#   '신영증권',
#   'ShinyoungSecurities',
#   '1987/08/24',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '9,386,237'),
#  ('KR7001721000',
#   '001725',
#   '신영증권1우선주',
#   '신영증권우',
#   'ShinyoungSecurities(1P)',
#   '1988/08/16',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '7,053,763'),
#  ('KR7001740000',
#   '001740',
#   'SK네트웍스보통주',
#   'SK네트웍스',
#   'SKNetworksCo.,Ltd',
#   '1977/06/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '2,500',
#   '248,187,647'),
#  ('KR7001741008',
#   '001745',
#   'SK네트웍스1우선주',
#   'SK네트웍스우',
#   'SKNetworksCo.,Ltd(1P)',
#   '1989/12/21',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '2,500',
#   '113,648'),
#  ('KR7001750009',
#   '001750',
#   '한양증권보통주',
#   '한양증권',
#   'HanyangSecurities',
#   '1988/03/04',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '12,728,534'),
#  ('KR7001751007',
#   '001755',
#   '한양증권1우선주',
#   '한양증권우',
#   'HanyangSecurities(1P)',
#   '1989/10/24',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '525,000'),
#  ('KR7001770007',
#   '001770',
#   'SHD보통주',
#   'SHD',
#   'SHIN HWA DYNAMICS',
#   '1988/11/23',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '1,214,878'),
#  ('KR7001780006',
#   '001780',
#   '알루코 보통주',
#   '알루코',
#   'ALUKO CO.,LTD.',
#   '2007/06/07',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '89,791,232'),
#  ('KR7001790005',
#   '001790',
#   '대한제당보통주',
#   '대한제당',
#   'TS',
#   '1968/12/27',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '89,696,580'),
#  ('KR7001791003',
#   '001795',
#   '대한제당1우선주',
#   '대한제당우',
#   'TS(1P)',
#   '1995/01/21',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '500',
#   '6,482,760'),
#  ('KR7001800002',
#   '001800',
#   '오리온홀딩스보통주',
#   '오리온홀딩스',
#   'ORION Holdings',
#   '1975/06/27',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '62,645,422'),
#  ('KR7001810001',
#   '001810',
#   '무림에스피',
#   '무림SP',
#   'MOORIM SP CO., LTD.',
#   '2000/01/04',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '22,137,500'),
#  ('KR7001820000',
#   '001820',
#   '삼화콘덴서공업보통주',
#   '삼화콘덴서',
#   'SamwhaCapacitor',
#   '1976/06/26',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '10,395,000'),
#  ('KR7001840008',
#   '001840',
#   '이화공영',
#   '이화공영',
#   'EehwaConstruction',
#   '1994/11/23',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '19,805,760'),
#  ('KR7001880004',
#   '001880',
#   'DL건설보통주',
#   'DL건설',
#   'DLConstruction',
#   '1977/12/22',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '22,053,284'),
#  ('KR7001940006',
#   '001940',
#   'KISCO홀딩스보통주',
#   'KISCO홀딩스',
#   'KISCO Holdings',
#   '1989/11/13',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '18,476,380'),
#  ('KR7002020006',
#   '002020',
#   '코오롱보통주',
#   '코오롱',
#   'KOLON CORPORATION',
#   '1975/06/23',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '12,626,426'),
#  ('KR7002021004',
#   '002025',
#   '코오롱1우선주',
#   '코오롱우',
#   'KOLON CORPORATION(1P)',
#   '1989/08/22',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '1,076,390'),
#  ('KR7002030005',
#   '002030',
#   '아세아보통주',
#   '아세아',
#   'ASIA HOLDINGS',
#   '1974/06/03',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '2,191,024'),
#  ('KR7002070001',
#   '002070',
#   '비비안보통주',
#   '비비안',
#   'VIVIEN CORPORATION',
#   '1976/07/13',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '29,793,990'),
#  ('KR7002100006',
#   '002100',
#   '경농보통주',
#   '경농',
#   'Kyungnong',
#   '1977/06/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '19,522,575'),
#  ('KR7002140002',
#   '002140',
#   '고려산업보통주',
#   '고려산업',
#   'KoreaIndustrial',
#   '1991/01/14',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '24,939,425'),
#  ('KR7002150001',
#   '002150',
#   '도화엔지니어링보통주',
#   '도화엔지니어링',
#   'DOHWA ENGINEERING',
#   '2010/08/12',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '33,720,000'),
#  ('KR7002170009',
#   '002170',
#   '삼양통상보통주',
#   '삼양통상',
#   'SamyangTongsang',
#   '1989/11/10',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '3,000,000'),
#  ('KR7002200004',
#   '002200',
#   '한국수출포장공업보통주',
#   '한국수출포장',
#   'KoreaExportPackagingIndustrial',
#   '1974/06/28',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '4,000,000'),
#  ('KR7002210003',
#   '002210',
#   '동성제약보통주',
#   '동성제약',
#   'DongsungPharmaceutical',
#   '1990/01/19',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '26,100,970'),
#  ('KR7002220002',
#   '002220',
#   '한일철강보통주',
#   '한일철강',
#   'HanilIron&Steel',
#   '1988/10/07',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '26,697,460'),
#  ('KR7002230001',
#   '002230',
#   '피에스텍',
#   '피에스텍',
#   'PS Tec. Co., Ltd.',
#   '1991/01/04',
#   'KOSDAQ',
#   '주권',
#   '투자주의환기종목(소속부없음)',
#   '보통주',
#   '500',
#   '19,669,243'),
#  ('KR7002240000',
#   '002240',
#   '고려제강보통주',
#   '고려제강',
#   'KISWire',
#   '1976/05/25',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '23,000,000'),
#  ('KR7002270007',
#   '002270',
#   '롯데푸드보통주',
#   '롯데푸드',
#   'LotteFood',
#   '1973/05/09',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '1,209,055'),
#  ('KR7002290005',
#   '002290',
#   '삼일기업공사',
#   '삼일기업공사',
#   'SAMIL ENTERPRISE CO., LTD.',
#   '1992/11/30',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '12,400,000'),
#  ('KR7002310001',
#   '002310',
#   '아세아제지보통주',
#   '아세아제지',
#   'AsiaPaperManufacturing',
#   '1988/12/15',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '8,956,502'),
#  ('KR7002320000',
#   '002320',
#   '한진보통주',
#   '한진',
#   'HanjinTransportation',
#   '1974/08/12',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '14,947,628'),
#  ('KR7002350007',
#   '002350',
#   '넥센타이어보통주',
#   '넥센타이어',
#   'NEXENTIRE',
#   '1976/05/19',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '97,667,877'),
#  ('KR7002351005',
#   '002355',
#   '넥센타이어1우선주(신형)',
#   '넥센타이어1우B',
#   'NEXENTIRE(1PB)',
#   '1999/06/08',
#   'KOSPI',
#   '주권',
#   '',
#   '신형우선주',
#   '500',
#   '6,500,000'),
#  ('KR7002360006',
#   '002360',
#   'SH에너지화학보통주',
#   'SH에너지화학',
#   'SH ENERGY & CHEMICAL',
#   '1985/12/23',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '111,133,730'),
#  ('KR7002380004',
#   '002380',
#   '주식회사케이씨씨',
#   'KCC',
#   'KCC Corporation',
#   '1973/06/25',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '8,886,471'),
#  ('KR7002390003',
#   '002390',
#   '한독보통주',
#   '한독',
#   'HANDOK Inc.',
#   '1976/06/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '13,763,533'),
#  ('KR7002410009',
#   '002410',
#   '범양건영보통주',
#   '범양건영',
#   'BUMYANG CONSTRUCTION',
#   '1988/05/25',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '24,831,982'),
#  ('KR7002420008',
#   '002420',
#   '세기상사보통주',
#   '세기상사',
#   'TheCentury',
#   '1968/12/27',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '4,276,420'),
#  ('KR7002450005',
#   '002450',
#   '삼익악기보통주',
#   '삼익악기',
#   'SamickMusicalInstruments',
#   '1988/09/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '90,530,915'),
#  ('KR7002460004',
#   '002460',
#   '화성산업보통주',
#   '화성산업',
#   'HwasungIndustrial',
#   '1988/09/29',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '12,450,800'),
#  ('KR7002600005',
#   '002600',
#   '조흥보통주',
#   '조흥',
#   'CHOHEUNG CORPORATION',
#   '1976/12/23',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '600,000'),
#  ('KR7002620003',
#   '002620',
#   '제일파마홀딩스보통주',
#   '제일파마홀딩스',
#   'JEIL PHARMA HOLDINGS INC.',
#   '1988/01/20',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '15,973,355'),
#  ('KR7002630002',
#   '002630',
#   '오리엔트바이오보통주',
#   '오리엔트바이오',
#   'ORIENTBIO',
#   '1976/12/28',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '118,583,005'),
#  ('KR7002680007',
#   '002680',
#   '한탑',
#   '한탑',
#   'Hantop Inc.',
#   '1995/07/07',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '28,269,988'),
#  ('KR7002690006',
#   '002690',
#   '동일제강보통주',
#   '동일제강',
#   'DONG IL STEEL MFG CO., LTD',
#   '2015/09/24',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '20,300,360'),
#  ('KR7002700003',
#   '002700',
#   '신일전자보통주',
#   '신일전자',
#   'SHINIL ELECTRONICS',
#   '1975/09/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '71,047,521'),
#  ('KR7002710002',
#   '002710',
#   'TCC스틸보통주',
#   'TCC스틸',
#   'TCC STEEL',
#   '1984/12/21',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '23,500,000'),
#  ('KR7002720001',
#   '002720',
#   '국제약품보통주',
#   '국제약품',
#   'Kukje Pharma',
#   '1975/12/27',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '19,276,090'),
#  ('KR7002760007',
#   '002760',
#   '보락보통주',
#   '보락',
#   'Bolak',
#   '1989/11/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '200',
#   '59,900,000'),
#  ('KR7002780005',
#   '002780',
#   '진흥기업보통주',
#   '진흥기업',
#   'ChinhungInternational',
#   '1977/06/25',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '145,471,745'),
#  ('KR7002781003',
#   '002785',
#   '진흥기업1우선주(신형)',
#   '진흥기업우B',
#   'CHINHUNG INT(1PB)',
#   '2003/06/16',
#   'KOSPI',
#   '주권',
#   '',
#   '신형우선주',
#   '500',
#   '857,218'),
#  ('KR7002782001',
#   '002787',
#   '진흥기업2우선주(신형)',
#   '진흥기업2우B',
#   'CHINHUNG INT (2PB)',
#   '2006/12/05',
#   'KOSPI',
#   '주권',
#   '',
#   '신형우선주',
#   '500',
#   '294,808'),
#  ('KR7002790004',
#   '002790',
#   '아모레G보통주',
#   '아모레G',
#   'AmoreG',
#   '1973/04/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '82,458,180'),
#  ('KR7002791002',
#   '002795',
#   '아모레G1우선주',
#   '아모레G우',
#   'AmoreG(1P)',
#   '1989/06/30',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '500',
#   '6,443,770'),
#  ('KR700279K010',
#   '00279K',
#   '아모레G3우선주(전환)',
#   '아모레G3우(전환)',
#   'AMOREG(3PC)',
#   '2019/12/26',
#   'KOSPI',
#   '주권',
#   '',
#   '신형우선주',
#   '500',
#   '7,092,200'),
#  ('KR7002800001',
#   '002800',
#   '신신제약',
#   '신신제약',
#   'SINSIN PHARMACEUTICAL CO., LTD.',
#   '2017/02/28',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '15,170,500'),
#  ('KR7002810000',
#   '002810',
#   '삼영무역보통주',
#   '삼영무역',
#   'SamyungTrading',
#   '1988/03/28',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '18,466,948'),
#  ('KR7002820009',
#   '002820',
#   '선앤엘보통주',
#   'SUN&L',
#   'SUN&L',
#   '1976/05/22',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '12,607,989'),
#  ('KR7002840007',
#   '002840',
#   '미원상사보통주',
#   '미원상사',
#   'MiwonCommercial',
#   '1989/09/25',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '4,970,000'),
#  ('KR7002870004',
#   '002870',
#   '신풍제지보통주',
#   '신풍제지',
#   'ShinpoongPaperMfg',
#   '1976/06/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '34,958,700'),
#  ('KR7002880003',
#   '002880',
#   '대유에이텍',
#   '대유에이텍',
#   'DAYOU AUTOMOTIVE SEAT TECHNOLOGY CO.,LTD',
#   '1977/02/18',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '115,094,114'),
#  ('KR7002900009',
#   '002900',
#   '티와이엠보통주',
#   'TYM',
#   'TYM CORPORATION',
#   '1973/06/26',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '151,987,447'),
#  ('KR7002920007',
#   '002920',
#   '유성기업보통주',
#   '유성기업',
#   'YoosungEnterprise',
#   '1988/10/10',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '25,947,500'),
#  ('KR7002960003',
#   '002960',
#   '한국쉘석유보통주',
#   '한국쉘석유',
#   'HankookShellOil',
#   '1988/08/10',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '1,300,000'),
#  ('KR7002990000',
#   '002990',
#   '금호건설보통주',
#   '금호건설',
#   'KUMHOE&C',
#   '1976/06/26',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '36,633,924'),
#  ('KR7002991008',
#   '002995',
#   '금호건설1우선주',
#   '금호건설우',
#   'KUMHOE&C(1P)',
#   '1988/10/06',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '292,266'),
#  ('KR7003000007',
#   '003000',
#   '부광약품보통주',
#   '부광약품',
#   'BukwangPharmaceutical',
#   '1988/08/05',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '71,063,049'),
#  ('KR7003010006',
#   '003010',
#   '혜인보통주',
#   '혜인',
#   'HaeinCorporation',
#   '1988/09/20',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '12,712,747'),
#  ('KR7003030004',
#   '003030',
#   '세아제강지주보통주',
#   '세아제강지주',
#   'SeAH Steel Holdings Corporation',
#   '1969/05/13',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '4,141,657'),
#  ('KR7003060001',
#   '003060',
#   '에이프로젠제약보통주',
#   '에이프로젠제약',
#   'Aprogen pharmaceuticals,Inc.',
#   '1984/10/19',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '398,575,767'),
#  ('KR7003070000',
#   '003070',
#   '코오롱글로벌보통주',
#   '코오롱글로벌',
#   'KolonGlobalCorporation',
#   '1978/09/15',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '25,210,438'),
#  ('KR7003071008',
#   '003075',
#   '코오롱글로벌1우선주',
#   '코오롱글로벌우',
#   'KolonGlobalCorporation(1P)',
#   '1989/12/11',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '312,803'),
#  ('KR7003080009',
#   '003080',
#   '성보화학보통주',
#   '성보화학',
#   'SungboChemical',
#   '1976/12/23',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '20,020,000'),
#  ('KR7003090008',
#   '003090',
#   '대웅보통주',
#   '대웅',
#   'Daewoong',
#   '1973/06/26',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '58,141,980'),
#  ('KR7003100005',
#   '003100',
#   '선광',
#   '선광',
#   'SUN KWANG Co., Ltd',
#   '1999/12/21',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '1,000',
#   '6,600,000'),
#  ('KR7003120003',
#   '003120',
#   '일성신약보통주',
#   '일성신약',
#   'IlsungPharmaceutical',
#   '1985/01/14',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '2,660,000'),
#  ('KR7003160009',
#   '003160',
#   '디아이보통주',
#   '디아이',
#   'DI',
#   '1996/07/31',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '31,496,785'),
#  ('KR7003200003',
#   '003200',
#   '일신방직보통주',
#   '일신방직',
#   'IlshinSpinning',
#   '1973/05/23',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '2,400,000'),
#  ('KR7003220001',
#   '003220',
#   '대원제약보통주',
#   '대원제약',
#   'DaewonPharmaceutical',
#   '1999/12/15',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '21,842,836'),
#  ('KR7003230000',
#   '003230',
#   '삼양식품보통주',
#   '삼양식품',
#   'SamyangFoods',
#   '1975/06/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '7,533,015'),
#  ('KR7003240009',
#   '003240',
#   '태광산업보통주',
#   '태광산업',
#   'TaekwangIndustrial',
#   '1975/12/27',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '1,113,400'),
#  ('KR7003280005',
#   '003280',
#   '흥아해운보통주',
#   '흥아해운',
#   'HeungaShipping',
#   '1976/06/29',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '240,424,899'),
#  ('KR7003300001',
#   '003300',
#   '한일홀딩스보통주',
#   '한일홀딩스',
#   'HANILHOLDINGS',
#   '1969/11/20',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '28,815,780'),
#  ('KR7003310000',
#   '003310',
#   '대주산업',
#   '대주산업',
#   'Daejoo Inc.',
#   '1992/08/01',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '35,392,350'),
#  ('KR7003350006',
#   '003350',
#   '한국화장품제조보통주',
#   '한국화장품제조',
#   'HankookCosmeticsManufacturing',
#   '1978/02/06',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '4,532,000'),
#  ('KR7003380003',
#   '003380',
#   '하림지주',
#   '하림지주',
#   'Harim Holdings Co., Ltd.',
#   '2017/06/30',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '100',
#   '112,005,621'),
#  ('KR7003410008',
#   '003410',
#   '쌍용C&E보통주',
#   '쌍용C&E',
#   'SSANGYONGC&E',
#   '1975/05/03',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '100',
#   '503,859,595'),
#  ('KR7003460003',
#   '003460',
#   '유화증권보통주',
#   '유화증권',
#   'YuhwaSecurities',
#   '1987/08/24',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '56,702,415'),
#  ('KR7003461001',
#   '003465',
#   '유화증권1우선주',
#   '유화증권우',
#   'YuhwaSecurities(1P)',
#   '1990/02/20',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '1,000',
#   '17,476,425'),
#  ('KR7003470002',
#   '003470',
#   '유안타증권보통주',
#   '유안타증권',
#   'Yuanta Securities Korea',
#   '1988/01/21',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '199,596,576'),
#  ('KR7003471000',
#   '003475',
#   '유안타증권1우선주',
#   '유안타증권우',
#   'Yuanta Securities Korea(1P)',
#   '1989/03/22',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '12,912,212'),
#  ('KR7003480001',
#   '003480',
#   '한진중공업홀딩스보통주',
#   '한진중공업홀딩스',
#   'HanjinHeavyInd&ConstHoldings',
#   '1956/03/03',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '29,529,812'),
#  ('KR7003490000',
#   '003490',
#   '대한항공보통주',
#   '대한항공',
#   'KoreanAirLines',
#   '1966/03/18',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '347,820,825'),
#  ('KR7003491008',
#   '003495',
#   '대한항공1우선주',
#   '대한항공우',
#   'KoreanAirLines(1P)',
#   '1990/03/31',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '1,110,794'),
#  ('KR7003520004',
#   '003520',
#   '영진약품보통주',
#   '영진약품',
#   'YUNGJIN PHARM',
#   '1973/06/25',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '182,892,731'),
#  ('KR7003530003',
#   '003530',
#   '한화투자증권보통주',
#   '한화투자증권',
#   'HANWHA INVESTMENT & SECURITIES',
#   '1986/11/25',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '214,547,775'),
#  ('KR7003531001',
#   '003535',
#   '한화투자증권1우선주',
#   '한화투자증권우',
#   'HANWHA INVESTMENT & SECURITIES(1P)',
#   '1989/05/06',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '4,800,000'),
#  ('KR7003540002',
#   '003540',
#   '대신증권보통주',
#   '대신증권',
#   'DaishinSecurities',
#   '1975/10/01',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '50,773,400'),
#  ('KR7003541000',
#   '003545',
#   '대신증권1우선주',
#   '대신증권우',
#   'DaishinSecurities(1P)',
#   '1988/09/01',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '26,000,000'),
#  ('KR7003542008',
#   '003547',
#   '대신증권2우선주(신형)',
#   '대신증권2우B',
#   'DAISHINSECURITIES(2PB)',
#   '2007/11/09',
#   'KOSPI',
#   '주권',
#   '',
#   '신형우선주',
#   '5,000',
#   '10,000,000'),
#  ('KR7003550001',
#   '003550',
#   'LG보통주',
#   'LG',
#   'LG Corp.',
#   '1970/02/13',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '157,300,993'),
#  ('KR7003551009',
#   '003555',
#   'LG1우선주',
#   'LG우',
#   'LG Corp.(1P)',
#   '1988/11/18',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '3,021,620'),
#  ('KR7003560000',
#   '003560',
#   'IHQ보통주',
#   'IHQ',
#   'IHQ',
#   '1973/12/18',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '151,378,606'),
#  ('KR7003570009',
#   '003570',
#   'SNT중공업보통주',
#   'SNT중공업',
#   'SNT DYNAMICS',
#   '1976/07/08',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '2,500',
#   '33,252,697'),
#  ('KR7003580008',
#   '003580',
#   '넥스트사이언스보통주',
#   '넥스트사이언스',
#   'NEXT SCIENCE',
#   '1990/03/23',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '42,165,837'),
#  ('KR7003610003',
#   '003610',
#   '방림보통주',
#   '방림',
#   'Pangrim',
#   '1989/05/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '42,314,090'),
#  ('KR7003620002',
#   '003620',
#   '쌍용자동차보통주',
#   '쌍용차',
#   'SsangyongMotor',
#   '1975/05/29',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '149,840,002'),
#  ('KR7003650009',
#   '003650',
#   '미창석유공업보통주',
#   '미창석유',
#   'MichangOilInd',
#   '1989/09/27',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '1,739,672'),
#  ('KR7003670007',
#   '003670',
#   '포스코케미칼보통주',
#   '포스코케미칼',
#   'POSCO CHEMICAL',
#   '2019/05/29',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '77,463,220'),
#  ('KR7003680006',
#   '003680',
#   '한성기업보통주',
#   '한성기업',
#   'HansungEnterprise',
#   '1989/01/26',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '6,209,515'),
#  ('KR7003690005',
#   '003690',
#   '코리안리재보험보통주',
#   '코리안리',
#   'Korean Reinsurance Company',
#   '1969/12/22',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '120,369,116'),
#  ('KR7003720000',
#   '003720',
#   '삼영화학공업보통주',
#   '삼영화학',
#   'SamyoungChemical',
#   '1976/06/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '34,000,000'),
#  ('KR7003780004',
#   '003780',
#   '진양산업보통주',
#   '진양산업',
#   'Chinyang Industry',
#   '1973/06/26',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '13,000,000'),
#  ('KR7003800000',
#   '003800',
#   '에이스침대',
#   '에이스침대',
#   'AceBed',
#   '1996/05/03',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '1,000',
#   '11,090,000'),
#  ('KR7003830007',
#   '003830',
#   '대한화섬보통주',
#   '대한화섬',
#   'DaehanSyntheticFibrer',
#   '1985/12/23',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '1,328,000'),
#  ('KR7003850005',
#   '003850',
#   '보령제약보통주',
#   '보령제약',
#   'BoryungPharm',
#   '1988/10/24',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '68,690,000'),
#  ('KR7003920006',
#   '003920',
#   '남양유업보통주',
#   '남양유업',
#   'NamyangDairyProducts',
#   '1978/06/24',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '720,000'),
#  ('KR7003921004',
#   '003925',
#   '남양유업1우선주',
#   '남양유업우',
#   'NamyangDairyProducts(1P)',
#   '1988/06/20',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '166,662'),
#  ('KR7003960002',
#   '003960',
#   '사조대림보통주',
#   '사조대림',
#   'SAJODAERIM',
#   '1976/09/16',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '9,164,467'),
#  ('KR7004000006',
#   '004000',
#   '롯데정밀화학보통주',
#   '롯데정밀화학',
#   'LOTTE Fine Chemical',
#   '1976/04/15',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '25,800,000'),
#  ('KR7004020004',
#   '004020',
#   '현대제철 보통주',
#   '현대제철',
#   'HYUNDAI STEEL',
#   '1987/05/23',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '133,445,785'),
#  ('KR7004060000',
#   '004060',
#   '에스지세계물산보통주',
#   'SG세계물산',
#   'SGCORPORATION',
#   '1976/04/19',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '202,424,960'),
#  ('KR7004080008',
#   '004080',
#   '신흥보통주',
#   '신흥',
#   'Shinhung',
#   '1991/02/08',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '9,500,000'),
#  ('KR7004090007',
#   '004090',
#   '한국석유공업보통주',
#   '한국석유',
#   'KOREA PETROLEUM INDUSTRIES',
#   '1977/06/25',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '12,694,120'),
#  ('KR7004100004',
#   '004100',
#   '태양금속공업보통주',
#   '태양금속',
#   'TaeyangMetalIndustrial',
#   '1976/05/25',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '36,700,000'),
#  ('KR7004101002',
#   '004105',
#   '태양금속공업1우선주',
#   '태양금속우',
#   'TaeyangMetalIndustrial(1P)',
#   '1990/01/08',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '500',
#   '3,300,000'),
#  ('KR7004140000',
#   '004140',
#   '동방보통주',
#   '동방',
#   'DongbangTransport&Logistics',
#   '1988/08/10',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '47,971,766'),
#  ('KR7004150009',
#   '004150',
#   '한솔홀딩스보통주',
#   '한솔홀딩스',
#   'Hansol Holdings',
#   '1972/05/17',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '42,008,577'),
#  ('KR7004170007',
#   '004170',
#   '신세계보통주',
#   '신세계',
#   'Shinsegae Co.,Ltd',
#   '1985/08/19',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '9,845,181'),
#  ('KR7004250007',
#   '004250',
#   'NPC보통주',
#   'NPC',
#   'NPC',
#   '1969/09/08',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '36,720,000'),
#  ('KR7004251005',
#   '004255',
#   'NPC1우선주',
#   'NPC우',
#   'NPC(1P)',
#   '1990/01/15',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '500',
#   '5,280,000'),
#  ('KR7004270005',
#   '004270',
#   '남성보통주',
#   '남성',
#   'Namsung',
#   '1989/11/14',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '36,212,160'),
#  ('KR7004310009',
#   '004310',
#   '현대약품보통주',
#   '현대약품',
#   'Hyundai pharm',
#   '1978/06/28',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '32,000,000'),
#  ('KR7004360004',
#   '004360',
#   '세방보통주',
#   '세방',
#   'SEBANG',
#   '1977/05/19',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '19,308,690'),
#  ('KR7004361002',
#   '004365',
#   '세방1우선주',
#   '세방우',
#   'SEBANG(1P)',
#   '1989/10/21',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '500',
#   '3,689,250'),
#  ('KR7004370003',
#   '004370',
#   '농심보통주',
#   '농심',
#   'Nongshim',
#   '1976/06/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '6,082,642'),
#  ('KR7004380002',
#   '004380',
#   '삼익THK보통주',
#   '삼익THK',
#   'SAMICK THK',
#   '1989/09/26',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '21,000,000'),
#  ('KR7004410007',
#   '004410',
#   '서울식품공업보통주',
#   '서울식품',
#   'SeoulFoodInd',
#   '1973/12/28',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '100',
#   '372,316,535'),
#  ('KR7004411005',
#   '004415',
#   '서울식품공업1우선주',
#   '서울식품우',
#   'SeoulFoodInd(1P)',
#   '1989/05/22',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '100',
#   '2,224,500'),
#  ('KR7004430005',
#   '004430',
#   '송원산업보통주',
#   '송원산업',
#   'SongwonIndustrial',
#   '1977/06/25',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '24,000,000'),
#  ('KR7004440004',
#   '004440',
#   '삼일씨엔에스보통주',
#   '삼일씨엔에스',
#   'SAMIL C&S',
#   '2016/03/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '12,731,947'),
#  ('KR7004450003',
#   '004450',
#   '삼화왕관보통주',
#   '삼화왕관',
#   'SamhwaCrown&Closure',
#   '1976/05/28',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '2,154,379'),
#  ('KR7004490009',
#   '004490',
#   '세방전지보통주',
#   '세방전지',
#   'SEBANG GLOBAL BATTERY',
#   '1987/11/28',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '14,000,000'),
#  ('KR7004540001',
#   '004540',
#   '깨끗한나라보통주',
#   '깨끗한나라',
#   'KleanNara',
#   '1975/06/25',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '37,240,693'),
#  ('KR7004541009',
#   '004545',
#   '깨끗한나라1우선주',
#   '깨끗한나라우',
#   'KleanNara(1P)',
#   '1988/11/21',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '1,000',
#   '366,160'),
#  ('KR7004560009',
#   '004560',
#   '현대비앤지스틸보통주',
#   '현대비앤지스틸',
#   'HYUNDAI BNG STEEL',
#   '1987/03/24',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '15,078,811'),
#  ('KR7004561007',
#   '004565',
#   '현대비앤지스틸1우선주',
#   '현대비앤지스틸우',
#   'HYUNDAI BNG STEEL(1P)',
#   '1989/08/31',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '109,852'),
#  ('KR7004590006',
#   '004590',
#   '한국가구',
#   '한국가구',
#   'KoreaFurniture',
#   '1993/06/03',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '100',
#   '15,000,000'),
#  ('KR7004650008',
#   '004650',
#   '창해에탄올',
#   '창해에탄올',
#   'Changhae Ethanol Co., Ltd.',
#   '2014/07/30',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '9,190,885'),
#  ('KR7004690004',
#   '004690',
#   '삼천리보통주',
#   '삼천리',
#   'Samchully',
#   '1976/12/23',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '4,055,025'),
#  ('KR7004700001',
#   '004700',
#   '조광피혁보통주',
#   '조광피혁',
#   'ChokwangLeather',
#   '1977/05/27',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '6,649,138'),
#  ('KR7004710000',
#   '004710',
#   '한솔테크닉스보통주',
#   '한솔테크닉스',
#   'HansolTechnics',
#   '1988/07/06',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '32,109,878'),
#  ('KR7004720009',
#   '004720',
#   '팜젠사이언스보통주',
#   '팜젠사이언스',
#   'PharmGen Science',
#   '1990/06/15',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '15,477,041'),
#  ('KR7004770004',
#   '004770',
#   '써니전자보통주',
#   '써니전자',
#   'SunnyElectronics',
#   '1987/04/22',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '34,845,011'),
#  ('KR7004780003',
#   '004780',
#   '대륙제관',
#   '대륙제관',
#   'DaeryukCan',
#   '1994/12/29',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '15,903,199'),
#  ('KR7004800009',
#   '004800',
#   '효성보통주',
#   '효성',
#   'Hyosung',
#   '1973/06/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '21,071,025'),
#  ('KR7004830006',
#   '004830',
#   '덕성보통주',
#   '덕성',
#   'Duksung',
#   '1987/09/25',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '15,680,000'),
#  ('KR7004831004',
#   '004835',
#   '덕성1우선주',
#   '덕성우',
#   'Duksung(1P)',
#   '1989/12/19',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '500',
#   '1,392,000'),
#  ('KR7004840005',
#   '004840',
#   '디알비동일보통주',
#   'DRB동일',
#   'DRB Holding Co.,Ltd',
#   '1976/05/21',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '19,930,000'),
#  ('KR7004870002',
#   '004870',
#   '티웨이홀딩스보통주',
#   '티웨이홀딩스',
#   "T'way Holdings",
#   '1977/06/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '109,472,167'),
#  ('KR7004890000',
#   '004890',
#   '동일산업보통주',
#   '동일산업',
#   'DONGILINDUSTRIESCO.,LTD',
#   '2005/06/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '2,425,215'),
#  ('KR7004910006',
#   '004910',
#   '조광페인트보통주',
#   '조광페인트',
#   'ChokwangPaint',
#   '1976/12/27',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '12,800,000'),
#  ('KR7004920005',
#   '004920',
#   '씨아이테크보통주',
#   '씨아이테크',
#   'CITECH',
#   '1989/11/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '39,951,719'),
#  ('KR7004960001',
#   '004960',
#   '한신공영보통주',
#   '한신공영',
#   'HanshinConstruction',
#   '1976/07/07',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '11,570,702'),
#  ('KR7004970000',
#   '004970',
#   '신라교역보통주',
#   '신라교역',
#   'Silla',
#   '1976/06/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '16,000,000'),
#  ('KR7004980009',
#   '004980',
#   '성신양회보통주',
#   '성신양회',
#   'SungshinCement',
#   '1976/06/30',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '24,516,073'),
#  ('KR7004981007',
#   '004985',
#   '성신양회1우선주',
#   '성신양회우',
#   'SungshinCement(1P)',
#   '1988/12/21',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '735,645'),
#  ('KR7004990008',
#   '004990',
#   '롯데지주보통주',
#   '롯데지주',
#   'Lotte Corporation',
#   '1974/02/16',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '200',
#   '104,909,237'),
#  ('KR700499K014',
#   '00499K',
#   '롯데지주1우선주',
#   '롯데지주우',
#   'Lotte Corporation(1P)',
#   '2017/10/30',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '200',
#   '987,623'),
#  ('KR7005010004',
#   '005010',
#   '휴스틸보통주',
#   '휴스틸',
#   'HUSTEEL',
#   '1973/06/29',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '7,837,615'),
#  ('KR7005030002',
#   '005030',
#   '부산주공보통주',
#   '부산주공',
#   'PusanCastIron',
#   '1975/12/26',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '65,973,604'),
#  ('KR7005070008',
#   '005070',
#   '코스모신소재보통주',
#   '코스모신소재',
#   'CosmoAM&T',
#   '1987/09/28',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '30,086,889'),
#  ('KR7005090006',
#   '005090',
#   'SGC에너지보통주',
#   'SGC에너지',
#   'SGC Energy',
#   '1993/01/06',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '14,677,004'),
#  ('KR7005110002',
#   '005110',
#   '한창보통주',
#   '한창',
#   'Hanchang',
#   '1976/06/01',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '66,790,269'),
#  ('KR7005160007',
#   '005160',
#   '동국산업',
#   '동국산업',
#   'DONGKUK INDUSTRIES COMPANY',
#   '1999/06/25',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '1,000',
#   '54,244,482'),
#  ('KR7005180005',
#   '005180',
#   '빙그레보통주',
#   '빙그레',
#   'Binggrae',
#   '1978/08/31',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '9,851,241'),
#  ('KR7005250006',
#   '005250',
#   '녹십자홀딩스보통주',
#   '녹십자홀딩스',
#   'Green Cross Holdings Corporation',
#   '1978/08/28',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '47,028,210'),
#  ('KR7005252002',
#   '005257',
#   '녹십자홀딩스2우선주(신형)',
#   '녹십자홀딩스2우',
#   'Green Cross Holdings Corporation(2PB)',
#   '1997/03/19',
#   'KOSPI',
#   '주권',
#   '',
#   '신형우선주',
#   '500',
#   '845,990'),
#  ('KR7005290002',
#   '005290',
#   '동진쎄미켐',
#   '동진쎄미켐',
#   'DONGJIN SEMICHEM CO., LTD.',
#   '1999/12/21',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '51,414,494'),
#  ('KR7005300009',
#   '005300',
#   '롯데칠성음료보통주',
#   '롯데칠성',
#   'LotteChilsungBeverage',
#   '1973/06/21',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '9,278,884'),
#  ('KR7005301007',
#   '005305',
#   '롯데칠성음료1우선주',
#   '롯데칠성우',
#   'LotteChilsungBeverage(1P)',
#   '1989/09/21',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '500',
#   '775,310'),
#  ('KR7005320007',
#   '005320',
#   '국동보통주',
#   '국동',
#   'Kukdong',
#   '1996/12/24',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '55,208,808'),
#  ('KR7005360003',
#   '005360',
#   '모나미보통주',
#   '모나미',
#   'Monami',
#   '1974/06/26',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '18,897,307'),
#  ('KR7005380001',
#   '005380',
#   '현대자동차보통주',
#   '현대차',
#   'HyundaiMotor',
#   '1974/06/28',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '213,668,187'),
#  ('KR7005381009',
#   '005385',
#   '현대자동차1우선주',
#   '현대차우',
#   'HyundaiMotor(1P)',
#   '1989/09/11',
#   'KOSPI',
#   '주권',
#   '',
#   '구형우선주',
#   '5,000',
#   '24,356,685'),
#  ('KR7005382007',
#   '005387',
#   '현대자동차2우선주(신형)',
#   '현대차2우B',
#   'HyundaiMotor(2PB)',
#   '1998/12/02',
#   'KOSPI',
#   '주권',
#   '',
#   '신형우선주',
#   '5,000',
#   '36,485,451'),
#  ('KR7005383005',
#   '005389',
#   '현대자동차3우선주(신형)',
#   '현대차3우B',
#   'HyundaiMotor(3PB)',
#   '1999/04/15',
#   'KOSPI',
#   '주권',
#   '',
#   '신형우선주',
#   '5,000',
#   '2,428,735'),
#  ('KR7005390000',
#   '005390',
#   '신성통상보통주',
#   '신성통상',
#   'ShinsungTongsang',
#   '1975/12/22',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '143,708,390'),
#  ('KR7005420005',
#   '005420',
#   '코스모화학보통주',
#   '코스모화학',
#   'COSMOCHEMICALCO',
#   '1987/07/23',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '27,860,157'),
#  ('KR7005430004',
#   '005430',
#   '한국공항보통주',
#   '한국공항',
#   'KoreaAirportService',
#   '1976/12/28',
# ...
#   '038340',
#   '유씨아이',
#   'UCI',
#   'UCI Co.,Ltd.',
#   '2001/11/22',
#   'KOSDAQ',
#   '주권',
#   '투자주의환기종목(소속부없음)',
#   '보통주',
#   '500',
#   '12,465,789'),
#  ('KR7038390001',
#   '038390',
#   '레드캡투어',
#   '레드캡투어',
#   'RedcapTour Co., Ltd.',
#   '2000/02/01',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '8,589,480'),
#  ('KR7038460002',
#   '038460',
#   '바이오스마트',
#   '바이오스마트',
#   'BioSmart Co., Ltd.',
#   '2000/06/22',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '20,087,800'),
#  ('KR7038500005',
#   '038500',
#   '삼표시멘트',
#   '삼표시멘트',
#   'SAMPYO Cement Co., Ltd.',
#   '2001/02/01',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '107,916,306'),
#  ('KR7038530002',
#   '038530',
#   '골드퍼시픽',
#   '골드퍼시픽',
#   'Gold Pacific Co.,Ltd',
#   '2000/06/09',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '92,016,431'),
#  ('KR7038540001',
#   '038540',
#   '상상인',
#   '상상인',
#   'Sangsangin Co., Ltd.',
#   '2000/08/18',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '1,000',
#   '55,328,313'),
#  ('KR7038620001',
#   '038620',
#   '위즈코프',
#   '위즈코프',
#   'WIZ CORP, Inc.',
#   '2000/05/04',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '66,546,465'),
#  ('KR7038680005',
#   '038680',
#   '에스넷시스템',
#   '에스넷',
#   'S NET SYSTEMS.Inc',
#   '2000/04/27',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '16,145,163'),
#  ('KR7038870002',
#   '038870',
#   '에코바이오홀딩스',
#   '에코바이오',
#   'EcoBio Holdings Co., Ltd.',
#   '2001/05/29',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '11,610,994'),
#  ('KR7038880001',
#   '038880',
#   '아이에이',
#   '아이에이',
#   'iA, Inc.',
#   '2000/04/27',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '100',
#   '294,769,150'),
#  ('KR7038950002',
#   '038950',
#   '파인디지털',
#   '파인디지털',
#   'FINEDIGITAL Inc.',
#   '2000/05/04',
#   'KOSDAQ',
#   '주권',
#   '벤처기업부',
#   '보통주',
#   '500',
#   '10,210,765'),
#  ('KR7039010004',
#   '039010',
#   '현대에이치티',
#   '현대에이치티',
#   'HYUNDAI HT',
#   '2000/07/20',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '8,625,000'),
#  ('KR7039020003',
#   '039020',
#   '이건홀딩스',
#   '이건홀딩스',
#   'EAGON HOLDINGS CO., LTD.',
#   '2000/05/04',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '1,000',
#   '22,584,709'),
#  ('KR7039030002',
#   '039030',
#   '이오테크닉스',
#   '이오테크닉스',
#   'EO Technics Co., Ltd.',
#   '2000/08/24',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '12,319,550'),
#  ('KR7039130000',
#   '039130',
#   '하나투어보통주',
#   '하나투어',
#   'HANATOUR SERVICE',
#   '2011/11/01',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '13,939,185'),
#  ('KR7039200001',
#   '039200',
#   '오스코텍',
#   '오스코텍',
#   'OSCOTEC Inc.',
#   '2007/01/17',
#   'KOSDAQ',
#   '주권',
#   '벤처기업부',
#   '보통주',
#   '500',
#   '30,206,525'),
#  ('KR7039240007',
#   '039240',
#   '경남스틸',
#   '경남스틸',
#   'Kyeong Nam Steel Co., LTD',
#   '2000/03/07',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '100',
#   '26,979,604'),
#  ('KR7039290002',
#   '039290',
#   '인포뱅크',
#   '인포뱅크',
#   'InfoBank Corporation',
#   '2006/07/04',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '8,693,978'),
#  ('KR7039310008',
#   '039310',
#   '세중',
#   '세중',
#   'SEJOONG CO., LTD.',
#   '2000/06/09',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '18,121,667'),
#  ('KR7039340005',
#   '039340',
#   '한국경제티브이',
#   '한국경제TV',
#   'Korea Business News CO., LTD.',
#   '2004/07/30',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '23,000,000'),
#  ('KR7039420005',
#   '039420',
#   '케이엘넷',
#   '케이엘넷',
#   'KL-Net Corp.',
#   '2002/03/12',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '24,154,730'),
#  ('KR7039440003',
#   '039440',
#   '에스티아이',
#   '에스티아이',
#   'Systems Technology Incorporated',
#   '2002/02/28',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '15,830,000'),
#  ('KR7039490008',
#   '039490',
#   '키움증권보통주',
#   '키움증권',
#   'KIWOOM Securities',
#   '2009/08/03',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '26,219,513'),
#  ('KR7039560008',
#   '039560',
#   '다산네트웍스',
#   '다산네트웍스',
#   'DASAN Networks, Inc.',
#   '2000/06/22',
#   'KOSDAQ',
#   '주권',
#   '벤처기업부',
#   '보통주',
#   '500',
#   '36,380,838'),
#  ('KR7039570007',
#   '039570',
#   '에이치디씨랩스보통주',
#   'HDC랩스',
#   'HDCLABS',
#   '2015/09/24',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '25,957,601'),
#  ('KR7039610001',
#   '039610',
#   '화성밸브',
#   '화성밸브',
#   'HS VALVE CO., LTD',
#   '2000/03/16',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '10,410,400'),
#  ('KR7039670005',
#   '039670',
#   '스포츠서울',
#   '스포츠서울',
#   'The Sports Seoul',
#   '2004/01/16',
#   'KOSDAQ',
#   '주권',
#   '관리종목(소속부없음)',
#   '보통주',
#   '500',
#   '9,211,617'),
#  ('KR7039740006',
#   '039740',
#   '한국정보공학',
#   '한국정보공학',
#   'Korea Information Engineering Services',
#   '2000/07/06',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '8,018,397'),
#  ('KR7039830005',
#   '039830',
#   '오로라월드',
#   '오로라',
#   'AURORA WORLD Corporation',
#   '2001/01/03',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '10,762,890'),
#  ('KR7039840004',
#   '039840',
#   '디오',
#   '디오',
#   'DIO Corporation',
#   '2000/06/29',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '15,774,309'),
#  ('KR7039860002',
#   '039860',
#   '나노엔텍',
#   '나노엔텍',
#   'NanoenTek,Inc.',
#   '2000/08/16',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '26,807,627'),
#  ('KR7039980008',
#   '039980',
#   '리노스',
#   '리노스',
#   'LEENOS CORP.',
#   '2002/08/13',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '43,576,286'),
#  ('KR7040160004',
#   '040160',
#   '누리플렉스',
#   '누리플렉스',
#   'NuriFlex',
#   '2000/08/29',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '12,055,535'),
#  ('KR7040300006',
#   '040300',
#   '와이티엔',
#   'YTN',
#   'YTN',
#   '2001/09/04',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '1,000',
#   '42,000,000'),
#  ('KR7040350001',
#   '040350',
#   '큐로컴',
#   '큐로컴',
#   'CUROCOM Co.,Ltd',
#   '2002/01/10',
#   'KOSDAQ',
#   '주권',
#   '벤처기업부',
#   '보통주',
#   '500',
#   '125,973,472'),
#  ('KR7040420002',
#   '040420',
#   '정상제이엘에스',
#   '정상제이엘에스',
#   'JLS CO.,LTD.',
#   '2000/08/01',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '15,677,552'),
#  ('KR7040610008',
#   '040610',
#   '에스지엔지',
#   'SG&G',
#   'SG&G Corporation',
#   '2000/04/27',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '34,087,196'),
#  ('KR7040910002',
#   '040910',
#   '아이씨디',
#   '아이씨디',
#   'ICD Co., Ltd.',
#   '2011/08/05',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '18,065,413'),
#  ('KR7041020009',
#   '041020',
#   '폴라리스오피스',
#   '폴라리스오피스',
#   'Polaris Office',
#   '2005/10/28',
#   'KOSDAQ',
#   '주권',
#   '벤처기업부',
#   '보통주',
#   '500',
#   '41,395,629'),
#  ('KR7041140005',
#   '041140',
#   '넥슨지티',
#   '넥슨지티',
#   'Nexon GT Co., Ltd.',
#   '2000/07/25',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '35,373,322'),
#  ('KR7041190000',
#   '041190',
#   '우리기술투자',
#   '우리기술투자',
#   'Woori Technology Investment Co., Ltd',
#   '2000/06/09',
#   'KOSDAQ',
#   '주권',
#   '벤처기업부',
#   '보통주',
#   '500',
#   '84,000,000'),
#  ('KR7041440009',
#   '041440',
#   '현대에버다임',
#   '현대에버다임',
#   'HYUNDAI EVERDIGM',
#   '2003/11/14',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '17,915,944'),
#  ('KR7041460007',
#   '041460',
#   '한국전자인증',
#   '한국전자인증',
#   'Korea Electronic Certification Authority Inc.',
#   '2010/11/19',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '19,000,000'),
#  ('KR7041510009',
#   '041510',
#   '에스엠엔터테인먼트',
#   '에스엠',
#   'SM ENTERTAINMENT CO., Ltd.',
#   '2000/04/27',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '23,773,301'),
#  ('KR7041520008',
#   '041520',
#   '이라이콤',
#   '이라이콤',
#   'e-LITECOM CO., LTD.',
#   '2003/07/04',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '12,188,730'),
#  ('KR7041590001',
#   '041590',
#   '플래스크',
#   '플래스크',
#   'Flask',
#   '2002/11/01',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '121,433,730'),
#  ('KR7041650003',
#   '041650',
#   '상신브레이크보통주',
#   '상신브레이크',
#   'SANGSINBRAKE',
#   '2004/10/27',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '21,471,450'),
#  ('KR7041830001',
#   '041830',
#   '인바디',
#   '인바디',
#   'InBody Co., Ltd.',
#   '2000/12/14',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '13,683,782'),
#  ('KR7041910001',
#   '041910',
#   '에스텍파마',
#   '에스텍파마',
#   'ESTECHPHARMA CO., LTD',
#   '2004/02/06',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '11,898,263'),
#  ('KR7041920000',
#   '041920',
#   '메디아나',
#   '메디아나',
#   'MEDIANA Co.,LTD',
#   '2014/10/07',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '16,000,000'),
#  ('KR7041930009',
#   '041930',
#   '동아화성',
#   '동아화성',
#   'DONG-A HWA SUNG CO.,LTD',
#   '2001/12/26',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '15,800,000'),
#  ('KR7041960006',
#   '041960',
#   '코미팜',
#   '코미팜',
#   'KOMIPHARM INTERNATIONAL CO., LTD.',
#   '2001/10/30',
#   'KOSDAQ',
#   '주권',
#   '벤처기업부',
#   '보통주',
#   '100',
#   '64,185,876'),
#  ('KR7042000000',
#   '042000',
#   '카페24',
#   '카페24',
#   'Cafe24 Corp.',
#   '2018/02/08',
#   'KOSDAQ',
#   '주권',
#   '기술성장기업부',
#   '보통주',
#   '500',
#   '22,497,198'),
#  ('KR7042040006',
#   '042040',
#   '케이피엠테크',
#   '케이피엠테크',
#   'KPM TECH CO., LTD.',
#   '2003/01/07',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '100',
#   '145,677,729'),
#  ('KR7042110007',
#   '042110',
#   '에스씨디',
#   '에스씨디',
#   'SCD CO.,LTD.',
#   '2000/07/13',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '48,329,564'),
#  ('KR7042370007',
#   '042370',
#   '비츠로테크',
#   '비츠로테크',
#   'Vitzro Tech Co., LTD.',
#   '2000/08/03',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '26,200,025'),
#  ('KR7042420000',
#   '042420',
#   '네오위즈홀딩스',
#   '네오위즈홀딩스',
#   'NEOWIZ HOLDINDS Corporation',
#   '2000/06/27',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '8,856,866'),
#  ('KR7042500009',
#   '042500',
#   '링네트',
#   '링네트',
#   'RingNet Co., Ltd.',
#   '2002/01/10',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '15,356,878'),
#  ('KR7042510008',
#   '042510',
#   '라온시큐어',
#   '라온시큐어',
#   'RaonSecure Co., Ltd.',
#   '2001/01/03',
#   'KOSDAQ',
#   '주권',
#   '벤처기업부',
#   '보통주',
#   '500',
#   '38,666,746'),
#  ('KR7042520007',
#   '042520',
#   '한스바이오메드',
#   '한스바이오메드',
#   'HANS BIOMED CORPORATION',
#   '2009/10/09',
#   'KOSDAQ',
#   '주권',
#   '벤처기업부',
#   '보통주',
#   '500',
#   '10,102,981'),
#  ('KR7042600007',
#   '042600',
#   '새로닉스',
#   '새로닉스',
#   'SERONICS. CO., LTD.',
#   '2002/10/01',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '12,423,574'),
#  ('KR7042660001',
#   '042660',
#   '대우조선해양보통주',
#   '대우조선해양',
#   'DAEWOOSHIPBUILDING&MARINEENGINEERING',
#   '2001/02/02',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '5,000',
#   '107,290,669'),
#  ('KR7042670000',
#   '042670',
#   '현대두산인프라코어보통주',
#   '현대두산인프라코어',
#   'Hyundai Doosan Infracore',
#   '2001/02/02',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '1,000',
#   '197,436,700'),
#  ('KR7042700005',
#   '042700',
#   '한미반도체보통주',
#   '한미반도체',
#   'HANMISemiconductorCO.,Ltd.',
#   '2005/07/22',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '100',
#   '98,919,754'),
#  ('KR7042940007',
#   '042940',
#   '상지카일룸',
#   '상지카일룸',
#   'Sangji Caelum, Inc.',
#   '2000/10/19',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '92,522,978'),
#  ('KR7043090000',
#   '043090',
#   '한창바이오텍',
#   '한창바이오텍',
#   'HanChang Biotech',
#   '2001/10/11',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '37,225,728'),
#  ('KR7043100007',
#   '043100',
#   '솔고바이오메디칼',
#   '솔고바이오',
#   'Solco Biomedical Co.,Ltd',
#   '2000/08/08',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '60,759,208'),
#  ('KR7043150002',
#   '043150',
#   '바텍',
#   '바텍',
#   'Value Added Technology Co., Ltd.',
#   '2006/09/29',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '14,854,256'),
#  ('KR7043200005',
#   '043200',
#   '파루',
#   '파루',
#   'PARU CO., LTD.',
#   '2000/07/19',
#   'KOSDAQ',
#   '주권',
#   '벤처기업부',
#   '보통주',
#   '500',
#   '41,804,315'),
#  ('KR7043220003',
#   '043220',
#   '에이치엘비파워',
#   '에이치엘비파워',
#   'HLB POWER Co., Ltd.',
#   '2001/07/03',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '91,115,377'),
#  ('KR7043260009',
#   '043260',
#   '성호전자',
#   '성호전자',
#   'SUNGHO ELECTRONICS CORP.',
#   '2001/11/29',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '53,405,384'),
#  ('KR7043340009',
#   '043340',
#   '에쎈테크',
#   '에쎈테크',
#   'ESSEN TECH CO., LTD.',
#   '2000/08/29',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '72,000,000'),
#  ('KR7043360007',
#   '043360',
#   '디지아이',
#   '디지아이',
#   'Digital Graphics Incorporation',
#   '2001/07/20',
#   'KOSDAQ',
#   '주권',
#   '벤처기업부',
#   '보통주',
#   '500',
#   '9,000,000'),
#  ('KR7043370006',
#   '043370',
#   '피에이치에이',
#   '피에이치에이',
#   'PHA',
#   '2001/12/13',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '21,000,000'),
#  ('KR7043590009',
#   '043590',
#   '크로바하이텍',
#   '크로바하이텍',
#   'CLOVER HITECHNOLOGY CO., LTD',
#   '2001/12/20',
#   'KOSDAQ',
#   '주권',
#   '관리종목(소속부없음)',
#   '보통주',
#   '500',
#   '35,755,643'),
#  ('KR7043610005',
#   '043610',
#   '지니뮤직',
#   '지니뮤직',
#   'GENIE MUSIC CORPORATION',
#   '2000/07/20',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '58,115,438'),
#  ('KR7043650001',
#   '043650',
#   '국순당',
#   '국순당',
#   'KOOK SOON DANG CO., LTD.',
#   '2000/08/24',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '17,858,304'),
#  ('KR7043710003',
#   '043710',
#   '서울리거',
#   '서울리거',
#   'SEOULEAGUER CO., LTD.',
#   '2002/07/11',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '39,111,384'),
#  ('KR7043910009',
#   '043910',
#   '자연과 환경',
#   '자연과환경',
#   'Nature and Environment Co., Ltd.',
#   '2005/11/18',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '81,293,968'),
#  ('KR7044060002',
#   '044060',
#   '조광아이엘아이',
#   '조광ILI',
#   'JOKWANG I.L.I CO., LTD',
#   '2001/01/18',
#   'KOSDAQ',
#   '주권',
#   '벤처기업부',
#   '보통주',
#   '500',
#   '15,039,996'),
#  ('KR7044180008',
#   '044180',
#   'KD',
#   'KD',
#   'KD Corporation',
#   '2000/11/16',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '24,848,641'),
#  ('KR7044340008',
#   '044340',
#   '위닉스',
#   '위닉스',
#   'WINIX INC.',
#   '2000/10/24',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '17,873,425'),
#  ('KR7044380004',
#   '044380',
#   '주연테크 보통주',
#   '주연테크',
#   'JOOYONTECH',
#   '2006/11/15',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '200',
#   '59,199,244'),
#  ('KR7044450005',
#   '044450',
#   '케이에스에스 해운 보통주',
#   'KSS해운',
#   'KSS LINE',
#   '2007/10/26',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '23,085,880'),
#  ('KR7044480002',
#   '044480',
#   '블루베리엔에프티',
#   '블루베리 NFT',
#   'Blueberry NFT',
#   '2001/01/11',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '32,343,981'),
#  ('KR7044490001',
#   '044490',
#   '태웅',
#   '태웅',
#   'TAEWOONG CO., LTD.',
#   '2001/11/08',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '20,007,381'),
#  ('KR7044780005',
#   '044780',
#   '에이치케이',
#   '에이치케이',
#   'HK CO., LTD.',
#   '2000/09/07',
#   'KOSDAQ',
#   '주권',
#   '벤처기업부',
#   '보통주',
#   '500',
#   '18,505,787'),
#  ('KR7044820009',
#   '044820',
#   '코스맥스비티아이 주식회사 보통주',
#   '코스맥스비티아이',
#   'COSMAX BTI',
#   '2006/11/13',
#   'KOSPI',
#   '주권',
#   '',
#   '보통주',
#   '500',
#   '9,603,921'),
#  ('KR7044960003',
#   '044960',
#   '이글벳',
#   '이글벳',
#   'Eagle Veterinary Technology Co.,Ltd',
#   '2000/11/16',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '12,641,883'),
#  ('KR7044990000',
#   '044990',
#   '에이치엔에스하이텍',
#   '에이치엔에스하이텍',
#   'H&S',
#   '2015/12/10',
#   'KONEX',
#   '주권',
#   '일반기업부',
#   '보통주',
#   '500',
#   '7,511,064'),
#  ('KR7045060001',
#   '045060',
#   '오공',
#   '오공',
#   'OKONG Corporation',
#   '2000/08/10',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '16,941,974'),
#  ('KR7045100005',
#   '045100',
#   '한양이엔지',
#   '한양이엔지',
#   'HANYANG ENG CO.,LTD.',
#   '2000/08/31',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '18,000,000'),
#  ('KR7045300001',
#   '045300',
#   '성우테크론',
#   '성우테크론',
#   'SUNGWOO TECHRON COMPANY',
#   '2001/12/18',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '9,586,649'),
#  ('KR7045340007',
#   '045340',
#   '토탈소프트뱅크',
#   '토탈소프트',
#   'TOTAL SOFT BANK LTD.',
#   '2002/07/19',
#   'KOSDAQ',
#   '주권',
#   '벤처기업부',
#   '보통주',
#   '500',
#   '8,558,040'),
#  ('KR7045390002',
#   '045390',
#   '대아티아이',
#   '대아티아이',
#   'DAEA TI CO., LTD.',
#   '2001/05/17',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '100',
#   '71,151,522'),
#  ('KR7045510005',
#   '045510',
#   '정원엔시스',
#   '정원엔시스',
#   'ZUNGWON EN-SYS INC.',
#   '2000/09/07',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '32,209,292'),
#  ('KR7045520004',
#   '045520',
#   '크린앤사이언스',
#   '크린앤사이언스',
#   'Clean & Science Co., Ltd',
#   '2000/12/05',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '6,500,000'),
#  ('KR7045660008',
#   '045660',
#   '에이텍',
#   '에이텍',
#   'ATEC CO.,Ltd',
#   '2001/05/24',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '8,260,000'),
#  ('KR7045970001',
#   '045970',
#   '코아시아',
#   '코아시아',
#   'CoAsia Corporation',
#   '2000/08/03',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '26,314,876'),
#  ('KR7046070009',
#   '046070',
#   '코다코',
#   '코다코',
#   'KODACO CO., LTD',
#   '2000/12/26',
#   'KOSDAQ',
#   '주권',
#   '중견기업부',
#   '보통주',
#   '500',
#   '39,064,256'),
#  ('KR7046110003',
#   '046110',
#   '한일네트웍스',
#   '한일네트웍스',
#   'HANIL NETWORKS CO., LTD.',
#   '2006/01/20',
#   'KOSDAQ',
#   '주권',
#   '우량기업부',
#   '보통주',
#   '500',
#   '11,954,227'),
#  ...)

# %%
get_stock_day("043650", 2)
# Out:
# [['2022.03.25', '9,960', '10', '9,950', '10,050', '9,910', '102,878'],
#  ['2022.03.24', '9,950', '130', '9,800', '9,950', '9,790', '63,736'],
#  ['2022.03.23', '9,820', '60', '9,950', '10,100', '9,810', '111,413'],
#  ['2022.03.22', '9,880', '0', '9,900', '9,920', '9,700', '87,838'],
#  ['2022.03.21', '9,880', '20', '9,900', '9,990', '9,870', '61,223'],
#  ['2022.03.18', '9,900', '120', '9,870', '10,050', '9,750', '162,872'],
#  ['2022.03.17', '9,780', '300', '9,560', '9,780', '9,550', '163,960'],
#  ['2022.03.16', '9,480', '130', '9,470', '9,490', '9,330', '88,307'],
#  ['2022.03.15', '9,350', '150', '9,440', '9,590', '9,330', '155,927'],
#  ['2022.03.14', '9,500', '450', '9,860', '9,910', '9,390', '364,240']]

# %%
cur.execute("SELECT * FROM stock WHERE code ='005930'")
# Out:
# 100

# %%
cur.execute("SELECT * FROM master WHERE ISU_SRT_CD = '00'")

# %%
cur.fetchall()
# Out:
# (('005930',
#   datetime.date(2021, 11, 12),
#   70600,
#   700,
#   70200,
#   70900,
#   69900,
#   10087450),
#  ('005930',
#   datetime.date(2021, 11, 15),
#   71400,
#   800,
#   71700,
#   71900,
#   70900,
#   12420710),
#  ('005930',
#   datetime.date(2021, 11, 16),
#   71300,
#   100,
#   71500,
#   72000,
#   71300,
#   10919239),
#  ('005930',
#   datetime.date(2021, 11, 17),
#   70700,
#   600,
#   71300,
#   71600,
#   70600,
#   11027606),
#  ('005930',
#   datetime.date(2021, 11, 18),
#   70200,
#   500,
#   70700,
#   71000,
#   70200,
#   10144957),
#  ('005930',
#   datetime.date(2021, 11, 19),
#   71200,
#   1000,
#   70400,
#   71400,
#   70100,
#   11954728),
#  ('005930',
#   datetime.date(2021, 11, 22),
#   74900,
#   3700,
#   73300,
#   75200,
#   73000,
#   27506623),
#  ('005930',
#   datetime.date(2021, 11, 23),
#   75300,
#   400,
#   76000,
#   76000,
#   74500,
#   22029195),
#  ('005930',
#   datetime.date(2021, 11, 24),
#   74800,
#   500,
#   76000,
#   76200,
#   74100,
#   15652305),
#  ('005930',
#   datetime.date(2021, 11, 25),
#   73700,
#   1100,
#   75100,
#   75100,
#   73600,
#   12559258),
#  ('005930',
#   datetime.date(2021, 11, 26),
#   72300,
#   1400,
#   73500,
#   74100,
#   72000,
#   13002242),
#  ('005930',
#   datetime.date(2021, 11, 29),
#   72300,
#   0,
#   71700,
#   73000,
#   71400,
#   16682559),
#  ('005930',
#   datetime.date(2021, 11, 30),
#   71300,
#   1000,
#   73200,
#   73900,
#   70500,
#   30364841),
#  ('005930',
#   datetime.date(2021, 12, 1),
#   74400,
#   3100,
#   72000,
#   74800,
#   71600,
#   21954856),
#  ('005930',
#   datetime.date(2021, 12, 2),
#   75800,
#   1400,
#   73900,
#   75800,
#   73800,
#   23652940),
#  ('005930',
#   datetime.date(2021, 12, 3),
#   75600,
#   200,
#   75600,
#   76000,
#   74100,
#   18330240),
#  ('005930',
#   datetime.date(2021, 12, 6),
#   76300,
#   700,
#   75100,
#   76700,
#   74900,
#   16391250),
#  ('005930',
#   datetime.date(2021, 12, 7),
#   77400,
#   1100,
#   76100,
#   77700,
#   75600,
#   19232453),
#  ('005930',
#   datetime.date(2021, 12, 8),
#   77400,
#   0,
#   78300,
#   78600,
#   77100,
#   21558340),
#  ('005930',
#   datetime.date(2021, 12, 9),
#   78200,
#   800,
#   77400,
#   78200,
#   77000,
#   21604528),
#  ('005930',
#   datetime.date(2021, 12, 10),
#   76900,
#   1300,
#   77400,
#   77600,
#   76800,
#   9155219),
#  ('005930',
#   datetime.date(2021, 12, 13),
#   76800,
#   100,
#   77200,
#   78300,
#   76500,
#   15038750),
#  ('005930',
#   datetime.date(2021, 12, 14),
#   77000,
#   200,
#   76500,
#   77200,
#   76200,
#   10976660),
#  ('005930',
#   datetime.date(2021, 12, 15),
#   77600,
#   600,
#   76400,
#   77600,
#   76300,
#   9584939),
#  ('005930',
#   datetime.date(2021, 12, 16),
#   77800,
#   200,
#   78500,
#   78500,
#   77400,
#   11996128),
#  ('005930',
#   datetime.date(2021, 12, 17),
#   78000,
#   200,
#   76800,
#   78000,
#   76800,
#   13108479),
#  ('005930',
#   datetime.date(2021, 12, 20),
#   77100,
#   900,
#   77600,
#   77800,
#   76800,
#   11264375),
#  ('005930',
#   datetime.date(2021, 12, 21),
#   78100,
#   1000,
#   77900,
#   78300,
#   77500,
#   14245298),
#  ('005930',
#   datetime.date(2021, 12, 22),
#   79400,
#   1300,
#   78900,
#   79400,
#   78800,
#   17105892),
#  ('005930',
#   datetime.date(2021, 12, 23),
#   79900,
#   500,
#   79800,
#   80000,
#   79300,
#   13577498),
#  ('005930',
#   datetime.date(2021, 12, 24),
#   80500,
#   600,
#   80200,
#   80800,
#   80200,
#   12086380),
#  ('005930',
#   datetime.date(2021, 12, 27),
#   80200,
#   300,
#   80600,
#   80600,
#   79800,
#   10783368),
#  ('005930',
#   datetime.date(2021, 12, 28),
#   80300,
#   100,
#   80200,
#   80400,
#   79700,
#   18226325),
#  ('005930',
#   datetime.date(2021, 12, 29),
#   78800,
#   1500,
#   80200,
#   80200,
#   78500,
#   19794795),
#  ('005930',
#   datetime.date(2021, 12, 30),
#   78300,
#   500,
#   78900,
#   79500,
#   78100,
#   14236700),
#  ('005930',
#   datetime.date(2022, 1, 3),
#   78600,
#   300,
#   79400,
#   79800,
#   78200,
#   13502112),
#  ('005930',
#   datetime.date(2022, 1, 4),
#   78700,
#   100,
#   78800,
#   79200,
#   78300,
#   12427416),
#  ('005930',
#   datetime.date(2022, 1, 5),
#   77400,
#   1300,
#   78800,
#   79000,
#   76400,
#   25470640),
#  ('005930',
#   datetime.date(2022, 1, 6),
#   76900,
#   500,
#   76700,
#   77600,
#   76600,
#   12931954),
#  ('005930',
#   datetime.date(2022, 1, 7),
#   78300,
#   1400,
#   78100,
#   78400,
#   77400,
#   15163757),
#  ('005930',
#   datetime.date(2022, 1, 10),
#   78000,
#   300,
#   78100,
#   78100,
#   77100,
#   9947422),
#  ('005930',
#   datetime.date(2022, 1, 11),
#   78900,
#   900,
#   78400,
#   79000,
#   78000,
#   13221123),
#  ('005930',
#   datetime.date(2022, 1, 12),
#   78900,
#   0,
#   79500,
#   79600,
#   78600,
#   11000502),
#  ('005930',
#   datetime.date(2022, 1, 13),
#   77900,
#   1000,
#   79300,
#   79300,
#   77900,
#   13889401),
#  ('005930',
#   datetime.date(2022, 1, 14),
#   77300,
#   600,
#   77700,
#   78100,
#   77100,
#   10096725),
#  ('005930',
#   datetime.date(2022, 1, 17),
#   77500,
#   200,
#   77600,
#   77800,
#   76900,
#   8785122),
#  ('005930',
#   datetime.date(2022, 1, 18),
#   77000,
#   500,
#   77600,
#   77800,
#   76600,
#   9592788),
#  ('005930',
#   datetime.date(2022, 1, 19),
#   76300,
#   700,
#   76500,
#   76900,
#   76100,
#   10598290),
#  ('005930',
#   datetime.date(2022, 1, 20),
#   76500,
#   200,
#   76200,
#   76700,
#   75900,
#   9708168),
#  ('005930',
#   datetime.date(2022, 1, 21),
#   75600,
#   900,
#   75800,
#   75800,
#   74700,
#   15774888),
#  ('005930',
#   datetime.date(2022, 1, 24),
#   75100,
#   500,
#   75400,
#   75800,
#   74700,
#   13691134),
#  ('005930',
#   datetime.date(2022, 1, 25),
#   74000,
#   1100,
#   74800,
#   75000,
#   73200,
#   17766704),
#  ('005930',
#   datetime.date(2022, 1, 26),
#   73300,
#   700,
#   73900,
#   74400,
#   73100,
#   12976730),
#  ('005930',
#   datetime.date(2022, 1, 27),
#   71300,
#   2000,
#   73800,
#   74000,
#   71300,
#   22274777),
#  ('005930',
#   datetime.date(2022, 1, 28),
#   73300,
#   2000,
#   71300,
#   73700,
#   71200,
#   21367447),
#  ('005930',
#   datetime.date(2022, 2, 3),
#   73300,
#   0,
#   74900,
#   74900,
#   73300,
#   17744721),
#  ('005930',
#   datetime.date(2022, 2, 4),
#   74000,
#   700,
#   74300,
#   74600,
#   73400,
#   12730034),
#  ('005930',
#   datetime.date(2022, 2, 7),
#   73000,
#   1000,
#   73500,
#   73600,
#   72400,
#   14240838),
#  ('005930',
#   datetime.date(2022, 2, 8),
#   73500,
#   500,
#   73800,
#   74200,
#   73000,
#   11736666),
#  ('005930',
#   datetime.date(2022, 2, 9),
#   74700,
#   1200,
#   74300,
#   74700,
#   74000,
#   9699122),
#  ('005930',
#   datetime.date(2022, 2, 10),
#   75400,
#   700,
#   75600,
#   75800,
#   74700,
#   17746033),
#  ('005930',
#   datetime.date(2022, 2, 11),
#   74900,
#   500,
#   75000,
#   75500,
#   74600,
#   12205407),
#  ('005930',
#   datetime.date(2022, 2, 14),
#   73700,
#   1200,
#   74400,
#   74500,
#   73100,
#   13993255),
#  ('005930',
#   datetime.date(2022, 2, 15),
#   73700,
#   0,
#   74100,
#   74200,
#   73100,
#   9320365),
#  ('005930',
#   datetime.date(2022, 2, 16),
#   74800,
#   1100,
#   74600,
#   74900,
#   74200,
#   10767386),
#  ('005930',
#   datetime.date(2022, 2, 17),
#   75000,
#   200,
#   75000,
#   75600,
#   74500,
#   13605382),
#  ('005930',
#   datetime.date(2022, 2, 18),
#   74300,
#   700,
#   74600,
#   74800,
#   73700,
#   10122226),
#  ('005930',
#   datetime.date(2022, 2, 21),
#   74200,
#   100,
#   73200,
#   74300,
#   72600,
#   10489717),
#  ('005930',
#   datetime.date(2022, 2, 22),
#   73400,
#   800,
#   73000,
#   73400,
#   72800,
#   11692469),
#  ('005930',
#   datetime.date(2022, 2, 23),
#   73000,
#   400,
#   73800,
#   73800,
#   72800,
#   10397964),
#  ('005930',
#   datetime.date(2022, 2, 24),
#   71500,
#   1500,
#   72300,
#   72300,
#   71300,
#   15759283),
#  ('005930',
#   datetime.date(2022, 2, 25),
#   71900,
#   400,
#   72100,
#   72600,
#   71900,
#   13168484),
#  ('005930',
#   datetime.date(2022, 2, 28),
#   72100,
#   200,
#   71100,
#   72100,
#   71000,
#   17781783),
#  ('005930',
#   datetime.date(2022, 3, 2),
#   71700,
#   400,
#   72300,
#   72400,
#   71500,
#   12481430),
#  ('005930',
#   datetime.date(2022, 3, 3),
#   72900,
#   1200,
#   72300,
#   73100,
#   72200,
#   13232638),
#  ('005930',
#   datetime.date(2022, 3, 4),
#   71500,
#   1400,
#   72700,
#   72700,
#   71200,
#   13409634),
#  ('005930',
#   datetime.date(2022, 3, 7),
#   70100,
#   1400,
#   70000,
#   70600,
#   69900,
#   18617138),
#  ('005930',
#   datetime.date(2022, 3, 8),
#   69500,
#   600,
#   68800,
#   70000,
#   68700,
#   15828269),
#  ('005930',
#   datetime.date(2022, 3, 10),
#   71200,
#   1700,
#   70800,
#   71200,
#   70500,
#   21159248),
#  ('005930',
#   datetime.date(2022, 3, 11),
#   70000,
#   1200,
#   70500,
#   70700,
#   69700,
#   15787655),
#  ('005930',
#   datetime.date(2022, 3, 14),
#   70200,
#   200,
#   70000,
#   70200,
#   69600,
#   9040993),
#  ('005930',
#   datetime.date(2022, 3, 15),
#   69500,
#   700,
#   69800,
#   70100,
#   69500,
#   10258562),
#  ('005930',
#   datetime.date(2022, 3, 16),
#   70400,
#   900,
#   70200,
#   70500,
#   69700,
#   10175750),
#  ('005930',
#   datetime.date(2022, 3, 17),
#   71200,
#   800,
#   71200,
#   71800,
#   70900,
#   17646315),
#  ('005930',
#   datetime.date(2022, 3, 18),
#   70700,
#   500,
#   70600,
#   70900,
#   70200,
#   14410038),
#  ('005930',
#   datetime.date(2022, 3, 21),
#   69900,
#   800,
#   70900,
#   71000,
#   69900,
#   11169002),
#  ('005930',
#   datetime.date(2022, 3, 22),
#   70300,
#   400,
#   69900,
#   70500,
#   69900,
#   9402666),
#  ('005930',
#   datetime.date(2022, 3, 23),
#   70500,
#   200,
#   70600,
#   71200,
#   70300,
#   12398025),
#  ('005930',
#   datetime.date(2022, 3, 24),
#   69800,
#   700,
#   69600,
#   70300,
#   69600,
#   37943357),
#  ('005930',
#   datetime.date(2022, 3, 25),
#   69800,
#   0,
#   70100,
#   70200,
#   69600,
#   12986010),
#  ('005930',
#   datetime.date(2022, 3, 28),
#   69700,
#   100,
#   69500,
#   69900,
#   69200,
#   12619289),
#  ('005930',
#   datetime.date(2022, 3, 29),
#   70200,
#   500,
#   70000,
#   70300,
#   69800,
#   13686208),
#  ('005930',
#   datetime.date(2022, 3, 30),
#   69900,
#   300,
#   70300,
#   70500,
#   69800,
#   12670187),
#  ('005930',
#   datetime.date(2022, 3, 31),
#   69600,
#   300,
#   69900,
#   70200,
#   69600,
#   12510366),
#  ('005930',
#   datetime.date(2022, 4, 1),
#   69100,
#   500,
#   69500,
#   69500,
#   69000,
#   15916846),
#  ('005930',
#   datetime.date(2022, 4, 4),
#   69300,
#   200,
#   68900,
#   69300,
#   68600,
#   11107905),
#  ('005930',
#   datetime.date(2022, 4, 5),
#   69200,
#   100,
#   69400,
#   69600,
#   69100,
#   8467248),
#  ('005930',
#   datetime.date(2022, 4, 6),
#   68500,
#   700,
#   68600,
#   68800,
#   68500,
#   15517308),
#  ('005930',
#   datetime.date(2022, 4, 7),
#   68000,
#   500,
#   68500,
#   68500,
#   68000,
#   20683327),
#  ('005930', datetime.date(2022, 4, 8), 68000, 0, 68100, 68300, 68000, 5676414))
