# %% [markdown]
# * UCI 머신러닝 리포지토리에서 제공하는 **사용자 행동 인식** 데이터 셋
# * 해당 데이터는 30명에게 스마트폰 센서를 장착한 뒤 사람의 동작과 관련된 여러가지 피처를 수집한 데이터

# %%
import pandas as pd

# %%
pd.read_csv("./data/UCIHARDataset/features.txt", sep='\s+').head()

# header=None 없을 때
# Out:
#    1  tBodyAcc-mean()-X
# 0  2  tBodyAcc-mean()-Y
# 1  3  tBodyAcc-mean()-Z
# 2  4   tBodyAcc-std()-X
# 3  5   tBodyAcc-std()-Y
# 4  6   tBodyAcc-std()-Z

# %%
feature_name_df = pd.read_csv("./data/UCIHARDataset/features.txt", sep='\s+', header=None, names=['col_index', 'col_name'])
feature_name_df.head()
# Out:
#    col_index           col_name
# 0          1  tBodyAcc-mean()-X
# 1          2  tBodyAcc-mean()-Y
# 2          3  tBodyAcc-mean()-Z
# 3          4   tBodyAcc-std()-X
# 4          5   tBodyAcc-std()-Y

# %%
feature_name = feature_name_df.iloc[:,1].tolist()
feature_name
# Out:
# ['tBodyAcc-mean()-X',
#  'tBodyAcc-mean()-Y',
#  'tBodyAcc-mean()-Z',
#  'tBodyAcc-std()-X',
#  'tBodyAcc-std()-Y',
#  'tBodyAcc-std()-Z',
#  'tBodyAcc-mad()-X',
#  'tBodyAcc-mad()-Y',
#  'tBodyAcc-mad()-Z',
#  'tBodyAcc-max()-X',
#  'tBodyAcc-max()-Y',
#  'tBodyAcc-max()-Z',
#  'tBodyAcc-min()-X',
#  'tBodyAcc-min()-Y',
#  'tBodyAcc-min()-Z',
#  'tBodyAcc-sma()',
#  'tBodyAcc-energy()-X',
#  'tBodyAcc-energy()-Y',
#  'tBodyAcc-energy()-Z',
#  'tBodyAcc-iqr()-X',
#  'tBodyAcc-iqr()-Y',
#  'tBodyAcc-iqr()-Z',
#  'tBodyAcc-entropy()-X',
#  'tBodyAcc-entropy()-Y',
#  'tBodyAcc-entropy()-Z',
#  'tBodyAcc-arCoeff()-X,1',
#  'tBodyAcc-arCoeff()-X,2',
#  'tBodyAcc-arCoeff()-X,3',
#  'tBodyAcc-arCoeff()-X,4',
#  'tBodyAcc-arCoeff()-Y,1',
#  'tBodyAcc-arCoeff()-Y,2',
#  'tBodyAcc-arCoeff()-Y,3',
#  'tBodyAcc-arCoeff()-Y,4',
#  'tBodyAcc-arCoeff()-Z,1',
#  'tBodyAcc-arCoeff()-Z,2',
#  'tBodyAcc-arCoeff()-Z,3',
#  'tBodyAcc-arCoeff()-Z,4',
#  'tBodyAcc-correlation()-X,Y',
# ...

# %%
feature_name.__len__()
# Out:
# 561

# %%
set(feature_name).__len__()
# Out:
# 477

# %%
list(set(feature_name)) # 중복이 제거되는 효과를 볼 수 있다
# Out:
# ['tGravityAccMag-entropy()',
#  'tBodyAcc-arCoeff()-Y,3',
#  'fBodyBodyAccJerkMag-energy()',
#  'fBodyBodyGyroMag-mad()',
#  'fBodyBodyGyroMag-meanFreq()',
#  'tBodyAccJerk-mad()-Y',
#  'fBodyBodyGyroMag-std()',
#  'tBodyGyroJerk-energy()-Z',
#  'fBodyBodyGyroJerkMag-meanFreq()',
#  'fBodyGyro-entropy()-Y',
#  'tBodyGyro-correlation()-Y,Z',
#  'tBodyGyroJerk-iqr()-Y',
#  'fBodyBodyGyroMag-skewness()',
#  'tBodyGyroJerk-min()-Z',
#  'fBodyAccJerk-mad()-X',
#  'fBodyAccJerk-meanFreq()-Y',
#  'tBodyGyro-arCoeff()-Z,4',
#  'tBodyGyroJerk-std()-X',
#  'tBodyAccJerk-max()-Z',
#  'tBodyAcc-mean()-X',
#  'fBodyAccJerk-mad()-Z',
#  'tBodyAccJerkMag-iqr()',
#  'fBodyAccMag-sma()',
#  'tBodyGyroJerkMag-mean()',
#  'tBodyAccJerk-arCoeff()-Y,1',
#  'tBodyGyro-correlation()-X,Y',
#  'fBodyGyro-mad()-Y',
#  'tGravityAccMag-arCoeff()4',
#  'tBodyAccJerk-arCoeff()-Y,2',
#  'fBodyAcc-mad()-Y',
#  'fBodyAccJerk-kurtosis()-Y',
#  'tGravityAcc-mean()-X',
#  'fBodyGyro-iqr()-Z',
#  'tBodyGyroMag-min()',
# ...

# %%
X_train = pd.read_csv("./data/UCIHARDataset/train/X_train.txt", sep="\s+", header=None)
X_train.columns = feature_name
# names=feature_name 이 안댐

# %%
X_train
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.995279         -0.983111         -0.913526         -0.995112
# ...

# %%
X_train.shape
# Out:
# (7351, 561)

# %%
y_train = pd.read_csv("./data/UCIHARDataset/train/y_train.txt", sep="\s+", header=None, names = ['action'])

# %%
y_train
# Out:
#       action
# 0          5
# 1          5
# 2          5
# 3          5
# 4          5
# ...      ...
# 7347       2
# 7348       2
# 7349       2
# 7350       2
# 7351       2
#
# [7352 rows x 1 columns]

# %% [markdown]
# ↓ action에 값이 뭐가 있는지 보고싶을때 2가지

# %%
y_train.value_counts()
# Out:
# action
# 6         1407
# 5         1374
# 4         1286
# 1         1226
# 2         1073
# 3          986
# dtype: int64

# %%
y_train['action'].unique()
# Out:
# array([5, 4, 6, 1, 3, 2], dtype=int64)
